# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Test accuracy

# %%
testacc = np.loadtxt("testacc.txt")

# %%
np.shape(testacc)
# Out:
# (8, 30)

# %%
methods = ["SGD","LBFGSfullbatch","LBFGSfullbatch", "LBFGSminibatch", "LBFGSNewminibatch", "LBFGSNewminibatch","SDLBFGS", "Curveball"]
bs_grid = [64,0,0,1024,1024,32,64,256]
hs_grid = [0,5,10,20,15,3,0,0]

# %%
for i in range(8):
    bs = bs_grid[i]
    hs = hs_grid[i]
    meth = methods[i]    
    plt.figure(1, figsize = (12,12))
    if i ==0:
        lr = 0.01
        plt.plot(testacc[i],label='{}, lr = {}, bs = {}'.format(meth,lr,bs))
        
    elif bs != 0 and hs !=0:
        plt.plot(testacc[i],label='{}, bs = {}, hs = {}'.format(meth,bs,hs))
    elif bs != 0:
        plt.plot(testacc[i],label='{}, bs = {}'.format(meth,bs))
    elif hs != 0:
        plt.plot(testacc[i],label='{}, hs = {}'.format(meth,hs))
    else:
        plt.plot(testacc[i],label='{}'.format(meth))
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.title('Test accuracy in FCNN for different methods',fontsize = 20)
plt.legend(fontsize = 13)
plt.savefig("test_accuracy_fcnn.jpg")
plt.figure (2)

# %% [markdown]
# ## Train loss

# %%
trainloss=np.loadtxt("trainloss.txt")
np.shape(trainloss)
# Out:
# (8, 30)

# %%
for i in range(8):
    bs = bs_grid[i]
    hs = hs_grid[i]
    meth = methods[i]    
    plt.figure(1, figsize = (12,12))
    if i ==0:
        lr = 0.01
        plt.plot(trainloss[i],label='{}, lr = {}, bs = {}'.format(meth,lr,bs))
        
    elif bs != 0 and hs !=0:
        plt.plot(trainloss[i],label='{}, bs = {}, hs = {}'.format(meth,bs,hs))
    elif bs != 0:
        plt.plot(trainloss[i],label='{}, bs = {}'.format(meth,bs))
    elif hs != 0:
        plt.plot(trainloss[i],label='{}, hs = {}'.format(meth,hs))
    else:
        plt.plot(trainloss[i],label='{}'.format(meth))
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
plt.title('Train Loss in FCNN for different methods',fontsize = 20)
plt.legend(fontsize = 13)
plt.savefig("train_loss_fcnn.jpg")
plt.figure (2)

# %%
for i in range(8):
    bs = bs_grid[i]
    hs = hs_grid[i]
    meth = methods[i]    
    plt.figure(1, figsize = (12,12))
    if i ==0:
        lr = 0.01
        plt.semilogy(trainloss[i],label='{}, lr = {}, bs = {}'.format(meth,lr,bs))
        
    elif bs != 0 and hs !=0:
        plt.semilogy(trainloss[i],label='{}, bs = {}, hs = {}'.format(meth,bs,hs))
    elif bs != 0:
        plt.semilogy(trainloss[i],label='{}, bs = {}'.format(meth,bs))
    elif hs != 0:
        plt.semilogy(trainloss[i],label='{}, hs = {}'.format(meth,hs))
    else:
        plt.semilogy(trainloss[i],label='{}'.format(meth))
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
plt.title('Train Loss in FCNN for different methods',fontsize = 20)
plt.legend(fontsize = 13)
plt.savefig("semilog_train_loss_fcnn.jpg")
plt.figure (2)

# %% [markdown]
# ## Test loss

# %%
testloss=np.loadtxt("testloss.txt")
np.shape(testloss)
# Out:
# (8, 30)

# %%
for i in range(8):
    bs = bs_grid[i]
    hs = hs_grid[i]
    meth = methods[i]    
    plt.figure(1, figsize = (12,12))
    if i ==0:
        lr = 0.01
        plt.plot(testloss[i],label='{}, lr = {}, bs = {}'.format(meth,lr,bs))
        
    elif bs != 0 and hs !=0:
        plt.plot(testloss[i],label='{}, bs = {}, hs = {}'.format(meth,bs,hs))
    elif bs != 0:
        plt.plot(testloss[i],label='{}, bs = {}'.format(meth,bs))
    elif hs != 0:
        plt.plot(testloss[i],label='{}, hs = {}'.format(meth,hs))
    else:
        plt.plot(testloss[i],label='{}'.format(meth))
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Test Loss in FCNN for different methods',fontsize = 20)
plt.legend(fontsize = 13)
plt.savefig("test_loss_fcnn.jpg")
plt.figure (2)

# %%
for i in range(8):
    bs = bs_grid[i]
    hs = hs_grid[i]
    meth = methods[i]    
    plt.figure(1, figsize = (12,12))
    if i ==0:
        lr = 0.01
        plt.semilogy(testloss[i],label='{}, lr = {}, bs = {}'.format(meth,lr,bs))
        
    elif bs != 0 and hs !=0:
        plt.semilogy(testloss[i],label='{}, bs = {}, hs = {}'.format(meth,bs,hs))
    elif bs != 0:
        plt.semilogy(testloss[i],label='{}, bs = {}'.format(meth,bs))
    elif hs != 0:
        plt.semilogy(testloss[i],label='{}, hs = {}'.format(meth,hs))
    else:
        plt.semilogy(testloss[i],label='{}'.format(meth))
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Test Loss in FCNN for different methods',fontsize = 20)
plt.legend(fontsize = 13)
plt.savefig("semilog_test_loss_fcnn.jpg")
plt.figure (2)
