# %%
# %matplotlib inline

import numpy as np
import torch
import matplotlib.pyplot as plt

#from helper2 import generate_dataset, visualize_one_dataset, visualize_datasets, predict_grid, visualize_predictions
from torch.utils import data

# %load_ext autoreload
# %autoreload 2

import torchvision

from time import time
from torchvision import datasets, transforms
from torch import nn, optim

from helpers_opt_parameters import *
#from sdlbfgs import *

# %%
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])

# %% [markdown]
# ### MNIST dataset
# The MNIST dataset is loaded.

# %%
trainset = datasets.FashionMNIST('', download=True, train=True, transform=transform)
valset = datasets.FashionMNIST('PATH_TO_STORE_TESTSET', download=True, train=False, transform=transform)

# %%
print("Training and test sets information is displayed.\n\n")
print("Trainset:\n",trainset)
print("Testset:\n",valset)
# Out:
# Training and test sets information is displayed.
#
#
# Trainset:
#  Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location:
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5,), std=(0.5,))
#            )
# Testset:
#  Dataset FashionMNIST
#     Number of datapoints: 10000
#     Root location: PATH_TO_STORE_TESTSET
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5,), std=(0.5,))
#            )

# %% [markdown]
# # LBFGS mini-batch hyperparameters tuning

# %%
minibatch_size_grid=[32,64]
max_iter = 3
history_size_grid=[10,20]

# %%
epochs = 30

# %% [markdown]
# ### Fully connected network

# %%
training_loss_fcnn, test_loss_fcnn,training_accuracy_fcnn, test_accuracy_fcnn, time_fcnn =hyperparameters_tuning_LBFGS_minibatch(trainset,valset,minibatch_size_grid, history_size_grid, max_iter,epochs, "FCNN")
# Out:
#  = 0.8153
# Number Of Images Tested = 60000
# Model Accuracy = 0.8344833333333334
# Test loss: 0.7248814880324248
#
# Epoch 20
# Training loss: 0.3227877182719608
# Number Of Images Tested = 10000
# Model Accuracy = 0.828
# Number Of Images Tested = 60000
# Model Accuracy = 0.8462166666666666
# Test loss: 0.6093688381556124
#
# Epoch 21
# Training loss: 0.33703113129759826
# Number Of Images Tested = 10000
# Model Accuracy = 0.7623
# Number Of Images Tested = 60000
# Model Accuracy = 0.7784333333333333
# Test loss: 0.9414406076502114
#
# Epoch 22
# Training loss: 0.35379738453974324
# Number Of Images Tested = 10000
# Model Accuracy = 0.8007
# Number Of Images Tested = 60000
# Model Accuracy = 0.8194
# Test loss: 0.6512735583149968
#
# Epoch 23
# Training loss: 0.3615498613901436
# Number Of Images Tested = 10000
# Model Accuracy = 0.8203
# Number Of Images Tested = 60000
# Model Accuracy = 0.8370166666666666
# Test loss: 0.8069626647062575
#
# Epoch 24
# Training loss: 0.35412679810896514
# Number Of Images Tested = 10000
# Model Accuracy = 0.8245
# Number Of Images Tested = 60000
# Model Accuracy = 0.8438833333333333
# Test loss: 0.7288513121703943
#
# Epoch 25
# Training loss: 0.3458337815688923
# Number Of Images Tested = 10000
# Model Accuracy = 0.7776
# Number Of Images Tested = 60000
# Model Accuracy = 0.79945
# Test loss: 0.865729291051531
#
# Epoch 26
# Training loss: 0.35386274661521117
# Number Of Images Tested = 10000
# Model Accuracy = 0.8141
# Number Of Images Tested = 60000
# Model Accuracy = 0.8340833333333333
# Test loss: 0.7460012392114146
#
# Epoch 27
# Training loss: 0.3463783070569237
# Number Of Images Tested = 10000
# Model Accuracy = 0.8399
# Number Of Images Tested = 60000
# Model Accuracy = 0.8649166666666667
# Test loss: 0.58003607568459
#
# Epoch 28
# Training loss: 0.35424061451603966
# Number Of Images Tested = 10000
# Model Accuracy = 0.8082
# Number Of Images Tested = 60000
# Model Accuracy = 0.8269166666666666
# Test loss: 0.8637757382739466
#
# Epoch 29
# Training loss: 0.3625628723505884
# Number Of Images Tested = 10000
# Model Accuracy = 0.8099
# Number Of Images Tested = 60000
# Model Accuracy = 0.8292833333333334
# Test loss: 0.717882757322095
#
#
# Training Time (in minutes) = 75.71335570414861
#
#
# Minibatch size:  32
# History size:  20
# Epoch 0
# Training loss: 0.37158258232871694
# Number Of Images Tested = 10000
# Model Accuracy = 0.7521
# Number Of Images Tested = 60000
# Model Accuracy = 0.7580666666666667
# Test loss: 0.7199238197872052
#
# Epoch 1
# Training loss: 0.2937083945954839
# Number Of Images Tested = 10000
# Model Accuracy = 0.8085
# Number Of Images Tested = 60000
# Model Accuracy = 0.8278166666666666
# Test loss: 0.6127374304559665
#
# Epoch 2
# Training loss: 0.2825853550901016
# Number Of Images Tested = 10000
# Model Accuracy = 0.8405
# Number Of Images Tested = 60000
# Model Accuracy = 0.8548166666666667
# Test loss: 0.5124495277722804
#
# Epoch 3
# Training loss: 0.28325359985629717
# Number Of Images Tested = 10000
# Model Accuracy = 0.738
# Number Of Images Tested = 60000
# Model Accuracy = 0.7501666666666666
# Test loss: 1.0116957080440399
#
# Epoch 4
# Training loss: 0.28376825116351245
# Number Of Images Tested = 10000
# Model Accuracy = 0.7996
# Number Of Images Tested = 60000
# Model Accuracy = 0.82
# Test loss: 0.5581318357596382
#
# Epoch 5
# Training loss: 0.2812583589211106
# Number Of Images Tested = 10000
# Model Accuracy = 0.6793
# Number Of Images Tested = 60000
# Model Accuracy = 0.69025
# Test loss: 1.3690611017397798
#
# Epoch 6
# Training loss: 0.283661377019311
# Number Of Images Tested = 10000
# Model Accuracy = 0.7779
# Number Of Images Tested = 60000
# Model Accuracy = 0.7977666666666666
# Test loss: 0.6976842308958499
#
# Epoch 7
# Training loss: 0.28534625083555776
# Number Of Images Tested = 10000
# Model Accuracy = 0.7856
# Number Of Images Tested = 60000
# Model Accuracy = 0.7996333333333333
# Test loss: 0.9016525006760805
#
# Epoch 8
# Training loss: 0.30094847510494294
# Number Of Images Tested = 10000
# Model Accuracy = 0.8318
# Number Of Images Tested = 60000
# Model Accuracy = 0.8468
# Test loss: 0.6492609879174552
#
# Epoch 9
# Training loss: 0.3017910729552309
# Number Of Images Tested = 10000
# Model Accuracy = 0.786
# Number Of Images Tested = 60000
# Model Accuracy = 0.80055
# Test loss: 0.6899106427789116
#
# Epoch 10
# Training loss: 0.3168200210611026
# Number Of Images Tested = 10000
# Model Accuracy = 0.8222
# Number Of Images Tested = 60000
# Model Accuracy = 0.8384333333333334
# Test loss: 0.6624951949848915
#
# Epoch 11
# Training loss: 0.31536122246682646
# Number Of Images Tested = 10000
# Model Accuracy = 0.8176
# Number Of Images Tested = 60000
# Model Accuracy = 0.8378
# Test loss: 0.5788878041048782
#
# Epoch 12
# Training loss: 0.32180732143844165
# Number Of Images Tested = 10000
# Model Accuracy = 0.8376
# Number Of Images Tested = 60000
# Model Accuracy = 0.8556333333333334
# Test loss: 0.6123491318557209
#
# Epoch 13
# Training loss: 0.31554208366433156
# Number Of Images Tested = 10000
# Model Accuracy = 0.8144
# Number Of Images Tested = 60000
# Model Accuracy = 0.83345
# Test loss: 0.5646253566677197
#
# Epoch 14
# Training loss: 0.3270988195930918
# Number Of Images Tested = 10000
# Model Accuracy = 0.8075
# Number Of Images Tested = 60000
# Model Accuracy = 0.8282833333333334
# Test loss: 0.6165579070393651
#
# Epoch 15
# Training loss: 0.34117042823433874
# Number Of Images Tested = 10000
# Model Accuracy = 0.7842
# Number Of Images Tested = 60000
# Model Accuracy = 0.80245
# Test loss: 0.8304089649607198
#
# Epoch 16
# Training loss: 0.3487347372867167
# Number Of Images Tested = 10000
# Model Accuracy = 0.7679
# Number Of Images Tested = 60000
# Model Accuracy = 0.7858833333333334
# Test loss: 0.9183433266779104
#
# Epoch 17
# Training loss: 0.33393733642597995
# Number Of Images Tested = 10000
# Model Accuracy = 0.8255
# Number Of Images Tested = 60000
# Model Accuracy = 0.8424333333333334
# Test loss: 0.6533145074027414
#
# Epoch 18
# Training loss: 0.34710465092230586
# Number Of Images Tested = 10000
# Model Accuracy = 0.787
# Number Of Images Tested = 60000
# Model Accuracy = 0.8009666666666667
# Test loss: 0.8313463290516561
#
# Epoch 19
# Training loss: 0.3441739253987869
# Number Of Images Tested = 10000
# Model Accuracy = 0.78
# Number Of Images Tested = 60000
# Model Accuracy = 0.7931833333333334
# Test loss: 1.1917075636192633
#
# Epoch 20
# Training loss: 0.34895866606086495
# Number Of Images Tested = 10000
# Model Accuracy = 0.7942
# Number Of Images Tested = 60000
# Model Accuracy = 0.8084666666666667
# Test loss: 1.0543983816719664
#
# Epoch 21
# Training loss: 0.3575886205608646
# Number Of Images Tested = 10000
# Model Accuracy = 0.8041
# Number Of Images Tested = 60000
# Model Accuracy = 0.8249833333333333
# Test loss: 0.6803025218625419
#
# Epoch 22
# Training loss: 0.37521881670951845
# Number Of Images Tested = 10000
# Model Accuracy = 0.8295
# Number Of Images Tested = 60000
# Model Accuracy = 0.8459166666666667
# Test loss: 0.6699951926406961
#
# Epoch 23
# Training loss: 0.38540424332891904
# Number Of Images Tested = 10000
# Model Accuracy = 0.8225
# Number Of Images Tested = 60000
# Model Accuracy = 0.8468333333333333
# Test loss: 0.6282084935341781
#
# Epoch 24
# Training loss: 0.37160455355991917
# Number Of Images Tested = 10000
# Model Accuracy = 0.8239
# Number Of Images Tested = 60000
# Model Accuracy = 0.84035
# Test loss: 0.7202291808332117
#
# Epoch 25
# Training loss: 0.3584679177249471
# Number Of Images Tested = 10000
# Model Accuracy = 0.8186
# Number Of Images Tested = 60000
# Model Accuracy = 0.8385833333333333
# Test loss: 0.9660487479438036
#
# Epoch 26
# Training loss: 0.3865986841318508
# Number Of Images Tested = 10000
# Model Accuracy = 0.7528
# Number Of Images Tested = 60000
# Model Accuracy = 0.76825
# Test loss: 0.9418090687582668
#
# Epoch 27
# Training loss: 0.393708001857996
# Number Of Images Tested = 10000
# Model Accuracy = 0.8194
# Number Of Images Tested = 60000
# Model Accuracy = 0.8351
# Test loss: 0.767727391788373
#
# Epoch 28
# Training loss: 0.3956820275977254
# Number Of Images Tested = 10000
# Model Accuracy = 0.8081
# Number Of Images Tested = 60000
# Model Accuracy = 0.82945
# Test loss: 0.6754546282104791
#
# Epoch 29
# Training loss: 0.37734674290965003
# Number Of Images Tested = 10000
# Model Accuracy = 0.8138
# Number Of Images Tested = 60000
# Model Accuracy = 0.8307333333333333
# Test loss: 1.2003232510998465
#
#
# Training Time (in minutes) = 85.45767532587051
#
#
# Minibatch size:  64
# History size:  10
# Epoch 0
# Training loss: 0.48530799504726935
# Number Of Images Tested = 10000
# Model Accuracy = 0.8018
# Number Of Images Tested = 60000
# Model Accuracy = 0.8117166666666666
# Test loss: 0.5701217714009011
#
# Epoch 1
# Training loss: 0.35018074689611695
# Number Of Images Tested = 10000
# Model Accuracy = 0.8278
# Number Of Images Tested = 60000
# Model Accuracy = 0.8341
# Test loss: 0.5065273547628123
#
# Epoch 2
# Training loss: 0.29560826977750637
# Number Of Images Tested = 10000
# Model Accuracy = 0.773
# Number Of Images Tested = 60000
# Model Accuracy = 0.78905
# Test loss: 0.6724478721998299
#
# Epoch 3
# Training loss: 0.26325185283192437
# Number Of Images Tested = 10000
# Model Accuracy = 0.8284
# Number Of Images Tested = 60000
# Model Accuracy = 0.84595
# Test loss: 0.49788839944229
#
# Epoch 4
# Training loss: 0.24263951604538508
# Number Of Images Tested = 10000
# Model Accuracy = 0.8172
# Number Of Images Tested = 60000
# Model Accuracy = 0.8335333333333333
# Test loss: 0.5294048092357672
#
# Epoch 5
# Training loss: 0.22905009434913903
# Number Of Images Tested = 10000
# Model Accuracy = 0.7964
# Number Of Images Tested = 60000
# Model Accuracy = 0.81755
# Test loss: 0.5645242858274727
#
# Epoch 6
# Training loss: 0.21841663936339717
# Number Of Images Tested = 10000
# Model Accuracy = 0.8622
# Number Of Images Tested = 60000
# Model Accuracy = 0.8831333333333333
# Test loss: 0.40534970933085035
#
# Epoch 7
# Training loss: 0.2040550605947974
# Number Of Images Tested = 10000
# Model Accuracy = 0.8133
# Number Of Images Tested = 60000
# Model Accuracy = 0.8321666666666667
# Test loss: 0.5300112789983202
#
# Epoch 8
# Training loss: 0.20320525656996377
# Number Of Images Tested = 10000
# Model Accuracy = 0.8568
# Number Of Images Tested = 60000
# Model Accuracy = 0.8796333333333334
# Test loss: 0.41177178966771266
#
# Epoch 9
# Training loss: 0.18984236375593555
# Number Of Images Tested = 10000
# Model Accuracy = 0.7994
# Number Of Images Tested = 60000
# Model Accuracy = 0.8167
# Test loss: 0.7064089239782588
#
# Epoch 10
# Training loss: 0.18651319274515993
# Number Of Images Tested = 10000
# Model Accuracy = 0.863
# Number Of Images Tested = 60000
# Model Accuracy = 0.8890166666666667
# Test loss: 0.42124346003031277
#
# Epoch 11
# Training loss: 0.18057513410753723
# Number Of Images Tested = 10000
# Model Accuracy = 0.845
# Number Of Images Tested = 60000
# Model Accuracy = 0.8717833333333334
# Test loss: 0.45531949733093285
#
# Epoch 12
# Training loss: 0.18054650430637065
# Number Of Images Tested = 10000
# Model Accuracy = 0.8743
# Number Of Images Tested = 60000
# Model Accuracy = 0.90135
# Test loss: 0.3816684947651663
#
# Epoch 13
# Training loss: 0.1786776411323262
# Number Of Images Tested = 10000
# Model Accuracy = 0.8537
# Number Of Images Tested = 60000
# Model Accuracy = 0.8780833333333333
# Test loss: 0.48039625388137097
#
# Epoch 14
# Training loss: 0.17288643610614068
# Number Of Images Tested = 10000
# Model Accuracy = 0.7663
# Number Of Images Tested = 60000
# Model Accuracy = 0.7843333333333333
# Test loss: 0.856857727477505
#
# Epoch 15
# Training loss: 0.16770721281141932
# Number Of Images Tested = 10000
# Model Accuracy = 0.8671
# Number Of Images Tested = 60000
# Model Accuracy = 0.8985333333333333
# Test loss: 0.39449375412266724
#
# Epoch 16
# Training loss: 0.16309277067330283
# Number Of Images Tested = 10000
# Model Accuracy = 0.8632
# Number Of Images Tested = 60000
# Model Accuracy = 0.89585
# Test loss: 0.4390070811388599
#
# Epoch 17
# Training loss: 0.15946610710089174
# Number Of Images Tested = 10000
# Model Accuracy = 0.7815
# Number Of Images Tested = 60000
# Model Accuracy = 0.8007833333333333
# Test loss: 0.9802559304768872
#
# Epoch 18
# Training loss: 0.15990537251316028
# Number Of Images Tested = 10000
# Model Accuracy = 0.8473
# Number Of Images Tested = 60000
# Model Accuracy = 0.8779666666666667
# Test loss: 0.5156054943799973
#
# Epoch 19
# Training loss: 0.15561988721611594
# Number Of Images Tested = 10000
# Model Accuracy = 0.7125
# Number Of Images Tested = 60000
# Model Accuracy = 0.7325666666666667
# Test loss: 1.439109463600596
#
# Epoch 20
# Training loss: 0.15674526833875507
# Number Of Images Tested = 10000
# Model Accuracy = 0.8606
# Number Of Images Tested = 60000
# Model Accuracy = 0.89485
# Test loss: 0.42803276605477
#
# Epoch 21
# Training loss: 0.15354948643563207
# Number Of Images Tested = 10000
# Model Accuracy = 0.8691
# Number Of Images Tested = 60000
# Model Accuracy = 0.9013166666666667
# Test loss: 0.44564703016713925
#
# Epoch 22
# Training loss: 0.15152984757079627
# Number Of Images Tested = 10000
# Model Accuracy = 0.8626
# Number Of Images Tested = 60000
# Model Accuracy = 0.9033
# Test loss: 0.4514947864849856
#
# Epoch 23
# Training loss: 0.15048455422037224
# Number Of Images Tested = 10000
# Model Accuracy = 0.8622
# Number Of Images Tested = 60000
# Model Accuracy = 0.8903833333333333
# Test loss: 0.47602268782960383
#
# Epoch 24
# Training loss: 0.14902961083741456
# Number Of Images Tested = 10000
# Model Accuracy = 0.8462
# Number Of Images Tested = 60000
# Model Accuracy = 0.87235
# Test loss: 0.5588101785463891
#
# Epoch 25
# Training loss: 0.14031031741790456
# Number Of Images Tested = 10000
# Model Accuracy = 0.8244
# Number Of Images Tested = 60000
# Model Accuracy = 0.8540666666666666
# Test loss: 0.5952662044459847
#
# Epoch 26
# Training loss: 0.14291999391965202
# Number Of Images Tested = 10000
# Model Accuracy = 0.8643
# Number Of Images Tested = 60000
# Model Accuracy = 0.9005666666666666
# Test loss: 0.5006489252113993
#
# Epoch 27
# Training loss: 0.1409341092305834
# Number Of Images Tested = 10000
# Model Accuracy = 0.8671
# Number Of Images Tested = 60000
# Model Accuracy = 0.9064166666666666
# Test loss: 0.4844408067548351
#
# Epoch 28
# Training loss: 0.13875358718147537
# Number Of Images Tested = 10000
# Model Accuracy = 0.8497
# Number Of Images Tested = 60000
# Model Accuracy = 0.8846166666666667
# Test loss: 0.5269806568220163
#
# Epoch 29
# Training loss: 0.1356661541651545
# Number Of Images Tested = 10000
# Model Accuracy = 0.8561
# Number Of Images Tested = 60000
# Model Accuracy = 0.8955333333333333
# Test loss: 0.5429572762838405
#
#
# Training Time (in minutes) = 56.727359588940935
#
#
# Minibatch size:  64
# History size:  20
# Epoch 0
# Training loss: 0.5710200811309347
# Number Of Images Tested = 10000
# Model Accuracy = 0.8009
# Number Of Images Tested = 60000
# Model Accuracy = 0.81405
# Test loss: 0.5470861794462629
#
# Epoch 1
# Training loss: 0.4094401016227726
# Number Of Images Tested = 10000
# Model Accuracy = 0.8085
# Number Of Images Tested = 60000
# Model Accuracy = 0.8228333333333333
# Test loss: 0.552281778898968
#
# Epoch 2
# Training loss: 0.35406587219664026
# Number Of Images Tested = 10000
# Model Accuracy = 0.7819
# Number Of Images Tested = 60000
# Model Accuracy = 0.79165
# Test loss: 0.6275592732961011
#
# Epoch 3
# Training loss: 0.31953653828231005
# Number Of Images Tested = 10000
# Model Accuracy = 0.7918
# Number Of Images Tested = 60000
# Model Accuracy = 0.8037833333333333
# Test loss: 0.6196341675937556
#
# Epoch 4
# Training loss: 0.2858684758848346
# Number Of Images Tested = 10000
# Model Accuracy = 0.8368
# Number Of Images Tested = 60000
# Model Accuracy = 0.8540666666666666
# Test loss: 0.4610153324664778
#
# Epoch 5
# Training loss: 0.265244434875593
# Number Of Images Tested = 10000
# Model Accuracy = 0.8389
# Number Of Images Tested = 60000
# Model Accuracy = 0.8518166666666667
# Test loss: 0.4591049702873655
#
# Epoch 6
# Training loss: 0.24457046987294262
# Number Of Images Tested = 10000
# Model Accuracy = 0.8575
# Number Of Images Tested = 60000
# Model Accuracy = 0.8774333333333333
# Test loss: 0.4062422308952186
#
# Epoch 7
# Training loss: 0.23236573615006165
# Number Of Images Tested = 10000
# Model Accuracy = 0.7962
# Number Of Images Tested = 60000
# Model Accuracy = 0.81135
# Test loss: 0.7023396332552478
#
# Epoch 8
# Training loss: 0.2202318027409028
# Number Of Images Tested = 10000
# Model Accuracy = 0.8345
# Number Of Images Tested = 60000
# Model Accuracy = 0.8552833333333333
# Test loss: 0.46054379290835873
#
# Epoch 9
# Training loss: 0.21721026570256205
# Number Of Images Tested = 10000
# Model Accuracy = 0.8025
# Number Of Images Tested = 60000
# Model Accuracy = 0.8176833333333333
# Test loss: 0.6061087199457132
#
# Epoch 10
# Training loss: 0.20630498909985207
# Number Of Images Tested = 10000
# Model Accuracy = 0.849
# Number Of Images Tested = 60000
# Model Accuracy = 0.8699833333333333
# Test loss: 0.4600651471098517
#
# Epoch 11
# Training loss: 0.20101958297208936
# Number Of Images Tested = 10000
# Model Accuracy = 0.8397
# Number Of Images Tested = 60000
# Model Accuracy = 0.8619333333333333
# Test loss: 0.4646875805156246
#
# Epoch 12
# Training loss: 0.19456458988108996
# Number Of Images Tested = 10000
# Model Accuracy = 0.8355
# Number Of Images Tested = 60000
# Model Accuracy = 0.8604
# Test loss: 0.48927953673206315
#
# Epoch 13
# Training loss: 0.19418483927869784
# Number Of Images Tested = 10000
# Model Accuracy = 0.8457
# Number Of Images Tested = 60000
# Model Accuracy = 0.8704
# Test loss: 0.4388999306851891
#
# Epoch 14
# Training loss: 0.186257206046505
# Number Of Images Tested = 10000
# Model Accuracy = 0.7956
# Number Of Images Tested = 60000
# Model Accuracy = 0.8233666666666667
# Test loss: 0.6598230573781736
#
# Epoch 15
# Training loss: 0.18340638310892748
# Number Of Images Tested = 10000
# Model Accuracy = 0.839
# Number Of Images Tested = 60000
# Model Accuracy = 0.8621166666666666
# Test loss: 0.555502979333993
#
# Epoch 16
# Training loss: 0.18069967153126687
# Number Of Images Tested = 10000
# Model Accuracy = 0.8118
# Number Of Images Tested = 60000
# Model Accuracy = 0.83005
# Test loss: 0.8265945256515673
#
# Epoch 17
# Training loss: 0.17796789035538652
# Number Of Images Tested = 10000
# Model Accuracy = 0.8584
# Number Of Images Tested = 60000
# Model Accuracy = 0.8848833333333334
# Test loss: 0.45682313952856
#
# Epoch 18
# Training loss: 0.17560203211393946
# Number Of Images Tested = 10000
# Model Accuracy = 0.8662
# Number Of Images Tested = 60000
# Model Accuracy = 0.8938333333333334
# Test loss: 0.4161346134296648
#
# Epoch 19
# Training loss: 0.1764224085277681
# Number Of Images Tested = 10000
# Model Accuracy = 0.8436
# Number Of Images Tested = 60000
# Model Accuracy = 0.8690166666666667
# Test loss: 0.5811449563617159
#
# Epoch 20
# Training loss: 0.17170386441421312
# Number Of Images Tested = 10000
# Model Accuracy = 0.8493
# Number Of Images Tested = 60000
# Model Accuracy = 0.8745833333333334
# Test loss: 0.4819208760360244
#
# Epoch 21
# Training loss: 0.17327574445113444
# Number Of Images Tested = 10000
# Model Accuracy = 0.8575
# Number Of Images Tested = 60000
# Model Accuracy = 0.8867333333333334
# Test loss: 0.46883421894281535
#
# Epoch 22
# Training loss: 0.1656100531078891
# Number Of Images Tested = 10000
# Model Accuracy = 0.8173
# Number Of Images Tested = 60000
# Model Accuracy = 0.8411333333333333
# Test loss: 0.6799080031123131
#
# Epoch 23
# Training loss: 0.17121943634257578
# Number Of Images Tested = 10000
# Model Accuracy = 0.844
# Number Of Images Tested = 60000
# Model Accuracy = 0.8706166666666667
# Test loss: 0.5943478381937477
#
# Epoch 24
# Training loss: 0.16323245483945045
# Number Of Images Tested = 10000
# Model Accuracy = 0.824
# Number Of Images Tested = 60000
# Model Accuracy = 0.8546833333333334
# Test loss: 0.5604817749588353
#
# Epoch 25
# Training loss: 0.15978454033445036
# Number Of Images Tested = 10000
# Model Accuracy = 0.8607
# Number Of Images Tested = 60000
# Model Accuracy = 0.9010833333333333
# Test loss: 0.4777281506841255
#
# Epoch 26
# Training loss: 0.16024852068280615
# Number Of Images Tested = 10000
# Model Accuracy = 0.8337
# Number Of Images Tested = 60000
# Model Accuracy = 0.8615833333333334
# Test loss: 0.562226525727351
#
# Epoch 27
# Training loss: 0.16058974065827822
# Number Of Images Tested = 10000
# Model Accuracy = 0.8494
# Number Of Images Tested = 60000
# Model Accuracy = 0.8846
# Test loss: 0.4938553187308038
#
# Epoch 28
# Training loss: 0.15832120270879346
# Number Of Images Tested = 10000
# Model Accuracy = 0.8412
# Number Of Images Tested = 60000
# Model Accuracy = 0.8645166666666667
# Test loss: 0.6215375873503411
#
# Epoch 29
# Training loss: 0.16110008701320683
# Number Of Images Tested = 10000
# Model Accuracy = 0.8481
# Number Of Images Tested = 60000
# Model Accuracy = 0.8754333333333333
# Test loss: 0.4911320729620138
#
#
# Training Time (in minutes) = 62.332775223255155

# %%
np.savetxt('1/LBFGS_minibatch_fcNN_trainloss.txt', training_loss_fcnn)
np.savetxt('1/LBFGS_minibatch_fcNN_testloss.txt', test_loss_fcnn)
np.savetxt('1/LBFGS_minibatch_fcNN_trainacc.txt', training_accuracy_fcnn)
np.savetxt('1/LBFGS_minibatch_fcNN_testacc.txt', test_accuracy_fcnn)
np.savetxt('1/LBFGS_minibatch_fcNN_times.txt',time_fcnn)

# %%
i = 0
for bs_index,bs in enumerate(minibatch_size_grid):
    for hs_index,hs in enumerate(history_size_grid):
        plt.figure(1, figsize = (10,8))
        plt.plot(test_loss_fcnn[i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(2, figsize = (10,8))
        plt.plot(training_loss_fcnn[i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(3, figsize = (10,8))
        plt.plot(test_accuracy_fcnn[i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(4, figsize = (10,8))
        plt.plot(training_accuracy_fcnn[i],label='bs = {}, hs = {}'.format(bs,hs))
        i+=1

plt.figure(1)
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Minibatch LBFGS Test loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("1/mini_LBFGS_test_loss_fcnn.jpg")
plt.figure (2)
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
plt.title('Minibatch LBFGS Train loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("1/mini_LBFGS_train_loss_fcnn.jpg")
plt.figure (3)
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.title('Minibatch LBFGS Test accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("1/mini_LBFGS_test_acc_fcnn.jpg")
plt.figure (4)
plt.xlabel('Epochs')
plt.ylabel('Train Accuracy')
plt.title('Minibatch LBFGS Train accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("1/mini_LBFGS_train_acc_fcnn.jpg")

# %%
minibatch_size_grid = [128,512,1024]

history_size_grid=[10,20]

# %%
training_loss_fcnn2, test_loss_fcnn,training_accuracy_fcnn2, test_accuracy_fcnn2, time_fcnn2 = hyperparameters_tuning_LBFGS_minibatch(trainset,valset,minibatch_size_grid, history_size_grid, max_iter,epochs, "FCNN2")
# Out:
# Of Images Tested = 60000
# Model Accuracy = 0.8853833333333333
# Test loss: 1.2037982791662216
#
# Epoch 20
# Training loss: 0.019757037682920472
# Number Of Images Tested = 10000
# Model Accuracy = 0.8631
# Number Of Images Tested = 60000
# Model Accuracy = 0.9136
# Test loss: 0.9592636346817016
#
# Epoch 21
# Training loss: 0.016414386274537736
# Number Of Images Tested = 10000
# Model Accuracy = 0.8632
# Number Of Images Tested = 60000
# Model Accuracy = 0.90975
# Test loss: 0.9877932846546174
#
# Epoch 22
# Training loss: 0.020534675650720847
# Number Of Images Tested = 10000
# Model Accuracy = 0.8597
# Number Of Images Tested = 60000
# Model Accuracy = 0.9087666666666666
# Test loss: 1.073169583082199
#
# Epoch 23
# Training loss: 0.016809262754592918
# Number Of Images Tested = 10000
# Model Accuracy = 0.8652
# Number Of Images Tested = 60000
# Model Accuracy = 0.9184833333333333
# Test loss: 1.1192024946212769
#
# Epoch 24
# Training loss: 0.017615164805724587
# Number Of Images Tested = 10000
# Model Accuracy = 0.859
# Number Of Images Tested = 60000
# Model Accuracy = 0.9014666666666666
# Test loss: 1.2253079831600189
#
# Epoch 25
# Training loss: 0.020788137302280137
# Number Of Images Tested = 10000
# Model Accuracy = 0.8612
# Number Of Images Tested = 60000
# Model Accuracy = 0.9159833333333334
# Test loss: 1.0893009305000305
#
# Epoch 26
# Training loss: 0.01694821174995445
# Number Of Images Tested = 10000
# Model Accuracy = 0.857
# Number Of Images Tested = 60000
# Model Accuracy = 0.9132666666666667
# Test loss: 1.291507214307785
#
# Epoch 27
# Training loss: 0.0160229567934609
# Number Of Images Tested = 10000
# Model Accuracy = 0.856
# Number Of Images Tested = 60000
# Model Accuracy = 0.9024833333333333
# Test loss: 1.3959486365318299
#
# Epoch 28
# Training loss: 0.016631271525866242
# Number Of Images Tested = 10000
# Model Accuracy = 0.8543
# Number Of Images Tested = 60000
# Model Accuracy = 0.9031
# Test loss: 1.2953247785568238
#
# Epoch 29
# Training loss: 0.015346874764842235
# Number Of Images Tested = 10000
# Model Accuracy = 0.8734
# Number Of Images Tested = 60000
# Model Accuracy = 0.94075
# Test loss: 1.0766368627548217
#
#
# Training Time (in minutes) = 22.386898950735727
#
#
# Minibatch size:  512
# History size:  20
# Epoch 0
# Training loss: 0.08094253322411471
# Number Of Images Tested = 10000
# Model Accuracy = 0.7766
# Number Of Images Tested = 60000
# Model Accuracy = 0.7878333333333334
# Test loss: 1.7797212958335877
#
# Epoch 1
# Training loss: 0.026430924897086098
# Number Of Images Tested = 10000
# Model Accuracy = 0.8103
# Number Of Images Tested = 60000
# Model Accuracy = 0.82275
# Test loss: 1.4333765387535096
#
# Epoch 2
# Training loss: 0.02068917241244196
# Number Of Images Tested = 10000
# Model Accuracy = 0.8107
# Number Of Images Tested = 60000
# Model Accuracy = 0.8323666666666667
# Test loss: 1.4121046543121338
#
# Epoch 3
# Training loss: 0.019562923407277794
# Number Of Images Tested = 10000
# Model Accuracy = 0.8222
# Number Of Images Tested = 60000
# Model Accuracy = 0.83785
# Test loss: 1.99328955411911
#
# Epoch 4
# Training loss: 0.023193808488817382
# Number Of Images Tested = 10000
# Model Accuracy = 0.7973
# Number Of Images Tested = 60000
# Model Accuracy = 0.8086
# Test loss: 1.8553299129009246
#
# Epoch 5
# Training loss: 0.021865501338236185
# Number Of Images Tested = 10000
# Model Accuracy = 0.8155
# Number Of Images Tested = 60000
# Model Accuracy = 0.8341166666666666
# Test loss: 1.8383384704589845
#
# Epoch 6
# Training loss: 0.021513065741539508
# Number Of Images Tested = 10000
# Model Accuracy = 0.8053
# Number Of Images Tested = 60000
# Model Accuracy = 0.82675
# Test loss: 1.9639113068580627
#
# Epoch 7
# Training loss: 0.019094441926365294
# Number Of Images Tested = 10000
# Model Accuracy = 0.7759
# Number Of Images Tested = 60000
# Model Accuracy = 0.80215
# Test loss: 2.7507938981056212
#
# Epoch 8
# Training loss: 0.021414516565277677
# Number Of Images Tested = 10000
# Model Accuracy = 0.7787
# Number Of Images Tested = 60000
# Model Accuracy = 0.7963833333333333
# Test loss: 2.4660819351673124
#
# Epoch 9
# Training loss: 0.02760511166041212
# Number Of Images Tested = 10000
# Model Accuracy = 0.795
# Number Of Images Tested = 60000
# Model Accuracy = 0.8170833333333334
# Test loss: 2.549648308753967
#
# Epoch 10
# Training loss: 0.026718425005122885
# Number Of Images Tested = 10000
# Model Accuracy = 0.8231
# Number Of Images Tested = 60000
# Model Accuracy = 0.84735
# Test loss: 1.9951545774936676
#
# Epoch 11
# Training loss: 0.03409229782347843
# Number Of Images Tested = 10000
# Model Accuracy = 0.8149
# Number Of Images Tested = 60000
# Model Accuracy = 0.8332833333333334
# Test loss: 2.062212234735489
#
# Epoch 12
# Training loss: 0.04545639442197063
# Number Of Images Tested = 10000
# Model Accuracy = 0.7975
# Number Of Images Tested = 60000
# Model Accuracy = 0.8148833333333333
# Test loss: 2.188187462091446
#
# Epoch 13
# Training loss: 0.051694308770662646
# Number Of Images Tested = 10000
# Model Accuracy = 0.7843
# Number Of Images Tested = 60000
# Model Accuracy = 0.8002333333333334
# Test loss: 2.2850488424301147
#
# Epoch 14
# Training loss: 0.054391031429739826
# Number Of Images Tested = 10000
# Model Accuracy = 0.8326
# Number Of Images Tested = 60000
# Model Accuracy = 0.8502333333333333
# Test loss: 1.9261009991168976
#
# Epoch 15
# Training loss: 0.05659651560144069
# Number Of Images Tested = 10000
# Model Accuracy = 0.8179
# Number Of Images Tested = 60000
# Model Accuracy = 0.8411333333333333
# Test loss: 2.6008599281311033
#
# Epoch 16
# Training loss: 0.06598747753680258
# Number Of Images Tested = 10000
# Model Accuracy = 0.8256
# Number Of Images Tested = 60000
# Model Accuracy = 0.8449333333333333
# Test loss: 1.6562928974628448
#
# Epoch 17
# Training loss: 0.07207879665607618
# Number Of Images Tested = 10000
# Model Accuracy = 0.8154
# Number Of Images Tested = 60000
# Model Accuracy = 0.8329
# Test loss: 2.1232695460319517
#
# Epoch 18
# Training loss: 0.08234747824401169
# Number Of Images Tested = 10000
# Model Accuracy = 0.8143
# Number Of Images Tested = 60000
# Model Accuracy = 0.831
# Test loss: 1.5729446172714234
#
# Epoch 19
# Training loss: 0.08506245964790805
# Number Of Images Tested = 10000
# Model Accuracy = 0.8275
# Number Of Images Tested = 60000
# Model Accuracy = 0.8534333333333334
# Test loss: 1.3560207068920136
#
# Epoch 20
# Training loss: 0.08490130793938602
# Number Of Images Tested = 10000
# Model Accuracy = 0.8122
# Number Of Images Tested = 60000
# Model Accuracy = 0.8345666666666667
# Test loss: 2.467121458053589
#
# Epoch 21
# Training loss: 0.09053740069522696
# Number Of Images Tested = 10000
# Model Accuracy = 0.8107
# Number Of Images Tested = 60000
# Model Accuracy = 0.8337
# Test loss: 1.4541866600513458
#
# Epoch 22
# Training loss: 0.10019526254953974
# Number Of Images Tested = 10000
# Model Accuracy = 0.8036
# Number Of Images Tested = 60000
# Model Accuracy = 0.8253333333333334
# Test loss: 1.4913140058517456
#
# Epoch 23
# Training loss: 0.09697854976264476
# Number Of Images Tested = 10000
# Model Accuracy = 0.7929
# Number Of Images Tested = 60000
# Model Accuracy = 0.8082666666666667
# Test loss: 2.745825910568237
#
# Epoch 24
# Training loss: 0.09535464376084886
# Number Of Images Tested = 10000
# Model Accuracy = 0.794
# Number Of Images Tested = 60000
# Model Accuracy = 0.8138333333333333
# Test loss: 2.394143486022949
#
# Epoch 25
# Training loss: 0.0998884282051191
# Number Of Images Tested = 10000
# Model Accuracy = 0.8202
# Number Of Images Tested = 60000
# Model Accuracy = 0.8397
# Test loss: 2.289751559495926
#
# Epoch 26
# Training loss: 0.11438949030460947
# Number Of Images Tested = 10000
# Model Accuracy = 0.8132
# Number Of Images Tested = 60000
# Model Accuracy = 0.8342333333333334
# Test loss: 1.7351740837097167
#
# Epoch 27
# Training loss: 0.10626462105093366
# Number Of Images Tested = 10000
# Model Accuracy = 0.8204
# Number Of Images Tested = 60000
# Model Accuracy = 0.8424833333333334
# Test loss: 1.164262267947197
#
# Epoch 28
# Training loss: 0.10476987082826889
# Number Of Images Tested = 10000
# Model Accuracy = 0.8114
# Number Of Images Tested = 60000
# Model Accuracy = 0.8370666666666666
# Test loss: 1.6043455243110656
#
# Epoch 29
# Training loss: 0.0992894396185875
# Number Of Images Tested = 10000
# Model Accuracy = 0.8088
# Number Of Images Tested = 60000
# Model Accuracy = 0.8312666666666667
# Test loss: 2.850331175327301
#
#
# Training Time (in minutes) = 29.708588925997415
#
#
# Minibatch size:  1024
# History size:  10
# Epoch 0
# Training loss: 0.43836922665773814
# Number Of Images Tested = 10000
# Model Accuracy = 0.83
# Number Of Images Tested = 60000
# Model Accuracy = 0.8448166666666667
# Test loss: 0.48969056010246276
#
# Epoch 1
# Training loss: 0.3452083660384356
# Number Of Images Tested = 10000
# Model Accuracy = 0.8385
# Number Of Images Tested = 60000
# Model Accuracy = 0.8562666666666666
# Test loss: 0.46084327399730685
#
# Epoch 2
# Training loss: 0.30826245147292897
# Number Of Images Tested = 10000
# Model Accuracy = 0.8427
# Number Of Images Tested = 60000
# Model Accuracy = 0.86175
# Test loss: 0.4566975623369217
#
# Epoch 3
# Training loss: 0.2820336288314755
# Number Of Images Tested = 10000
# Model Accuracy = 0.8506
# Number Of Images Tested = 60000
# Model Accuracy = 0.8725666666666667
# Test loss: 0.42441019117832185
#
# Epoch 4
# Training loss: 0.2590049409260184
# Number Of Images Tested = 10000
# Model Accuracy = 0.8512
# Number Of Images Tested = 60000
# Model Accuracy = 0.87215
# Test loss: 0.4317700058221817
#
# Epoch 5
# Training loss: 0.23928738094992558
# Number Of Images Tested = 10000
# Model Accuracy = 0.8486
# Number Of Images Tested = 60000
# Model Accuracy = 0.86975
# Test loss: 0.44805099368095397
#
# Epoch 6
# Training loss: 0.2235951014494492
# Number Of Images Tested = 10000
# Model Accuracy = 0.8553
# Number Of Images Tested = 60000
# Model Accuracy = 0.8804833333333333
# Test loss: 0.4271759182214737
#
# Epoch 7
# Training loss: 0.2095673134771444
# Number Of Images Tested = 10000
# Model Accuracy = 0.8515
# Number Of Images Tested = 60000
# Model Accuracy = 0.8734666666666666
# Test loss: 0.4493884027004242
#
# Epoch 8
# Training loss: 0.1964386252023406
# Number Of Images Tested = 10000
# Model Accuracy = 0.8607
# Number Of Images Tested = 60000
# Model Accuracy = 0.8881666666666667
# Test loss: 0.4175716876983643
#
# Epoch 9
# Training loss: 0.1846551943128392
# Number Of Images Tested = 10000
# Model Accuracy = 0.8554
# Number Of Images Tested = 60000
# Model Accuracy = 0.8847833333333334
# Test loss: 0.4408030241727829
#
# Epoch 10
# Training loss: 0.17042547540139344
# Number Of Images Tested = 10000
# Model Accuracy = 0.8595
# Number Of Images Tested = 60000
# Model Accuracy = 0.8928333333333334
# Test loss: 0.42471928894519806
#
# Epoch 11
# Training loss: 0.16161290442539475
# Number Of Images Tested = 10000
# Model Accuracy = 0.8566
# Number Of Images Tested = 60000
# Model Accuracy = 0.88555
# Test loss: 0.44749782979488373
#
# Epoch 12
# Training loss: 0.15990388544939332
# Number Of Images Tested = 10000
# Model Accuracy = 0.8535
# Number Of Images Tested = 60000
# Model Accuracy = 0.88145
# Test loss: 0.46823306679725646
#
# Epoch 13
# Training loss: 0.1435058989514739
# Number Of Images Tested = 10000
# Model Accuracy = 0.8599
# Number Of Images Tested = 60000
# Model Accuracy = 0.89205
# Test loss: 0.45680713653564453
#
# Epoch 14
# Training loss: 0.13298148194612083
# Number Of Images Tested = 10000
# Model Accuracy = 0.8596
# Number Of Images Tested = 60000
# Model Accuracy = 0.8967
# Test loss: 0.4324101358652115
#
# Epoch 15
# Training loss: 0.1276734033125942
# Number Of Images Tested = 10000
# Model Accuracy = 0.8594
# Number Of Images Tested = 60000
# Model Accuracy = 0.8938166666666667
# Test loss: 0.45461476147174834
#
# Epoch 16
# Training loss: 0.11894387284577904
# Number Of Images Tested = 10000
# Model Accuracy = 0.8585
# Number Of Images Tested = 60000
# Model Accuracy = 0.9
# Test loss: 0.44858976304531095
#
# Epoch 17
# Training loss: 0.11164018802218519
# Number Of Images Tested = 10000
# Model Accuracy = 0.8642
# Number Of Images Tested = 60000
# Model Accuracy = 0.9080333333333334
# Test loss: 0.4374361902475357
#
# Epoch 18
# Training loss: 0.10623469329991583
# Number Of Images Tested = 10000
# Model Accuracy = 0.8654
# Number Of Images Tested = 60000
# Model Accuracy = 0.9054666666666666
# Test loss: 0.47047318518161774
#
# Epoch 19
# Training loss: 0.09722391541226436
# Number Of Images Tested = 10000
# Model Accuracy = 0.8623
# Number Of Images Tested = 60000
# Model Accuracy = 0.9108333333333334
# Test loss: 0.44464061558246615
#
# Epoch 20
# Training loss: 0.09400534554053161
# Number Of Images Tested = 10000
# Model Accuracy = 0.8686
# Number Of Images Tested = 60000
# Model Accuracy = 0.9081
# Test loss: 0.479472616314888
#
# Epoch 21
# Training loss: 0.08721655594595408
# Number Of Images Tested = 10000
# Model Accuracy = 0.8713
# Number Of Images Tested = 60000
# Model Accuracy = 0.9205166666666666
# Test loss: 0.43618278205394745
#
# Epoch 22
# Training loss: 0.08466737925753755
# Number Of Images Tested = 10000
# Model Accuracy = 0.8699
# Number Of Images Tested = 60000
# Model Accuracy = 0.92005
# Test loss: 0.4585444450378418
#
# Epoch 23
# Training loss: 0.08048698135604293
# Number Of Images Tested = 10000
# Model Accuracy = 0.8667
# Number Of Images Tested = 60000
# Model Accuracy = 0.9136
# Test loss: 0.496193653345108
#
# Epoch 24
# Training loss: 0.07661637998485969
# Number Of Images Tested = 10000
# Model Accuracy = 0.8657
# Number Of Images Tested = 60000
# Model Accuracy = 0.9197833333333333
# Test loss: 0.49613827764987944
#
# Epoch 25
# Training loss: 0.07142815978850349
# Number Of Images Tested = 10000
# Model Accuracy = 0.8709
# Number Of Images Tested = 60000
# Model Accuracy = 0.9232166666666667
# Test loss: 0.48465149402618407
#
# Epoch 26
# Training loss: 0.06864117389008151
# Number Of Images Tested = 10000
# Model Accuracy = 0.8611
# Number Of Images Tested = 60000
# Model Accuracy = 0.9095166666666666
# Test loss: 0.5713684767484665
#
# Epoch 27
# Training loss: 0.06629052234150595
# Number Of Images Tested = 10000
# Model Accuracy = 0.8712
# Number Of Images Tested = 60000
# Model Accuracy = 0.9241
# Test loss: 0.5000548273324966
#
# Epoch 28
# Training loss: 0.06386755305831715
# Number Of Images Tested = 10000
# Model Accuracy = 0.8721
# Number Of Images Tested = 60000
# Model Accuracy = 0.9262
# Test loss: 0.5098258584737778
#
# Epoch 29
# Training loss: 0.05778275764847206
# Number Of Images Tested = 10000
# Model Accuracy = 0.8742
# Number Of Images Tested = 60000
# Model Accuracy = 0.9333833333333333
# Test loss: 0.4768593281507492
#
#
# Training Time (in minutes) = 19.765771079063416
#
#
# Minibatch size:  1024
# History size:  20
# Epoch 0
# Training loss: 0.1830859376212298
# Number Of Images Tested = 10000
# Model Accuracy = 0.8126
# Number Of Images Tested = 60000
# Model Accuracy = 0.8364833333333334
# Test loss: 0.5947806894779205
#
# Epoch 1
# Training loss: 0.08273140707258451
# Number Of Images Tested = 10000
# Model Accuracy = 0.839
# Number Of Images Tested = 60000
# Model Accuracy = 0.8593166666666666
# Test loss: 0.6043301582336426
#
# Epoch 2
# Training loss: 0.05181188572008731
# Number Of Images Tested = 10000
# Model Accuracy = 0.8395
# Number Of Images Tested = 60000
# Model Accuracy = 0.8649833333333333
# Test loss: 0.6683595836162567
#
# Epoch 3
# Training loss: 0.038028750805405236
# Number Of Images Tested = 10000
# Model Accuracy = 0.845
# Number Of Images Tested = 60000
# Model Accuracy = 0.8734666666666666
# Test loss: 0.7396208643913269
#
# Epoch 4
# Training loss: 0.03294754486878292
# Number Of Images Tested = 10000
# Model Accuracy = 0.8483
# Number Of Images Tested = 60000
# Model Accuracy = 0.873
# Test loss: 0.7665813207626343
#
# Epoch 5
# Training loss: 0.024089423166114395
# Number Of Images Tested = 10000
# Model Accuracy = 0.8518
# Number Of Images Tested = 60000
# Model Accuracy = 0.8822
# Test loss: 0.763144713640213
#
# Epoch 6
# Training loss: 0.016825312663706304
# Number Of Images Tested = 10000
# Model Accuracy = 0.8486
# Number Of Images Tested = 60000
# Model Accuracy = 0.8767166666666667
# Test loss: 0.8915044605731964
#
# Epoch 7
# Training loss: 0.015561271324690621
# Number Of Images Tested = 10000
# Model Accuracy = 0.8543
# Number Of Images Tested = 60000
# Model Accuracy = 0.8833666666666666
# Test loss: 0.753091013431549
#
# Epoch 8
# Training loss: 0.013180365111142144
# Number Of Images Tested = 10000
# Model Accuracy = 0.8519
# Number Of Images Tested = 60000
# Model Accuracy = 0.8863166666666666
# Test loss: 0.8389636933803558
#
# Epoch 9
# Training loss: 0.010874222186630813
# Number Of Images Tested = 10000
# Model Accuracy = 0.8592
# Number Of Images Tested = 60000
# Model Accuracy = 0.8912
# Test loss: 0.8600662291049957
#
# Epoch 10
# Training loss: 0.011938610682421821
# Number Of Images Tested = 10000
# Model Accuracy = 0.8504
# Number Of Images Tested = 60000
# Model Accuracy = 0.8842666666666666
# Test loss: 0.6534147202968598
#
# Epoch 11
# Training loss: 0.012630426026959667
# Number Of Images Tested = 10000
# Model Accuracy = 0.8616
# Number Of Images Tested = 60000
# Model Accuracy = 0.8935166666666666
# Test loss: 0.8765280961990356
#
# Epoch 12
# Training loss: 0.00818146409277441
# Number Of Images Tested = 10000
# Model Accuracy = 0.8559
# Number Of Images Tested = 60000
# Model Accuracy = 0.8924833333333333
# Test loss: 0.876868623495102
#
# Epoch 13
# Training loss: 0.007321386035705395
# Number Of Images Tested = 10000
# Model Accuracy = 0.8636
# Number Of Images Tested = 60000
# Model Accuracy = 0.8980333333333334
# Test loss: 0.8637871861457824
#
# Epoch 14
# Training loss: 0.006378205384569779
# Number Of Images Tested = 10000
# Model Accuracy = 0.8587
# Number Of Images Tested = 60000
# Model Accuracy = 0.89605
# Test loss: 0.8489216089248657
#
# Epoch 15
# Training loss: 0.007324155664734416
# Number Of Images Tested = 10000
# Model Accuracy = 0.854
# Number Of Images Tested = 60000
# Model Accuracy = 0.8933833333333333
# Test loss: 0.9261402785778046
#
# Epoch 16
# Training loss: 0.005863438616901384
# Number Of Images Tested = 10000
# Model Accuracy = 0.8553
# Number Of Images Tested = 60000
# Model Accuracy = 0.8932166666666667
# Test loss: 0.9221909523010254
#
# Epoch 17
# Training loss: 0.004353709901698818
# Number Of Images Tested = 10000
# Model Accuracy = 0.8604
# Number Of Images Tested = 60000
# Model Accuracy = 0.9016333333333333
# Test loss: 0.9139615178108216
#
# Epoch 18
# Training loss: 0.0061461285853726885
# Number Of Images Tested = 10000
# Model Accuracy = 0.8687
# Number Of Images Tested = 60000
# Model Accuracy = 0.9085833333333333
# Test loss: 0.9098035454750061
#
# Epoch 19
# Training loss: 0.00379390226996709
# Number Of Images Tested = 10000
# Model Accuracy = 0.8601
# Number Of Images Tested = 60000
# Model Accuracy = 0.9034166666666666
# Test loss: 0.830931544303894
#
# Epoch 20
# Training loss: 0.003302960522903003
# Number Of Images Tested = 10000
# Model Accuracy = 0.8689
# Number Of Images Tested = 60000
# Model Accuracy = 0.9151166666666667
# Test loss: 0.9593516886234283
#
# Epoch 21
# Training loss: 0.0027225157887264453
# Number Of Images Tested = 10000
# Model Accuracy = 0.8675
# Number Of Images Tested = 60000
# Model Accuracy = 0.91685
# Test loss: 1.002612966299057
#
# Epoch 22
# Training loss: 0.0029224464946063394
# Number Of Images Tested = 10000
# Model Accuracy = 0.8681
# Number Of Images Tested = 60000
# Model Accuracy = 0.9149833333333334
# Test loss: 0.9742823719978333
#
# Epoch 23
# Training loss: 0.0030317409590510176
# Number Of Images Tested = 10000
# Model Accuracy = 0.867
# Number Of Images Tested = 60000
# Model Accuracy = 0.9185833333333333
# Test loss: 1.0287777602672576
#
# Epoch 24
# Training loss: 0.0020320359923308557
# Number Of Images Tested = 10000
# Model Accuracy = 0.8728
# Number Of Images Tested = 60000
# Model Accuracy = 0.9268
# Test loss: 0.9053403198719024
#
# Epoch 25
# Training loss: 0.002094609966815816
# Number Of Images Tested = 10000
# Model Accuracy = 0.8649
# Number Of Images Tested = 60000
# Model Accuracy = 0.9158833333333334
# Test loss: 1.1512407779693603
#
# Epoch 26
# Training loss: 0.0019523818203705853
# Number Of Images Tested = 10000
# Model Accuracy = 0.8761
# Number Of Images Tested = 60000
# Model Accuracy = 0.92935
# Test loss: 1.0320662260055542
#
# Epoch 27
# Training loss: 0.001638131661604995
# Number Of Images Tested = 10000
# Model Accuracy = 0.8616
# Number Of Images Tested = 60000
# Model Accuracy = 0.9173333333333333
# Test loss: 1.0057556748390197
#
# Epoch 28
# Training loss: 0.0013483132561767411
# Number Of Images Tested = 10000
# Model Accuracy = 0.8769
# Number Of Images Tested = 60000
# Model Accuracy = 0.92945
# Test loss: 1.0562787413597108
#
# Epoch 29
# Training loss: 0.0017092922377849977
# Number Of Images Tested = 10000
# Model Accuracy = 0.8687
# Number Of Images Tested = 60000
# Model Accuracy = 0.9215666666666666
# Test loss: 1.0370300710201263
#
#
# Training Time (in minutes) = 23.553479584058127

# %%
np.savetxt('2/LBFGS_minibatch_fcNN_trainloss.txt', training_loss_fcnn2)
np.savetxt('2/LBFGS_minibatch_fcNN_testloss.txt', test_loss_fcnn)
np.savetxt('2/LBFGS_minibatch_fcNN_trainacc.txt', training_accuracy_fcnn2)
np.savetxt('2/LBFGS_minibatch_fcNN_testacc.txt', test_accuracy_fcnn2)
np.savetxt('2/LBFGS_minibatch_fcNN_times.txt',time_fcnn2)

# %%
i = 0
for bs_index,bs in enumerate(minibatch_size_grid):
    for hs_index,hs in enumerate(history_size_grid):
        plt.figure(1, figsize = (10,8))
        plt.plot(test_loss_fcnn[i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(2, figsize = (10,8))
        plt.plot(training_loss_fcnn2[i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(3, figsize = (10,8))
        plt.plot(test_accuracy_fcnn2[i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(4, figsize = (10,8))
        plt.plot(training_accuracy_fcnn2[i],label='bs = {}, hs = {}'.format(bs,hs))
        i+=1

plt.figure(1)
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Minibatch LBFGS Test loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("2/mini_LBFGS_test_loss_fcnn.jpg")
plt.figure (2)
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
plt.title('Minibatch LBFGS Train loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("2/mini_LBFGS_train_loss_fcnn.jpg")
plt.figure (3)
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.title('Minibatch LBFGS Test accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("2/mini_LBFGS_test_acc_fcnn.jpg")
plt.figure (4)
plt.xlabel('Epochs')
plt.ylabel('Train Accuracy')
plt.title('Minibatch LBFGS Train accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("2/mini_LBFGS_train_acc_fcnn.jpg")

# %%
minibatch_size_grid = [2048,4096]
max_iter = 20
epochs = 30
history_size_grid=[10,20]

# %%
training_loss_fcnn3, test_loss_fcnn3,training_accuracy_fcnn3, test_accuracy_fcnn3, time_fcnn3 = hyperparameters_tuning_LBFGS_minibatch(trainset,valset,minibatch_size_grid, history_size_grid, max_iter,epochs, "FCNN2")
# Out:
# uracy = 0.8509
# Number Of Images Tested = 60000
# Model Accuracy = 0.87825
# Test loss: 0.4329738438129425
#
# Epoch 20
# Training loss: 0.23620370278755823
# Number Of Images Tested = 10000
# Model Accuracy = 0.8513
# Number Of Images Tested = 60000
# Model Accuracy = 0.8791166666666667
# Test loss: 0.41302432417869567
#
# Epoch 21
# Training loss: 0.22894783119360607
# Number Of Images Tested = 10000
# Model Accuracy = 0.862
# Number Of Images Tested = 60000
# Model Accuracy = 0.8886833333333334
# Test loss: 0.4179393768310547
#
# Epoch 22
# Training loss: 0.22486781229575475
# Number Of Images Tested = 10000
# Model Accuracy = 0.8525
# Number Of Images Tested = 60000
# Model Accuracy = 0.8839666666666667
# Test loss: 0.4272325932979584
#
# Epoch 23
# Training loss: 0.22344494511683782
# Number Of Images Tested = 10000
# Model Accuracy = 0.8667
# Number Of Images Tested = 60000
# Model Accuracy = 0.8939
# Test loss: 0.394692063331604
#
# Epoch 24
# Training loss: 0.21862459232409795
# Number Of Images Tested = 10000
# Model Accuracy = 0.8535
# Number Of Images Tested = 60000
# Model Accuracy = 0.8852666666666666
# Test loss: 0.42365352511405946
#
# Epoch 25
# Training loss: 0.21260809302330017
# Number Of Images Tested = 10000
# Model Accuracy = 0.8552
# Number Of Images Tested = 60000
# Model Accuracy = 0.8805333333333333
# Test loss: 0.43648014664649964
#
# Epoch 26
# Training loss: 0.2111088181535403
# Number Of Images Tested = 10000
# Model Accuracy = 0.8675
# Number Of Images Tested = 60000
# Model Accuracy = 0.9012333333333333
# Test loss: 0.38252655863761903
#
# Epoch 27
# Training loss: 0.20699407706658046
# Number Of Images Tested = 10000
# Model Accuracy = 0.8606
# Number Of Images Tested = 60000
# Model Accuracy = 0.8912333333333333
# Test loss: 0.42223438024520876
#
# Epoch 28
# Training loss: 0.2045550728837649
# Number Of Images Tested = 10000
# Model Accuracy = 0.8539
# Number Of Images Tested = 60000
# Model Accuracy = 0.8879333333333334
# Test loss: 0.42523998618125913
#
# Epoch 29
# Training loss: 0.20213215003410975
# Number Of Images Tested = 10000
# Model Accuracy = 0.8586
# Number Of Images Tested = 60000
# Model Accuracy = 0.8873166666666666
# Test loss: 0.42225784063339233
#
#
# Training Time (in minutes) = 17.986878697077433
#
#
# Minibatch size:  2048
# History size:  20
# Epoch 0
# Training loss: 0.2793554705878099
# Number Of Images Tested = 10000
# Model Accuracy = 0.8291
# Number Of Images Tested = 60000
# Model Accuracy = 0.84515
# Test loss: 0.643135404586792
#
# Epoch 1
# Training loss: 0.14552420352896053
# Number Of Images Tested = 10000
# Model Accuracy = 0.832
# Number Of Images Tested = 60000
# Model Accuracy = 0.84975
# Test loss: 0.7619887471199036
#
# Epoch 2
# Training loss: 0.1147661859790484
# Number Of Images Tested = 10000
# Model Accuracy = 0.8405
# Number Of Images Tested = 60000
# Model Accuracy = 0.8655166666666667
# Test loss: 0.5847553491592408
#
# Epoch 3
# Training loss: 0.08979036541034778
# Number Of Images Tested = 10000
# Model Accuracy = 0.8439
# Number Of Images Tested = 60000
# Model Accuracy = 0.8757666666666667
# Test loss: 0.6234032511711121
#
# Epoch 4
# Training loss: 0.07544718040153384
# Number Of Images Tested = 10000
# Model Accuracy = 0.8519
# Number Of Images Tested = 60000
# Model Accuracy = 0.8777333333333334
# Test loss: 0.6722359299659729
#
# Epoch 5
# Training loss: 0.06304557393305003
# Number Of Images Tested = 10000
# Model Accuracy = 0.8554
# Number Of Images Tested = 60000
# Model Accuracy = 0.8848666666666667
# Test loss: 0.6610820651054382
#
# Epoch 6
# Training loss: 0.05615772067879637
# Number Of Images Tested = 10000
# Model Accuracy = 0.8576
# Number Of Images Tested = 60000
# Model Accuracy = 0.89125
# Test loss: 0.6091299891471863
#
# Epoch 7
# Training loss: 0.04918391470176478
# Number Of Images Tested = 10000
# Model Accuracy = 0.8539
# Number Of Images Tested = 60000
# Model Accuracy = 0.888
# Test loss: 0.7380890846252441
#
# Epoch 8
# Training loss: 0.037902971170842646
# Number Of Images Tested = 10000
# Model Accuracy = 0.8552
# Number Of Images Tested = 60000
# Model Accuracy = 0.89415
# Test loss: 0.6365518212318421
#
# Epoch 9
# Training loss: 0.03377994314456979
# Number Of Images Tested = 10000
# Model Accuracy = 0.8633
# Number Of Images Tested = 60000
# Model Accuracy = 0.90215
# Test loss: 0.6624021768569947
#
# Epoch 10
# Training loss: 0.03058984042145312
# Number Of Images Tested = 10000
# Model Accuracy = 0.8549
# Number Of Images Tested = 60000
# Model Accuracy = 0.8936833333333334
# Test loss: 0.7462126970291137
#
# Epoch 11
# Training loss: 0.025784809088024
# Number Of Images Tested = 10000
# Model Accuracy = 0.8611
# Number Of Images Tested = 60000
# Model Accuracy = 0.902
# Test loss: 0.7756816864013671
#
# Epoch 12
# Training loss: 0.023482176071653763
# Number Of Images Tested = 10000
# Model Accuracy = 0.8657
# Number Of Images Tested = 60000
# Model Accuracy = 0.90675
# Test loss: 0.7407484650611877
#
# Epoch 13
# Training loss: 0.019816395310529818
# Number Of Images Tested = 10000
# Model Accuracy = 0.8619
# Number Of Images Tested = 60000
# Model Accuracy = 0.9083
# Test loss: 0.7686004638671875
#
# Epoch 14
# Training loss: 0.019097746054952344
# Number Of Images Tested = 10000
# Model Accuracy = 0.8697
# Number Of Images Tested = 60000
# Model Accuracy = 0.9176166666666666
# Test loss: 0.723626971244812
#
# Epoch 15
# Training loss: 0.01600947033924361
# Number Of Images Tested = 10000
# Model Accuracy = 0.8651
# Number Of Images Tested = 60000
# Model Accuracy = 0.9192
# Test loss: 0.7392491579055787
#
# Epoch 16
# Training loss: 0.013629601375820736
# Number Of Images Tested = 10000
# Model Accuracy = 0.8622
# Number Of Images Tested = 60000
# Model Accuracy = 0.9225
# Test loss: 0.7397127509117126
#
# Epoch 17
# Training loss: 0.012405278409520786
# Number Of Images Tested = 10000
# Model Accuracy = 0.8628
# Number Of Images Tested = 60000
# Model Accuracy = 0.9188666666666667
# Test loss: 0.7904921054840088
#
# Epoch 18
# Training loss: 0.013023697018312911
# Number Of Images Tested = 10000
# Model Accuracy = 0.8647
# Number Of Images Tested = 60000
# Model Accuracy = 0.91995
# Test loss: 0.8148333549499511
#
# Epoch 19
# Training loss: 0.010233398346463219
# Number Of Images Tested = 10000
# Model Accuracy = 0.8687
# Number Of Images Tested = 60000
# Model Accuracy = 0.9228166666666666
# Test loss: 0.827748692035675
#
# Epoch 20
# Training loss: 0.012453408578100305
# Number Of Images Tested = 10000
# Model Accuracy = 0.8623
# Number Of Images Tested = 60000
# Model Accuracy = 0.9185666666666666
# Test loss: 0.9014987468719482
#
# Epoch 21
# Training loss: 0.010081366742573058
# Number Of Images Tested = 10000
# Model Accuracy = 0.8702
# Number Of Images Tested = 60000
# Model Accuracy = 0.9351833333333334
# Test loss: 0.7787057518959045
#
# Epoch 22
# Training loss: 0.008378224241702507
# Number Of Images Tested = 10000
# Model Accuracy = 0.8711
# Number Of Images Tested = 60000
# Model Accuracy = 0.92795
# Test loss: 0.8703019499778748
#
# Epoch 23
# Training loss: 0.007368786122727519
# Number Of Images Tested = 10000
# Model Accuracy = 0.8684
# Number Of Images Tested = 60000
# Model Accuracy = 0.9288
# Test loss: 0.9115331530570984
#
# Epoch 24
# Training loss: 0.006677116918338773
# Number Of Images Tested = 10000
# Model Accuracy = 0.8684
# Number Of Images Tested = 60000
# Model Accuracy = 0.93075
# Test loss: 0.8992212653160095
#
# Epoch 25
# Training loss: 0.006549528312946981
# Number Of Images Tested = 10000
# Model Accuracy = 0.872
# Number Of Images Tested = 60000
# Model Accuracy = 0.9383
# Test loss: 0.8380197525024414
#
# Epoch 26
# Training loss: 0.005739739847679933
# Number Of Images Tested = 10000
# Model Accuracy = 0.8704
# Number Of Images Tested = 60000
# Model Accuracy = 0.9371333333333334
# Test loss: 0.8743519306182861
#
# Epoch 27
# Training loss: 0.005689658273089056
# Number Of Images Tested = 10000
# Model Accuracy = 0.8713
# Number Of Images Tested = 60000
# Model Accuracy = 0.9374166666666667
# Test loss: 0.8950197577476502
#
# Epoch 28
# Training loss: 0.005430778124718927
# Number Of Images Tested = 10000
# Model Accuracy = 0.8705
# Number Of Images Tested = 60000
# Model Accuracy = 0.9398833333333333
# Test loss: 0.8811475515365601
#
# Epoch 29
# Training loss: 0.0054196733869806245
# Number Of Images Tested = 10000
# Model Accuracy = 0.8693
# Number Of Images Tested = 60000
# Model Accuracy = 0.9354333333333333
# Test loss: 0.949510109424591
#
#
# Training Time (in minutes) = 19.577799757321674
#
#
# Minibatch size:  4096
# History size:  10
# Epoch 0
# Training loss: 0.5473063627878825
# Number Of Images Tested = 10000
# Model Accuracy = 0.8337
# Number Of Images Tested = 60000
# Model Accuracy = 0.8466333333333333
# Test loss: 0.4707806706428528
#
# Epoch 1
# Training loss: 0.386471559604009
# Number Of Images Tested = 10000
# Model Accuracy = 0.8451
# Number Of Images Tested = 60000
# Model Accuracy = 0.8629333333333333
# Test loss: 0.432025671005249
#
# Epoch 2
# Training loss: 0.36716187198956807
# Number Of Images Tested = 10000
# Model Accuracy = 0.8515
# Number Of Images Tested = 60000
# Model Accuracy = 0.8649166666666667
# Test loss: 0.42266801993052167
#
# Epoch 3
# Training loss: 0.3592918256918589
# Number Of Images Tested = 10000
# Model Accuracy = 0.8518
# Number Of Images Tested = 60000
# Model Accuracy = 0.8669333333333333
# Test loss: 0.4206712245941162
#
# Epoch 4
# Training loss: 0.3545108258724213
# Number Of Images Tested = 10000
# Model Accuracy = 0.8527
# Number Of Images Tested = 60000
# Model Accuracy = 0.8712166666666666
# Test loss: 0.40962130824724835
#
# Epoch 5
# Training loss: 0.3466017623742422
# Number Of Images Tested = 10000
# Model Accuracy = 0.8527
# Number Of Images Tested = 60000
# Model Accuracy = 0.87005
# Test loss: 0.4193927049636841
#
# Epoch 6
# Training loss: 0.3417549749215444
# Number Of Images Tested = 10000
# Model Accuracy = 0.8554
# Number Of Images Tested = 60000
# Model Accuracy = 0.8724166666666666
# Test loss: 0.4075472553571065
#
# Epoch 7
# Training loss: 0.3369026045004527
# Number Of Images Tested = 10000
# Model Accuracy = 0.8538
# Number Of Images Tested = 60000
# Model Accuracy = 0.872
# Test loss: 0.4026421308517456
#
# Epoch 8
# Training loss: 0.33210676511128745
# Number Of Images Tested = 10000
# Model Accuracy = 0.8588
# Number Of Images Tested = 60000
# Model Accuracy = 0.87425
# Test loss: 0.40442458788553876
#
# Epoch 9
# Training loss: 0.3278671344121297
# Number Of Images Tested = 10000
# Model Accuracy = 0.857
# Number Of Images Tested = 60000
# Model Accuracy = 0.87505
# Test loss: 0.39810672402381897
#
# Epoch 10
# Training loss: 0.3248369038105011
# Number Of Images Tested = 10000
# Model Accuracy = 0.8608
# Number Of Images Tested = 60000
# Model Accuracy = 0.8778833333333333
# Test loss: 0.3959606885910034
#
# Epoch 11
# Training loss: 0.32002463142077126
# Number Of Images Tested = 10000
# Model Accuracy = 0.8562
# Number Of Images Tested = 60000
# Model Accuracy = 0.8741333333333333
# Test loss: 0.40629151463508606
#
# Epoch 12
# Training loss: 0.31538389921188353
# Number Of Images Tested = 10000
# Model Accuracy = 0.8606
# Number Of Images Tested = 60000
# Model Accuracy = 0.8791166666666667
# Test loss: 0.3918646077315013
#
# Epoch 13
# Training loss: 0.3134825944900513
# Number Of Images Tested = 10000
# Model Accuracy = 0.8603
# Number Of Images Tested = 60000
# Model Accuracy = 0.8793166666666666
# Test loss: 0.3899526695410411
#
# Epoch 14
# Training loss: 0.3097070137659709
# Number Of Images Tested = 10000
# Model Accuracy = 0.8647
# Number Of Images Tested = 60000
# Model Accuracy = 0.88325
# Test loss: 0.38318220774332684
#
# Epoch 15
# Training loss: 0.3070599059263865
# Number Of Images Tested = 10000
# Model Accuracy = 0.8636
# Number Of Images Tested = 60000
# Model Accuracy = 0.88325
# Test loss: 0.38283546765645343
#
# Epoch 16
# Training loss: 0.3032066305478414
# Number Of Images Tested = 10000
# Model Accuracy = 0.8642
# Number Of Images Tested = 60000
# Model Accuracy = 0.8838333333333334
# Test loss: 0.39117992917696637
#
# Epoch 17
# Training loss: 0.30185057123502096
# Number Of Images Tested = 10000
# Model Accuracy = 0.8643
# Number Of Images Tested = 60000
# Model Accuracy = 0.8849166666666667
# Test loss: 0.3838505645593007
#
# Epoch 18
# Training loss: 0.29800604383150736
# Number Of Images Tested = 10000
# Model Accuracy = 0.8638
# Number Of Images Tested = 60000
# Model Accuracy = 0.8842833333333333
# Test loss: 0.38480642437934875
#
# Epoch 19
# Training loss: 0.294719531138738
# Number Of Images Tested = 10000
# Model Accuracy = 0.8645
# Number Of Images Tested = 60000
# Model Accuracy = 0.8845333333333333
# Test loss: 0.38191087047259015
#
# Epoch 20
# Training loss: 0.29229696790377296
# Number Of Images Tested = 10000
# Model Accuracy = 0.8622
# Number Of Images Tested = 60000
# Model Accuracy = 0.88715
# Test loss: 0.3798082172870636
#
# Epoch 21
# Training loss: 0.2885615468025208
# Number Of Images Tested = 10000
# Model Accuracy = 0.8678
# Number Of Images Tested = 60000
# Model Accuracy = 0.8894166666666666
# Test loss: 0.38108696540196735
#
# Epoch 22
# Training loss: 0.2872379819552104
# Number Of Images Tested = 10000
# Model Accuracy = 0.868
# Number Of Images Tested = 60000
# Model Accuracy = 0.8921166666666667
# Test loss: 0.38117684920628864
#
# Epoch 23
# Training loss: 0.28326245546340945
# Number Of Images Tested = 10000
# Model Accuracy = 0.8677
# Number Of Images Tested = 60000
# Model Accuracy = 0.8916833333333334
# Test loss: 0.37293219566345215
#
# Epoch 24
# Training loss: 0.2812941650549571
# Number Of Images Tested = 10000
# Model Accuracy = 0.8689
# Number Of Images Tested = 60000
# Model Accuracy = 0.8943333333333333
# Test loss: 0.37019715706507367
#
# Epoch 25
# Training loss: 0.2781227032343547
# Number Of Images Tested = 10000
# Model Accuracy = 0.8687
# Number Of Images Tested = 60000
# Model Accuracy = 0.8920666666666667
# Test loss: 0.37148745854695636
#
# Epoch 26
# Training loss: 0.2749205609162649
# Number Of Images Tested = 10000
# Model Accuracy = 0.8693
# Number Of Images Tested = 60000
# Model Accuracy = 0.8936833333333334
# Test loss: 0.3698713382085164
#
# Epoch 27
# Training loss: 0.27518758972485863
# Number Of Images Tested = 10000
# Model Accuracy = 0.8711
# Number Of Images Tested = 60000
# Model Accuracy = 0.8961333333333333
# Test loss: 0.3643260896205902
#
# Epoch 28
# Training loss: 0.2705142438411713
# Number Of Images Tested = 10000
# Model Accuracy = 0.8656
# Number Of Images Tested = 60000
# Model Accuracy = 0.89215
# Test loss: 0.37639373540878296
#
# Epoch 29
# Training loss: 0.26795900662740074
# Number Of Images Tested = 10000
# Model Accuracy = 0.8699
# Number Of Images Tested = 60000
# Model Accuracy = 0.8946666666666667
# Test loss: 0.3676568269729614
#
#
# Training Time (in minutes) = 16.423934853076936
#
#
# Minibatch size:  4096
# History size:  20
# Epoch 0
# Training loss: 0.40031559467315675
# Number Of Images Tested = 10000
# Model Accuracy = 0.8476
# Number Of Images Tested = 60000
# Model Accuracy = 0.8677
# Test loss: 0.4322970112164815
#
# Epoch 1
# Training loss: 0.25371707578500113
# Number Of Images Tested = 10000
# Model Accuracy = 0.8571
# Number Of Images Tested = 60000
# Model Accuracy = 0.8782
# Test loss: 0.41865678628285724
#
# Epoch 2
# Training loss: 0.22081016699473063
# Number Of Images Tested = 10000
# Model Accuracy = 0.8622
# Number Of Images Tested = 60000
# Model Accuracy = 0.8845333333333333
# Test loss: 0.40616415937741596
#
# Epoch 3
# Training loss: 0.2021946966648102
# Number Of Images Tested = 10000
# Model Accuracy = 0.8637
# Number Of Images Tested = 60000
# Model Accuracy = 0.8880666666666667
# Test loss: 0.41078658898671466
#
# Epoch 4
# Training loss: 0.18864191075166067
# Number Of Images Tested = 10000
# Model Accuracy = 0.8661
# Number Of Images Tested = 60000
# Model Accuracy = 0.8914
# Test loss: 0.4173964858055115
#
# Epoch 5
# Training loss: 0.17506887515385947
# Number Of Images Tested = 10000
# Model Accuracy = 0.8553
# Number Of Images Tested = 60000
# Model Accuracy = 0.8814833333333333
# Test loss: 0.46979183952013653
#
# Epoch 6
# Training loss: 0.16239884495735168
# Number Of Images Tested = 10000
# Model Accuracy = 0.8603
# Number Of Images Tested = 60000
# Model Accuracy = 0.8918333333333334
# Test loss: 0.41466978192329407
#
# Epoch 7
# Training loss: 0.15649482011795043
# Number Of Images Tested = 10000
# Model Accuracy = 0.8654
# Number Of Images Tested = 60000
# Model Accuracy = 0.8966833333333334
# Test loss: 0.42119229833285016
#
# Epoch 8
# Training loss: 0.14686544885238012
# Number Of Images Tested = 10000
# Model Accuracy = 0.8616
# Number Of Images Tested = 60000
# Model Accuracy = 0.8985
# Test loss: 0.43959754705429077
#
# Epoch 9
# Training loss: 0.13930289298295975
# Number Of Images Tested = 10000
# Model Accuracy = 0.8653
# Number Of Images Tested = 60000
# Model Accuracy = 0.9024666666666666
# Test loss: 0.43584543466567993
#
# Epoch 10
# Training loss: 0.12713459630807242
# Number Of Images Tested = 10000
# Model Accuracy = 0.872
# Number Of Images Tested = 60000
# Model Accuracy = 0.9089333333333334
# Test loss: 0.4162853757540385
#
# Epoch 11
# Training loss: 0.1230272596081098
# Number Of Images Tested = 10000
# Model Accuracy = 0.8729
# Number Of Images Tested = 60000
# Model Accuracy = 0.9107333333333333
# Test loss: 0.41739073395729065
#
# Epoch 12
# Training loss: 0.114076300462087
# Number Of Images Tested = 10000
# Model Accuracy = 0.8635
# Number Of Images Tested = 60000
# Model Accuracy = 0.9088
# Test loss: 0.43674994508425397
#
# Epoch 13
# Training loss: 0.11208715091149012
# Number Of Images Tested = 10000
# Model Accuracy = 0.8682
# Number Of Images Tested = 60000
# Model Accuracy = 0.9146333333333333
# Test loss: 0.4344437023003896
#
# Epoch 14
# Training loss: 0.10626442084709803
# Number Of Images Tested = 10000
# Model Accuracy = 0.867
# Number Of Images Tested = 60000
# Model Accuracy = 0.9109
# Test loss: 0.44803541898727417
#
# Epoch 15
# Training loss: 0.1003159244855245
# Number Of Images Tested = 10000
# Model Accuracy = 0.8668
# Number Of Images Tested = 60000
# Model Accuracy = 0.9117333333333333
# Test loss: 0.44803176323572796
#
# Epoch 16
# Training loss: 0.09597272972265879
# Number Of Images Tested = 10000
# Model Accuracy = 0.866
# Number Of Images Tested = 60000
# Model Accuracy = 0.9114666666666666
# Test loss: 0.45694034298261005
#
# Epoch 17
# Training loss: 0.09234741230805715
# Number Of Images Tested = 10000
# Model Accuracy = 0.8698
# Number Of Images Tested = 60000
# Model Accuracy = 0.9222666666666667
# Test loss: 0.4360438585281372
#
# Epoch 18
# Training loss: 0.08468751658995946
# Number Of Images Tested = 10000
# Model Accuracy = 0.871
# Number Of Images Tested = 60000
# Model Accuracy = 0.9210166666666667
# Test loss: 0.4400338629881541
#
# Epoch 19
# Training loss: 0.08952535291512807
# Number Of Images Tested = 10000
# Model Accuracy = 0.8743
# Number Of Images Tested = 60000
# Model Accuracy = 0.9226
# Test loss: 0.46198874711990356
#
# Epoch 20
# Training loss: 0.07977880711356798
# Number Of Images Tested = 10000
# Model Accuracy = 0.8705
# Number Of Images Tested = 60000
# Model Accuracy = 0.92445
# Test loss: 0.47310657302538556
#
# Epoch 21
# Training loss: 0.07749830856919289
# Number Of Images Tested = 10000
# Model Accuracy = 0.8711
# Number Of Images Tested = 60000
# Model Accuracy = 0.9230333333333334
# Test loss: 0.4797002176443736
#
# Epoch 22
# Training loss: 0.0730340247352918
# Number Of Images Tested = 10000
# Model Accuracy = 0.8737
# Number Of Images Tested = 60000
# Model Accuracy = 0.9266833333333333
# Test loss: 0.47437263528505963
#
# Epoch 23
# Training loss: 0.07160883049170176
# Number Of Images Tested = 10000
# Model Accuracy = 0.8745
# Number Of Images Tested = 60000
# Model Accuracy = 0.9285666666666667
# Test loss: 0.47347832719484967
#
# Epoch 24
# Training loss: 0.06675006449222565
# Number Of Images Tested = 10000
# Model Accuracy = 0.872
# Number Of Images Tested = 60000
# Model Accuracy = 0.9317333333333333
# Test loss: 0.4659656286239624
#
# Epoch 25
# Training loss: 0.06812471027175586
# Number Of Images Tested = 10000
# Model Accuracy = 0.8671
# Number Of Images Tested = 60000
# Model Accuracy = 0.9288
# Test loss: 0.4921610454718272
#
# Epoch 26
# Training loss: 0.05976160317659378
# Number Of Images Tested = 10000
# Model Accuracy = 0.87
# Number Of Images Tested = 60000
# Model Accuracy = 0.9273166666666667
# Test loss: 0.503665546576182
#
# Epoch 27
# Training loss: 0.05868017636239529
# Number Of Images Tested = 10000
# Model Accuracy = 0.8743
# Number Of Images Tested = 60000
# Model Accuracy = 0.9340666666666667
# Test loss: 0.5171971420447031
#
# Epoch 28
# Training loss: 0.05780891478061676
# Number Of Images Tested = 10000
# Model Accuracy = 0.8776
# Number Of Images Tested = 60000
# Model Accuracy = 0.93685
# Test loss: 0.49662869175275165
#
# Epoch 29
# Training loss: 0.05550967901945114
# Number Of Images Tested = 10000
# Model Accuracy = 0.8778
# Number Of Images Tested = 60000
# Model Accuracy = 0.9391166666666667
# Test loss: 0.47394734621047974
#
#
# Training Time (in minutes) = 17.75554143190384

# %%
np.savetxt('3/LBFGS_minibatch_fcNN_trainloss.txt', training_loss_fcnn3)
np.savetxt('3/LBFGS_minibatch_fcNN_testloss.txt', test_loss_fcnn3)
np.savetxt('3/LBFGS_minibatch_fcNN_trainacc.txt', training_accuracy_fcnn3)
np.savetxt('3/LBFGS_minibatch_fcNN_testacc.txt', test_accuracy_fcnn3)
np.savetxt('3/LBFGS_minibatch_fcNN_times.txt',time_fcnn3)

# %%
i = 0
for bs_index,bs in enumerate(minibatch_size_grid):
    for hs_index,hs in enumerate(history_size_grid):
        plt.figure(1, figsize = (10,8))
        plt.plot(test_loss_fcnn3[i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(2, figsize = (10,8))
        plt.plot(training_loss_fcnn3[i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(3, figsize = (10,8))
        plt.plot(test_accuracy_fcnn3[i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(4, figsize = (10,8))
        plt.plot(training_accuracy_fcnn3[i],label='bs = {}, hs = {}'.format(bs,hs))
        i+=1

plt.figure(1)
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Minibatch LBFGS Test loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("3/mini_LBFGS_test_loss_fcnn.jpg")
plt.figure (2)
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
plt.title('Minibatch LBFGS Train loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("3/mini_LBFGS_train_loss_fcnn.jpg")
plt.figure (3)
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.title('Minibatch LBFGS Test accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("3/mini_LBFGS_test_acc_fcnn.jpg")
plt.figure (4)
plt.xlabel('Epochs')
plt.ylabel('Train Accuracy')
plt.title('Minibatch LBFGS Train accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("3/mini_LBFGS_train_acc_fcnn.jpg")
