# %%
# %matplotlib inline

import numpy as np
import torch
import matplotlib.pyplot as plt

#from helper2 import generate_dataset, visualize_one_dataset, visualize_datasets, predict_grid, visualize_predictions
from torch.utils import data

# %load_ext autoreload
# %autoreload 2

import torchvision

from time import time
from torchvision import datasets, transforms
from torch import nn, optim

from helpers_nn import *
from sdlbfgs import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])

# %% [markdown]
# ### MNIST dataset
# The MNIST dataset is loaded.

# %%
trainset = datasets.MNIST('', download=True, train=True, transform=transform)
valset = datasets.MNIST('PATH_TO_STORE_TESTSET', download=True, train=False, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=64, shuffle=True)

# %%
print("Training and test sets information is displayed.\n\n")
print("Trainset:\n",trainset)
print("Testset:\n",valset)
# Out:
# Training and test sets information is displayed.
#
#
# Trainset:
#  Dataset MNIST
#     Number of datapoints: 60000
#     Root location:
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5,), std=(0.5,))
#            )
# Testset:
#  Dataset MNIST
#     Number of datapoints: 10000
#     Root location: PATH_TO_STORE_TESTSET
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5,), std=(0.5,))
#            )

# %%
print(valloader)
len(valloader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x000001ED6EAEDCC0>
# 157

# %% [markdown]
# 64 images in each batch and each image has a dimension of 28 x 28 pixels

# %%
# A subset of a batch is plotted to show a sample of the dataset. 
dataiter = iter(trainloader)
images, labels = dataiter.next()
figure = plt.figure()
num_of_images = 60
for index in range(1, num_of_images + 1):
    plt.subplot(6, 10, index)
    plt.axis('off')
    plt.imshow(images[index].numpy().squeeze(), cmap='gray_r')

# %% [markdown]
# # Neural Network

# %% [markdown]
# ### Model definition
# The model is defined, specifying the structure of the neural network.

# %% [markdown]
# ### Model A: FCNN
# Fully connected neural network, with hidden layer structure through vector *hidden_sizes*.

# %%
# Input and output sizes and network structure are defined.
input_size = 784
output_size = 10
sizes = [input_size,128,64,output_size]

# The model is built
modelA=fully_connected_NN(sizes)
print(modelA)

# Loss of the model is defined.
criterion = nn.NLLLoss()
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=10, bias=True)
#   (5): LogSoftmax()
# )

# %% [markdown]
# ### Model B: CNN
# Convolutional neural network composed of two convolutional layers and two fully connected layers.

# %%
# The size of the images is computed.
images,_=dataiter.next()
image_size=images[0].shape[1]
# Using nn.CrossEntropyLoss allows to avoid specifying LogSoftmax as final layer.
criterion = nn.CrossEntropyLoss()
# Depending on the size of the image, a CNN model is built.
modelB=ConvNet(image_size)
print(modelB)
# Out:
# ConvNet(
#   (layer1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (drop_out): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=3136, out_features=1000, bias=True)
#   (fc2): Linear(in_features=1000, out_features=10, bias=True)
# )

# %% [markdown]
# ### Training

# %% [markdown]
# ModelA is trained with SGD, used as baseline.

# %%
lr=0.003
momentum=0.9
optimizer = optim.SGD(modelA.parameters(), lr=0.003, momentum=0.9)
time0 = time()
epochs = 9

train_losses, test_losses, accuracies = optimize(optimizer, epochs, trainloader,valloader, modelA, criterion)
# Out:
# Epoch 0
# Training loss: 0.6280803931579153
# Number Of Images Tested = 10000
# Model Accuracy = 0.8968
# Test loss: 0.33774925996163846
#
# Epoch 1
# Training loss: 0.276253281228705
# Number Of Images Tested = 10000
# Model Accuracy = 0.9305
# Test loss: 0.23433822597477846
#
# Epoch 2
# Training loss: 0.2152593854044292
# Number Of Images Tested = 10000
# Model Accuracy = 0.9424
# Test loss: 0.1902027435980405
#
# Epoch 3
# Training loss: 0.17093356284521408
# Number Of Images Tested = 10000
# Model Accuracy = 0.9472
# Test loss: 0.16905593112775474
#
# Epoch 4
# Training loss: 0.14305553972713156
# Number Of Images Tested = 10000
# Model Accuracy = 0.9583
# Test loss: 0.13778456640993333
#
# Epoch 5
# Training loss: 0.12207712474932421
# Number Of Images Tested = 10000
# Model Accuracy = 0.9625
# Test loss: 0.12513537066662386
#
# Epoch 6
# Training loss: 0.10607272868296866
# Number Of Images Tested = 10000
# Model Accuracy = 0.9651
# Test loss: 0.11423845800339796
#
# Epoch 7
# Training loss: 0.09362705853650533
# Number Of Images Tested = 10000
# Model Accuracy = 0.9654
# Test loss: 0.10925400226857442
#
# Epoch 8
# Training loss: 0.08439358236736802
# Number Of Images Tested = 10000
# Model Accuracy = 0.9674
# Test loss: 0.10304249804111043
#
#
# Training Time (in minutes) = 2.4852619330088297

# %% [markdown]
# ModelB is trained with SGD, used as baseline.

# %%
lr=0.003
momentum=0.9
optimizer = optim.SGD(modelB.parameters(), lr=0.003, momentum=0.9)
time0 = time()
epochs = 9

train_losses, test_losses, accuracies = optimize_CNN(optimizer, epochs, trainloader,valloader, modelB, criterion)
# Out:
# Epoch 0
# Training loss: 0.35904344354968654
# Number Of Images Tested = 10000
# Model Accuracy = 0.9756
# Test loss: 0.08433993537406063
#
# Epoch 1
# Training loss: 0.07557747548054863
# Number Of Images Tested = 10000
# Model Accuracy = 0.9847
# Test loss: 0.049247576297515895
#
# Epoch 2
# Training loss: 0.05395757732888076
# Number Of Images Tested = 10000
# Model Accuracy = 0.9879
# Test loss: 0.03757618771640548
#
# Epoch 3
# Training loss: 0.04492432910907787
# Number Of Images Tested = 10000
# Model Accuracy = 0.9879
# Test loss: 0.03467085597455312
#
# Epoch 4
# Training loss: 0.038135342740032795
# Number Of Images Tested = 10000
# Model Accuracy = 0.9892
# Test loss: 0.0331583095664028
#
# Epoch 5
# Training loss: 0.03259685160063489
# Number Of Images Tested = 10000
# Model Accuracy = 0.9886
# Test loss: 0.0326143630856654
#
# Epoch 6
# Training loss: 0.029259411990940412
# Number Of Images Tested = 10000
# Model Accuracy = 0.9878
# Test loss: 0.032590359255113895
#
# Epoch 7
# Training loss: 0.025776245212374774
# Number Of Images Tested = 10000
# Model Accuracy = 0.989
# Test loss: 0.030550982061236694
#
# Epoch 8
# Training loss: 0.022979501097532325
# Number Of Images Tested = 10000
# Model Accuracy = 0.9906
# Test loss: 0.0269899987571155
#
#
# Training Time (in minutes) = 32.22838770151138

# %%
plt.plot(test_losses,label='Test loss')
plt.plot(train_losses,label='Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and test loss as function of the training epochs')
plt.legend()

# %%
# This cell gives insight into how the prediction process works.
images, labels = next(iter(valloader))
img = images[0].view(1, 784)
with torch.no_grad():
    logps = model(img)
ps = torch.exp(logps)
probab = list(ps.numpy()[0])
print("Probabilities computed for each digit =\n",probab)
print("\nPredicted Digit =", probab.index(max(probab)))
print("Actual Digit =",labels[0].numpy())
#view_classify(img.view(1, 28, 28), ps)
# Out:
# Probabilities computed for each digit =
#  [4.632957e-06, 5.140131e-05, 1.9065958e-05, 0.9926165, 0.0036483733, 0.00041103543, 1.1146047e-05, 0.0031636038, 1.10238325e-05, 6.3191e-05]
#
# Predicted Digit = 3
# Actual Digit = 3

# %%
probabilities, predicctions = predict_one_img(valloader,model)
# Out:
# Probabilities computed for each digit =
#  [3.0963787e-16, 1.6100303e-16, 1.0272674e-13, 2.8647522e-09, 2.0396508e-14, 2.2982263e-12, 8.063883e-14, 4.531942e-22, 1.0, 1.0583134e-12]
#
# Predicted Digit = 8
# Actual Digit = 8

# %% [markdown]
# ### Test
# The trained model is used to predict the labels of the test set, and the model performance is evaluated.

# %%
# Accuracy obtained for FCNN
accuracy = accuracy_test(valloader, model)
# Out:
# Number Of Images Tested = 10000
#
# Model Accuracy = 0.9803

# %%
# Accuracy obtained for CNN
accuracy=accuracy_test_CNN(valloader,modelB)
# Out:
# Number Of Images Tested = 10000
# Model Accuracy = 0.9903

# %% [markdown]
# ### Hyperparameter optimization

# %%
epochs = 3
blr = best_learning_rate(input_size, output_size, trainloader, valloader)

# %% [markdown]
# ## LBFGS

# %%
def LBFGS_optimizer(parameter):
    lr=0.8
    max_iter=4
    max_eval=None
    tolerance_grad=1e-5
    tolerance_change=1e-9
    history_size=10
    line_search_fn='strong_wolfe'
    return torch.optim.LBFGS(parameter, lr, max_iter, max_eval, tolerance_grad, tolerance_change, history_size, line_search_fn)

# %%
input_size = 784
output_size = 10
sizes = [input_size,128,64,output_size]

# The model is built
modelA=fully_connected_NN(sizes)
# Loss of the model is defined.
criterion = nn.NLLLoss()

method = "LBFGS"
optimizer = LBFGS_optimizer(modelA.parameters())
time0 = time()
epochs = 20

train_losses, test_losses,  accuracies = optimize(optimizer, epochs, trainloader,valloader, modelA, criterion, method)
# Out:
# Epoch 0
# Training loss: 0.20529357966398998
# Number Of Images Tested = 10000
# Model Accuracy = 0.9139
# Test loss: 0.34558694171392995
#
# Epoch 1
# Training loss: 0.08987847692457272
# Number Of Images Tested = 10000
# Model Accuracy = 0.9317
# Test loss: 0.26287285813147493
#
# Epoch 2
# Training loss: 0.07605219433100388
# Number Of Images Tested = 10000
# Model Accuracy = 0.9411
# Test loss: 0.28539429602634375
#
# Epoch 3
# Training loss: 0.057343016756279744
# Number Of Images Tested = 10000
# Model Accuracy = 0.9582
# Test loss: 0.1712426622843097
#
# Epoch 4
# Training loss: 0.055138675317697936
# Number Of Images Tested = 10000
# Model Accuracy = 0.9516
# Test loss: 0.2364658225464166
#
# Epoch 5
# Training loss: 0.05381857698716352
# Number Of Images Tested = 10000
# Model Accuracy = 0.9444
# Test loss: 0.2805934348914796
#
# Epoch 6
# Training loss: 0.05083650539069176
# Number Of Images Tested = 10000
# Model Accuracy = 0.9623
# Test loss: 0.17198492878336893
#
# Epoch 7
# Training loss: 0.04970532100712411
# Number Of Images Tested = 10000
# Model Accuracy = 0.9663
# Test loss: 0.1849518096438538
#
# Epoch 8
# Training loss: 0.04772557139790818
# Number Of Images Tested = 10000
# Model Accuracy = 0.9579
# Test loss: 0.20213838584201946
#
# Epoch 9
# Training loss: 0.04276225260593437
# Number Of Images Tested = 10000
# Model Accuracy = 0.9534
# Test loss: 0.250619723050778
#
# Epoch 10
# Training loss: 0.040644986186179205
# Number Of Images Tested = 10000
# Model Accuracy = 0.947
# Test loss: 0.2712868826187981
#
# Epoch 11
# Training loss: 0.03723024299980839
# Number Of Images Tested = 10000
# Model Accuracy = 0.9402
# Test loss: 0.3622920964933505
#
# Epoch 12
# Training loss: 0.03903338915452725
# Number Of Images Tested = 10000
# Model Accuracy = 0.9568
# Test loss: 0.22601662702763164
#
# Epoch 13
# Training loss: 0.04612541856062819
# Number Of Images Tested = 10000
# Model Accuracy = 0.9387
# Test loss: 0.4259884696169074
#
# Epoch 14
# Training loss: 0.03332620967596041
# Number Of Images Tested = 10000
# Model Accuracy = 0.9562
# Test loss: 0.25206841517589795
#
# Epoch 15
# Training loss: 0.036368559970536896
# Number Of Images Tested = 10000
# Model Accuracy = 0.9662
# Test loss: 0.1863438265385539
#
# Epoch 16
# Training loss: 0.041371948741779324
# Number Of Images Tested = 10000
# Model Accuracy = 0.9624
# Test loss: 0.22838196425782314
#
# Epoch 17
# Training loss: 0.03233694918818645
# Number Of Images Tested = 10000
# Model Accuracy = 0.9153
# Test loss: 0.6314372695258753
#
# Epoch 18
# Training loss: 0.03258391966052283
# Number Of Images Tested = 10000
# Model Accuracy = 0.9727
# Test loss: 0.1715161545141937
#
# Epoch 19
# Training loss: 0.03248364392031706
# Number Of Images Tested = 10000
# Model Accuracy = 0.9552
# Test loss: 0.2992215933230747
#
#
# Training Time (in minutes) = 10.845892592271168
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-4d0ad1ade8c2> in <module>
#      13 epochs = 20
#      14
# ---> 15 train_losses, test_losses,  accuracies = optimize(optimizer, epochs, trainloader,valloader, modelA, criterion, method)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %% [markdown]
# ## LBFGS

# %%
from lbfgsnew import LBFGSNew

# %%
input_size = 784
output_size = 10
sizes = [input_size,128,64,output_size]

# The model is built
modelA=fully_connected_NN(sizes)
# Loss of the model is defined.
criterion = nn.NLLLoss()

method = "LBFGS"
optimizer = LBFGSNew(modelA.parameters(), history_size=10, max_iter=4, line_search_fn=True,batch_mode=True)
time0 = time()
epochs = 20

train_losses, test_losses = optimize(optimizer, epochs, trainloader,valloader, modelA, criterion, method)
# Out:
# Epoch 0
# Training loss: 0.370116194404328
# Number Of Images Tested = 10000
# Model Accuracy = 0.8353
# Test loss: 0.5153968813502865
#
# Epoch 1
# Training loss: 0.12603927853265043
# Number Of Images Tested = 10000
# Model Accuracy = 0.9132
# Test loss: 0.2934160553346014
#
# Epoch 2
# Training loss: 0.042800883495453385
# Number Of Images Tested = 10000
# Model Accuracy = 0.9445
# Test loss: 0.18494744099391874
#
# Epoch 3
# Training loss: 0.019732473420350553
# Number Of Images Tested = 10000
# Model Accuracy = 0.957
# Test loss: 0.14679814385143436
#
# Epoch 4
# Training loss: 0.012137761624750377
# Number Of Images Tested = 10000
# Model Accuracy = 0.9595
# Test loss: 0.14045590202318162
#
# Epoch 5
# Training loss: 0.008504871873985301
# Number Of Images Tested = 10000
# Model Accuracy = 0.9653
# Test loss: 0.11924162996446441
#
# Epoch 6
# Training loss: 0.006017661009823828
# Number Of Images Tested = 10000
# Model Accuracy = 0.9691
# Test loss: 0.10428848187661593
#
# Epoch 7
# Training loss: 0.004905000936847105
# Number Of Images Tested = 10000
# Model Accuracy = 0.9668
# Test loss: 0.12159490047295572
#
# Epoch 8
# Training loss: 0.003798315632135929
# Number Of Images Tested = 10000
# Model Accuracy = 0.9541
# Test loss: 0.1876485717012384
#
# Epoch 9
# Training loss: 0.003106818617060175
# Number Of Images Tested = 10000
# Model Accuracy = 0.9669
# Test loss: 0.13523190442819719
#
# Epoch 10
# Training loss: 0.002780088327831523
# Number Of Images Tested = 10000
# Model Accuracy = 0.9637
# Test loss: 0.16416667425221984
#
# Epoch 11
# Training loss: 0.0022839588180583008
# Number Of Images Tested = 10000
# Model Accuracy = 0.9733
# Test loss: 0.11043206593946771
#
# Epoch 12
# Training loss: 0.00209035410386502
# Number Of Images Tested = 10000
# Model Accuracy = 0.9592
# Test loss: 0.171045069396088
#
# Epoch 13
# Training loss: 0.0018163062658147025
# Number Of Images Tested = 10000
# Model Accuracy = 0.9538
# Test loss: 0.21549737298654267
#
# Epoch 14
# Training loss: 0.0016993474491852438
# Number Of Images Tested = 10000
# Model Accuracy = 0.9484
# Test loss: 0.24827399829500443
#
# Epoch 15
# Training loss: 0.0016366394813229796
# Number Of Images Tested = 10000
# Model Accuracy = 0.9648
# Test loss: 0.20384155476337357
#
# Epoch 16
# Training loss: 0.0014296709611751402
# Number Of Images Tested = 10000
# Model Accuracy = 0.9598
# Test loss: 0.18868996532912705
#
# Epoch 17
# Training loss: 0.0014562956445798554
# Number Of Images Tested = 10000
# Model Accuracy = 0.9684
# Test loss: 0.16099266384200492
#
# Epoch 18
# Training loss: 0.0013402839047204852
# Number Of Images Tested = 10000
# Model Accuracy = 0.9555
# Test loss: 0.23944156843802833
#
# Epoch 19
