# %%
# %matplotlib inline

import numpy as np
import torch
import matplotlib.pyplot as plt

#from helper2 import generate_dataset, visualize_one_dataset, visualize_datasets, predict_grid, visualize_predictions
from torch.utils import data

# %load_ext autoreload
# %autoreload 2

import torchvision

from time import time
from torchvision import datasets, transforms
from torch import nn, optim

from helper import *
from sdlbfgs import *

# %%
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])

# %% [markdown]
# ### MNIST dataset
# The MNIST dataset is loaded.

# %%
trainset = datasets.MNIST('', download=True, train=True, transform=transform)
valset = datasets.MNIST('', download=True, train=False, transform=transform)

# %%
print("Training and test sets information is displayed.\n\n")
print("Trainset:\n",trainset)
print("Testset:\n",valset)
# Out:
# Training and test sets information is displayed.
#
#
# Trainset:
#  Dataset MNIST
#     Number of datapoints: 60000
#     Root location:
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5,), std=(0.5,))
#            )
# Testset:
#  Dataset MNIST
#     Number of datapoints: 10000
#     Root location: PATH_TO_STORE_TESTSET
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5,), std=(0.5,))
#            )

# %% [markdown]
# # LBFGSNew mini-batch hyperparameters tuning

# %%
minibatch_size_grid = [32,64,128]
max_iter_grid = [3,6,10]

# %%
epochs = 15

# %% [markdown]
# ### Fully connected network

# %%
results =hyperparameters_tuning_LBFGS_new_minibatch(trainset,valset,minibatch_size_grid, max_iter_grid, epochs, "FCNN")
# Out:
# Minibatch size:  32
# History size:  3
# Epoch 0
# Training loss: 0.4123996182839076
# Number Of Images Tested = 10000
# Model Accuracy = 0.8965
# Number Of Images Tested = 60000
# Model Accuracy = 0.8911833333333333
# Test loss: 0.35239260115276894
#
# Epoch 1
# Training loss: 0.19627887757023177
# Number Of Images Tested = 10000
# Model Accuracy = 0.9211
# Number Of Images Tested = 60000
# Model Accuracy = 0.9192833333333333
# Test loss: 0.2693832507624794
#
# Epoch 2
# Training loss: 0.13419620700478554
# Number Of Images Tested = 10000
# Model Accuracy = 0.9375
# Number Of Images Tested = 60000
# Model Accuracy = 0.9394166666666667
# Test loss: 0.20092262237811812
#
# Epoch 3
# Training loss: 0.09475007768670718
# Number Of Images Tested = 10000
# Model Accuracy = 0.947
# Number Of Images Tested = 60000
# Model Accuracy = 0.9504333333333334
# Test loss: 0.17116234253961057
#
# Epoch 4
# Training loss: 0.07082882276674111
# Number Of Images Tested = 10000
# Model Accuracy = 0.9455
# Number Of Images Tested = 60000
# Model Accuracy = 0.9478
# Test loss: 0.17856176403431465
#
# Epoch 5
# Training loss: 0.05562458275705576
# Number Of Images Tested = 10000
# Model Accuracy = 0.9546
# Number Of Images Tested = 60000
# Model Accuracy = 0.9597333333333333
# Test loss: 0.1413944876193405
#
# Epoch 6
# Training loss: 0.046050238291174175
# Number Of Images Tested = 10000
# Model Accuracy = 0.9576
# Number Of Images Tested = 60000
# Model Accuracy = 0.9619333333333333
# Test loss: 0.13389395281357078
#
# Epoch 7
# Training loss: 0.038705728919804096
# Number Of Images Tested = 10000
# Model Accuracy = 0.9645
# Number Of Images Tested = 60000
# Model Accuracy = 0.9699666666666666
# Test loss: 0.1148598552071534
#
# Epoch 8
# Training loss: 0.03324448885396123
# Number Of Images Tested = 10000
# Model Accuracy = 0.9489
# Number Of Images Tested = 60000
# Model Accuracy = 0.9547333333333333
# Test loss: 0.16758800353021763
#
# Epoch 9
# Training loss: 0.028785561844396096
# Number Of Images Tested = 10000
# Model Accuracy = 0.9664
# Number Of Images Tested = 60000
# Model Accuracy = 0.9724333333333334
# Test loss: 0.10914878566197445
#
# Epoch 10
# Training loss: 0.02642335178796202
# Number Of Images Tested = 10000
# Model Accuracy = 0.969
# Number Of Images Tested = 60000
# Model Accuracy = 0.97355
# Test loss: 0.10142707812284438
#
# Epoch 11
# Training loss: 0.02322818123170485
# Number Of Images Tested = 10000
# Model Accuracy = 0.9655
# Number Of Images Tested = 60000
# Model Accuracy = 0.9762
# Test loss: 0.11134763979338133
#
# Epoch 12
# Training loss: 0.020450195670158912
# Number Of Images Tested = 10000
# Model Accuracy = 0.9685
# Number Of Images Tested = 60000
# Model Accuracy = 0.9779166666666667
# Test loss: 0.10468100761985794
#
# Epoch 13
# Training loss: 0.01878107480922093
# Number Of Images Tested = 10000
# Model Accuracy = 0.967
# Number Of Images Tested = 60000
# Model Accuracy = 0.9749
# Test loss: 0.10261195913379709
#
# Epoch 14
# Training loss: 0.01694259246729004
# Number Of Images Tested = 10000
# Model Accuracy = 0.9718
# Number Of Images Tested = 60000
# Model Accuracy = 0.9821
# Test loss: 0.09088446810311926
#
#
# Training Time (in minutes) = 14.401471094290416
#
#
# Minibatch size:  32
# History size:  6
# Epoch 0
# Training loss: 0.03915253062280826
# Number Of Images Tested = 10000
# Model Accuracy = 0.9258
# Number Of Images Tested = 60000
# Model Accuracy = 0.93005
# Test loss: 0.3163934536852886
#
# Epoch 1
# Training loss: 0.0056907234628775765
# Number Of Images Tested = 10000
# Model Accuracy = 0.8818
# Number Of Images Tested = 60000
# Model Accuracy = 0.8848166666666667
# Test loss: 1.0349652289049165
#
# Epoch 2
# Training loss: 0.017901850550376304
# Number Of Images Tested = 10000
# Model Accuracy = 0.9262
# Number Of Images Tested = 60000
# Model Accuracy = 0.9263333333333333
# Test loss: 0.3642398326378018
#
# Epoch 3
# Training loss: 0.03752966437172436
# Number Of Images Tested = 10000
# Model Accuracy = 0.9031
# Number Of Images Tested = 60000
# Model Accuracy = 0.903
# Test loss: 0.4881157250446342
#
# Epoch 4
# Training loss: 0.07386862055438832
# Number Of Images Tested = 10000
# Model Accuracy = 0.9108
# Number Of Images Tested = 60000
# Model Accuracy = 0.9115666666666666
# Test loss: 0.610606020313692
#
# Epoch 5
# Training loss: 0.2113441910882204
# Number Of Images Tested = 10000
# Model Accuracy = 0.883
# Number Of Images Tested = 60000
# Model Accuracy = 0.8783
# Test loss: 0.5937452970292812
#
# Epoch 6
# Training loss: 0.14983773994684768
# Number Of Images Tested = 10000
# Model Accuracy = 0.8801
# Number Of Images Tested = 60000
# Model Accuracy = 0.8839666666666667
# Test loss: 0.7775597951639766
#
# Epoch 7
# Training loss: 0.1698430450134833
# Number Of Images Tested = 10000
# Model Accuracy = 0.8659
# Number Of Images Tested = 60000
# Model Accuracy = 0.8648166666666667
# Test loss: 0.603400783107494
#
# Epoch 8
# Training loss: 0.22588713713646477
# Number Of Images Tested = 10000
# Model Accuracy = 0.8159
# Number Of Images Tested = 60000
# Model Accuracy = 0.8104666666666667
# Test loss: 0.7914740932873263
#
# Epoch 9
# Training loss: 0.3168028008157698
# Number Of Images Tested = 10000
# Model Accuracy = 0.7218
# Number Of Images Tested = 60000
# Model Accuracy = 0.7244333333333334
# Test loss: 1.022926661676873
#
# Epoch 10
# Training loss: 0.5901645292838414
# Number Of Images Tested = 10000
# Model Accuracy = 0.781
# Number Of Images Tested = 60000
# Model Accuracy = 0.7855833333333333
# Test loss: 1.165381994300757
#
# Epoch 11
# Training loss: 0.37980001295457283
# Number Of Images Tested = 10000
# Model Accuracy = 0.8534
# Number Of Images Tested = 60000
# Model Accuracy = 0.8528333333333333
# Test loss: 0.6016405865835687
#
# Epoch 12
# Training loss: 0.35799470588968446
# Number Of Images Tested = 10000
# Model Accuracy = 0.7458
# Number Of Images Tested = 60000
# Model Accuracy = 0.7444833333333334
# Test loss: 0.8335733510815678
#
# Epoch 13
# Training loss: 0.23126761955792705
# Number Of Images Tested = 10000
# Model Accuracy = 0.8644
# Number Of Images Tested = 60000
# Model Accuracy = 0.8660166666666667
# Test loss: 0.6219237004986967
#
# Epoch 14
# Training loss: 0.22330704583209007
# Number Of Images Tested = 10000
# Model Accuracy = 0.8443
# Number Of Images Tested = 60000
# Model Accuracy = 0.8488833333333333
# Test loss: 1.0164374154263411
#
#
# Training Time (in minutes) = 25.067614726225536
#
#
# Minibatch size:  32
# History size:  10
# Epoch 0
# Training loss: 0.16512690245064246
# Number Of Images Tested = 10000
# Model Accuracy = 0.7209
# Number Of Images Tested = 60000
# Model Accuracy = 0.7183666666666667
# Test loss: 1.1107711114060765
#
# Epoch 1
# Training loss: 0.3837137052282691
# Number Of Images Tested = 10000
# Model Accuracy = 0.1028
# Number Of Images Tested = 60000
# Model Accuracy = 0.10441666666666667
# Test loss: 2.322813290757493
#
# Epoch 2
# Training loss: 2.1791079507827757
# Number Of Images Tested = 10000
# Model Accuracy = 0.1032
# Number Of Images Tested = 60000
# Model Accuracy = 0.0993
# Test loss: 2.4962669614785775
#
# Epoch 3
# Training loss: 2.165549405415853
# Number Of Images Tested = 10000
# Model Accuracy = 0.0892
# Number Of Images Tested = 60000
# Model Accuracy = 0.09035
# Test loss: 2.3165297287340745
#
# Epoch 4
# Training loss: 2.1572841829299927
# Number Of Images Tested = 10000
# Model Accuracy = 0.0974
# Number Of Images Tested = 60000
# Model Accuracy = 0.09751666666666667
# Test loss: 2.5501445329989108
#
# Epoch 5
# Training loss: 2.1573700876871746
# Number Of Images Tested = 10000
# Model Accuracy = 0.0892
# Number Of Images Tested = 60000
# Model Accuracy = 0.09035
# Test loss: 2.4004398268251754
#
# Epoch 6
# Training loss: 2.150313944117228
# Number Of Images Tested = 10000
# Model Accuracy = 0.101
# Number Of Images Tested = 60000
# Model Accuracy = 0.10218333333333333
# Test loss: 2.4492777711667193
#
# Epoch 7
# Training loss: 2.1528271940231325
# Number Of Images Tested = 10000
# Model Accuracy = 0.098
# Number Of Images Tested = 60000
# Model Accuracy = 0.09871666666666666
# Test loss: 2.356300567285702
#
# Epoch 8
# Training loss: 2.1496704582214354
# Number Of Images Tested = 10000
# Model Accuracy = 0.0982
# Number Of Images Tested = 60000
# Model Accuracy = 0.09736666666666667
# Test loss: 2.4540673414358314
#
# Epoch 9
# Training loss: 2.1498601389567056
# Number Of Images Tested = 10000
# Model Accuracy = 0.101
# Number Of Images Tested = 60000
# Model Accuracy = 0.10218333333333333
# Test loss: 2.432892348438787
#
# Epoch 10
# Training loss: 2.147922423171997
# Number Of Images Tested = 10000
# Model Accuracy = 0.1135
# Number Of Images Tested = 60000
# Model Accuracy = 0.11236666666666667
# Test loss: 2.4515605475575017
#
# Epoch 11
# Training loss: 2.1497010420481364
# Number Of Images Tested = 10000
# Model Accuracy = 0.0974
# Number Of Images Tested = 60000
# Model Accuracy = 0.09751666666666667
# Test loss: 2.4091750729959993
#
# Epoch 12
# Training loss: 2.148442773882548
# Number Of Images Tested = 10000
# Model Accuracy = 0.101
# Number Of Images Tested = 60000
# Model Accuracy = 0.10218333333333333
# Test loss: 2.6041339487313464
#
# Epoch 13
# Training loss: 2.148277014287313
# Number Of Images Tested = 10000
# Model Accuracy = 0.0958
# Number Of Images Tested = 60000
# Model Accuracy = 0.09863333333333334
# Test loss: 2.6166238693383557
#
# Epoch 14
# Training loss: 2.1481730470657348
# Number Of Images Tested = 10000
# Model Accuracy = 0.1028
# Number Of Images Tested = 60000
# Model Accuracy = 0.10441666666666667
# Test loss: 2.8460062151899734
#
#
# Training Time (in minutes) = 33.14398288329442
#
#
# Minibatch size:  64
# History size:  3
# Epoch 0
# Training loss: 0.353389789181541
# Number Of Images Tested = 10000
# Model Accuracy = 0.8991
# Number Of Images Tested = 60000
# Model Accuracy = 0.8960333333333333
# Test loss: 0.3492016855888306
#
# Epoch 1
# Training loss: 0.18526852540354102
# Number Of Images Tested = 10000
# Model Accuracy = 0.9269
# Number Of Images Tested = 60000
# Model Accuracy = 0.92495
# Test loss: 0.2523335508859841
#
# Epoch 2
# Training loss: 0.12165215623173822
# Number Of Images Tested = 10000
# Model Accuracy = 0.8704
# Number Of Images Tested = 60000
# Model Accuracy = 0.8676833333333334
# Test loss: 0.4215476565110456
#
# Epoch 3
# Training loss: 0.08423730416862822
# Number Of Images Tested = 10000
# Model Accuracy = 0.956
# Number Of Images Tested = 60000
# Model Accuracy = 0.9595166666666667
# Test loss: 0.14573040959324426
#
# Epoch 4
# Training loss: 0.06484089639665348
# Number Of Images Tested = 10000
# Model Accuracy = 0.9561
# Number Of Images Tested = 60000
# Model Accuracy = 0.9612666666666667
# Test loss: 0.1458194593240501
#
# Epoch 5
# Training loss: 0.052686217073192286
# Number Of Images Tested = 10000
# Model Accuracy = 0.9551
# Number Of Images Tested = 60000
# Model Accuracy = 0.9602166666666667
# Test loss: 0.15205626830956928
#
# Epoch 6
# Training loss: 0.04389042923076034
# Number Of Images Tested = 10000
# Model Accuracy = 0.9618
# Number Of Images Tested = 60000
# Model Accuracy = 0.9684666666666667
# Test loss: 0.1288850792790437
#
# Epoch 7
# Training loss: 0.036809145422306844
# Number Of Images Tested = 10000
# Model Accuracy = 0.9681
# Number Of Images Tested = 60000
# Model Accuracy = 0.9749833333333333
# Test loss: 0.10830935558221143
#
# Epoch 8
# Training loss: 0.031961519757647126
# Number Of Images Tested = 10000
# Model Accuracy = 0.963
# Number Of Images Tested = 60000
# Model Accuracy = 0.97215
# Test loss: 0.11932554604948327
#
# Epoch 9
# Training loss: 0.028429262878955093
# Number Of Images Tested = 10000
# Model Accuracy = 0.9656
# Number Of Images Tested = 60000
# Model Accuracy = 0.97505
# Test loss: 0.11502136129019841
#
# Epoch 10
# Training loss: 0.025326726443098503
# Number Of Images Tested = 10000
# Model Accuracy = 0.9691
# Number Of Images Tested = 60000
# Model Accuracy = 0.9806833333333334
# Test loss: 0.10244506502607066
#
# Epoch 11
# Training loss: 0.02279439555984467
# Number Of Images Tested = 10000
# Model Accuracy = 0.9674
# Number Of Images Tested = 60000
# Model Accuracy = 0.9783166666666666
# Test loss: 0.10976093392937807
#
# Epoch 12
# Training loss: 0.021085225959131714
# Number Of Images Tested = 10000
# Model Accuracy = 0.9689
# Number Of Images Tested = 60000
# Model Accuracy = 0.981
# Test loss: 0.10593445008549436
#
# Epoch 13
# Training loss: 0.019375755803596014
# Number Of Images Tested = 10000
# Model Accuracy = 0.953
# Number Of Images Tested = 60000
# Model Accuracy = 0.9597
# Test loss: 0.169011032413454
#
# Epoch 14
# Training loss: 0.017383644882806026
# Number Of Images Tested = 10000
# Model Accuracy = 0.9728
# Number Of Images Tested = 60000
# Model Accuracy = 0.9858166666666667
# Test loss: 0.0939435971052546
#
#
# Training Time (in minutes) = 11.13567453622818
#
#
# Minibatch size:  64
# History size:  6
# Epoch 0
# Training loss: 0.043750914024511305
# Number Of Images Tested = 10000
# Model Accuracy = 0.9008
# Number Of Images Tested = 60000
# Model Accuracy = 0.9038333333333334
# Test loss: 0.4101071338032841
#
# Epoch 1
# Training loss: 0.002709010277364613
# Number Of Images Tested = 10000
# Model Accuracy = 0.9324
# Number Of Images Tested = 60000
# Model Accuracy = 0.9380833333333334
# Test loss: 0.25405067289663347
#
# Epoch 2
# Training loss: 0.0017093896822828925
# Number Of Images Tested = 10000
# Model Accuracy = 0.9205
# Number Of Images Tested = 60000
# Model Accuracy = 0.92415
# Test loss: 0.4180750943910164
#
# Epoch 3
# Training loss: 0.0018659576335267047
# Number Of Images Tested = 10000
# Model Accuracy = 0.945
# Number Of Images Tested = 60000
# Model Accuracy = 0.9531
# Test loss: 0.270106410969547
#
# Epoch 4
# Training loss: 0.002741095059013254
# Number Of Images Tested = 10000
# Model Accuracy = 0.9098
# Number Of Images Tested = 60000
# Model Accuracy = 0.912
# Test loss: 0.47529036803230357
#
# Epoch 5
# Training loss: 0.005633235942607963
# Number Of Images Tested = 10000
# Model Accuracy = 0.927
# Number Of Images Tested = 60000
# Model Accuracy = 0.9335333333333333
# Test loss: 0.4505960254686545
#
# Epoch 6
# Training loss: 0.01645545258372531
# Number Of Images Tested = 10000
# Model Accuracy = 0.9169
# Number Of Images Tested = 60000
# Model Accuracy = 0.9147
# Test loss: 0.47813303300007515
#
# Epoch 7
# Training loss: 0.022074125771766293
# Number Of Images Tested = 10000
# Model Accuracy = 0.9015
# Number Of Images Tested = 60000
# Model Accuracy = 0.9062
# Test loss: 1.3905463015577537
#
# Epoch 8
# Training loss: 0.02971079465187688
# Number Of Images Tested = 10000
# Model Accuracy = 0.9361
# Number Of Images Tested = 60000
# Model Accuracy = 0.9411666666666667
# Test loss: 0.48525103434451683
#
# Epoch 9
# Training loss: 0.03508855168432432
# Number Of Images Tested = 10000
# Model Accuracy = 0.9398
# Number Of Images Tested = 60000
# Model Accuracy = 0.9438166666666666
# Test loss: 0.35685343397366015
#
# Epoch 10
# Training loss: 0.04524702962094098
# Number Of Images Tested = 10000
# Model Accuracy = 0.9287
# Number Of Images Tested = 60000
# Model Accuracy = 0.9268166666666666
# Test loss: 0.5436163456149542
#
# Epoch 11
# Training loss: 0.05887825669581447
# Number Of Images Tested = 10000
# Model Accuracy = 0.9154
# Number Of Images Tested = 60000
# Model Accuracy = 0.9203333333333333
# Test loss: 0.8332816210759294
#
# Epoch 12
# Training loss: 0.05439291300797007
# Number Of Images Tested = 10000
# Model Accuracy = 0.9299
# Number Of Images Tested = 60000
# Model Accuracy = 0.93295
# Test loss: 0.48787572071739255
#
# Epoch 13
# Training loss: 0.07005951876533127
# Number Of Images Tested = 10000
# Model Accuracy = 0.8901
# Number Of Images Tested = 60000
# Model Accuracy = 0.8877166666666667
# Test loss: 0.6424018621065055
#
# Epoch 14
# Training loss: 0.0628273475313074
# Number Of Images Tested = 10000
# Model Accuracy = 0.9303
# Number Of Images Tested = 60000
# Model Accuracy = 0.9363833333333333
# Test loss: 0.41169988311779726
#
#
# Training Time (in minutes) = 16.81814147233963
#
#
# Minibatch size:  64
# History size:  10
# Epoch 0
# Training loss: 0.049946566595422744
# Number Of Images Tested = 10000
# Model Accuracy = 0.9303
# Number Of Images Tested = 60000
# Model Accuracy = 0.9335666666666667
# Test loss: 0.37258757381539814
#
# Epoch 1
# Training loss: 0.0007244646200482601
# Number Of Images Tested = 10000
# Model Accuracy = 0.9346
# Number Of Images Tested = 60000
# Model Accuracy = 0.9345333333333333
# Test loss: 0.6200082823574827
#
# Epoch 2
# Training loss: 0.004685591744468127
# Number Of Images Tested = 10000
# Model Accuracy = 0.8878
# Number Of Images Tested = 60000
# Model Accuracy = 0.8855166666666666
# Test loss: 0.867640233913045
#
# Epoch 3
# Training loss: 0.005116507454460089
# Number Of Images Tested = 10000
# Model Accuracy = 0.8877
# Number Of Images Tested = 60000
# Model Accuracy = 0.88065
# Test loss: 0.7517237554594969
#
# Epoch 4
# Training loss: 0.014672947708636204
# Number Of Images Tested = 10000
# Model Accuracy = 0.9057
# Number Of Images Tested = 60000
# Model Accuracy = 0.9096833333333333
# Test loss: 0.6455283333683849
#
# Epoch 5
# Training loss: 0.02966534172316869
# Number Of Images Tested = 10000
# Model Accuracy = 0.9014
# Number Of Images Tested = 60000
# Model Accuracy = 0.8943333333333333
# Test loss: 0.902862008471208
#
# Epoch 6
# Training loss: 0.043427508770889384
# Number Of Images Tested = 10000
# Model Accuracy = 0.8917
# Number Of Images Tested = 60000
# Model Accuracy = 0.8828666666666667
# Test loss: 0.5986173593789149
#
# Epoch 7
# Training loss: 0.05823170421345862
# Number Of Images Tested = 10000
# Model Accuracy = 0.9177
# Number Of Images Tested = 60000
# Model Accuracy = 0.9147166666666666
# Test loss: 0.931623056771198
#
# Epoch 8
# Training loss: 0.0748827550866982
# Number Of Images Tested = 10000
# Model Accuracy = 0.9179
# Number Of Images Tested = 60000
# Model Accuracy = 0.9179166666666667
# Test loss: 0.6483933178672365
#
# Epoch 9
# Training loss: 0.09105564673613357
# Number Of Images Tested = 10000
# Model Accuracy = 0.9189
# Number Of Images Tested = 60000
# Model Accuracy = 0.9200666666666667
# Test loss: 0.9367946881139473
#
# Epoch 10
# Training loss: 0.0968258052334757
# Number Of Images Tested = 10000
# Model Accuracy = 0.9191
# Number Of Images Tested = 60000
# Model Accuracy = 0.91895
# Test loss: 0.812276991048626
#
# Epoch 11
# Training loss: 0.1113904588480108
# Number Of Images Tested = 10000
# Model Accuracy = 0.9246
# Number Of Images Tested = 60000
# Model Accuracy = 0.9239666666666667
# Test loss: 0.47701784180607765
#
# Epoch 12
# Training loss: 0.10343417790237819
# Number Of Images Tested = 10000
# Model Accuracy = 0.9015
# Number Of Images Tested = 60000
# Model Accuracy = 0.8991333333333333
# Test loss: 0.7410475266207556
#
# Epoch 13
# Training loss: 0.10984606607471113
# Number Of Images Tested = 10000
# Model Accuracy = 0.8564
# Number Of Images Tested = 60000
# Model Accuracy = 0.8537333333333333
# Test loss: 2.376701601086908
#
# Epoch 14
# Training loss: 0.12831520689314566
# Number Of Images Tested = 10000
# Model Accuracy = 0.8072
# Number Of Images Tested = 60000
# Model Accuracy = 0.8121333333333334
# Test loss: 1.3511850253032271
#
#
# Training Time (in minutes) = 22.98075318733851
#
#
# Minibatch size:  128
# History size:  3
# Epoch 0
# Training loss: 0.6103271751769824
# Number Of Images Tested = 10000
# Model Accuracy = 0.8358
# Number Of Images Tested = 60000
# Model Accuracy = 0.8289333333333333
# Test loss: 0.5437029339844668
#
# Epoch 1
# Training loss: 0.46669343654026607
# Number Of Images Tested = 10000
# Model Accuracy = 0.8617
# Number Of Images Tested = 60000
# Model Accuracy = 0.8589833333333333
# Test loss: 0.4640300255033034
#
# Epoch 2
# Training loss: 0.40833172812136503
# Number Of Images Tested = 10000
# Model Accuracy = 0.878
# Number Of Images Tested = 60000
# Model Accuracy = 0.8732833333333333
# Test loss: 0.4064844846725464
#
# Epoch 3
# Training loss: 0.37165220320097675
# Number Of Images Tested = 10000
# Model Accuracy = 0.8864
# Number Of Images Tested = 60000
# Model Accuracy = 0.88405
# Test loss: 0.3795907586058484
#
# Epoch 4
# Training loss: 0.3454348366779051
# Number Of Images Tested = 10000
# Model Accuracy = 0.8936
# Number Of Images Tested = 60000
# Model Accuracy = 0.8906833333333334
# Test loss: 0.36408865451812744
#
# Epoch 5
# Training loss: 0.3223538463557961
# Number Of Images Tested = 10000
# Model Accuracy = 0.9038
# Number Of Images Tested = 60000
# Model Accuracy = 0.8985833333333333
# Test loss: 0.33471017736422864
#
# Epoch 6
# Training loss: 0.3063057331578818
# Number Of Images Tested = 10000
# Model Accuracy = 0.9026
# Number Of Images Tested = 60000
# Model Accuracy = 0.8977333333333334
# Test loss: 0.32239588717871076
#
# Epoch 7
# Training loss: 0.2919011781337673
# Number Of Images Tested = 10000
# Model Accuracy = 0.9051
# Number Of Images Tested = 60000
# Model Accuracy = 0.9023666666666667
# Test loss: 0.31654227345804625
#
# Epoch 8
# Training loss: 0.279815093731321
# Number Of Images Tested = 10000
# Model Accuracy = 0.9148
# Number Of Images Tested = 60000
# Model Accuracy = 0.911
# Test loss: 0.29345746545851986
#
# Epoch 9
# Training loss: 0.2661731043762998
# Number Of Images Tested = 10000
# Model Accuracy = 0.9126
# Number Of Images Tested = 60000
# Model Accuracy = 0.9092333333333333
# Test loss: 0.2908869917634167
#
# Epoch 10
# Training loss: 0.25708310090021286
# Number Of Images Tested = 10000
# Model Accuracy = 0.919
# Number Of Images Tested = 60000
# Model Accuracy = 0.9163666666666667
# Test loss: 0.27664904937713963
#
# Epoch 11
# Training loss: 0.2464427303498996
# Number Of Images Tested = 10000
# Model Accuracy = 0.9142
# Number Of Images Tested = 60000
# Model Accuracy = 0.9117166666666666
# Test loss: 0.28767945513695103
#
# Epoch 12
# Training loss: 0.23810588916354597
# Number Of Images Tested = 10000
# Model Accuracy = 0.9216
# Number Of Images Tested = 60000
# Model Accuracy = 0.9213666666666667
# Test loss: 0.2670377807903893
#
# Epoch 13
# Training loss: 0.22980231011727217
# Number Of Images Tested = 10000
# Model Accuracy = 0.9241
# Number Of Images Tested = 60000
# Model Accuracy = 0.92265
# Test loss: 0.2731292526933211
#
# Epoch 14
# Training loss: 0.22180075144399203
# Number Of Images Tested = 10000
# Model Accuracy = 0.9237
# Number Of Images Tested = 60000
# Model Accuracy = 0.9221333333333334
# Test loss: 0.26230137380240837
#
#
# Training Time (in minutes) = 9.397986022631327
#
#
# Minibatch size:  128
# History size:  6
# Epoch 0
# Training loss: 0.14018171391626602
# Number Of Images Tested = 10000
# Model Accuracy = 0.9077
# Number Of Images Tested = 60000
# Model Accuracy = 0.9098
# Test loss: 0.31149755050487155
#
# Epoch 1
# Training loss: 0.01270598689017734
# Number Of Images Tested = 10000
# Model Accuracy = 0.9474
# Number Of Images Tested = 60000
# Model Accuracy = 0.9526166666666667
# Test loss: 0.18116363788707346
#
# Epoch 2
# Training loss: 0.004309657311413501
# Number Of Images Tested = 10000
# Model Accuracy = 0.9617
# Number Of Images Tested = 60000
# Model Accuracy = 0.9697833333333333
# Test loss: 0.13851420744027518
#
# Epoch 3
# Training loss: 0.0021837801556909646
# Number Of Images Tested = 10000
# Model Accuracy = 0.9655
# Number Of Images Tested = 60000
# Model Accuracy = 0.9735333333333334
# Test loss: 0.14072426786952758
#
# Epoch 4
# Training loss: 0.0013985679024641317
# Number Of Images Tested = 10000
# Model Accuracy = 0.9572
# Number Of Images Tested = 60000
# Model Accuracy = 0.9620166666666666
# Test loss: 0.21018499124182177
#
# Epoch 5
# Training loss: 0.0009823537804515235
# Number Of Images Tested = 10000
# Model Accuracy = 0.9554
# Number Of Images Tested = 60000
# Model Accuracy = 0.9630833333333333
# Test loss: 0.22940041615607076
#
# Epoch 6
# Training loss: 0.0007318851987994872
# Number Of Images Tested = 10000
# Model Accuracy = 0.9633
# Number Of Images Tested = 60000
# Model Accuracy = 0.9702333333333333
# Test loss: 0.1886431005889479
#
# Epoch 7
# Training loss: 0.0006115627787918024
# Number Of Images Tested = 10000
# Model Accuracy = 0.9692
# Number Of Images Tested = 60000
# Model Accuracy = 0.9802666666666666
# Test loss: 0.1470464529827697
#
# Epoch 8
# Training loss: 0.00047780550507758347
# Number Of Images Tested = 10000
# Model Accuracy = 0.9637
# Number Of Images Tested = 60000
# Model Accuracy = 0.9726
# Test loss: 0.1821812056358668
#
# Epoch 9
# Training loss: 0.0004271789502318904
# Number Of Images Tested = 10000
# Model Accuracy = 0.9688
# Number Of Images Tested = 60000
# Model Accuracy = 0.97805
# Test loss: 0.17730913622617203
#
# Epoch 10
# Training loss: 0.00033906992434618694
# Number Of Images Tested = 10000
# Model Accuracy = 0.9696
# Number Of Images Tested = 60000
# Model Accuracy = 0.9810666666666666
# Test loss: 0.15612999676974326
#
# Epoch 11
# Training loss: 0.0003713012805774134
# Number Of Images Tested = 10000
# Model Accuracy = 0.9725
# Number Of Images Tested = 60000
# Model Accuracy = 0.9816166666666667
# Test loss: 0.16417278248015083
#
# Epoch 12
# Training loss: 0.0002773460097472056
# Number Of Images Tested = 10000
# Model Accuracy = 0.9675
# Number Of Images Tested = 60000
# Model Accuracy = 0.9763666666666667
# Test loss: 0.18644483736421488
#
# Epoch 13
# Training loss: 0.00029872441340216693
# Number Of Images Tested = 10000
# Model Accuracy = 0.9748
# Number Of Images Tested = 60000
# Model Accuracy = 0.9841833333333333
# Test loss: 0.14638102306583542
#
# Epoch 14
# Training loss: 0.00026613297267371217
# Number Of Images Tested = 10000
# Model Accuracy = 0.9717
# Number Of Images Tested = 60000
# Model Accuracy = 0.98335
# Test loss: 0.17373947637697942
#
#
# Training Time (in minutes) = 12.86941343943278
#
#
# Minibatch size:  128
# History size:  10
# Epoch 0
# Training loss: 0.07114579265320134
# Number Of Images Tested = 10000
# Model Accuracy = 0.9169
# Number Of Images Tested = 60000
# Model Accuracy = 0.9205833333333333
# Test loss: 0.40033002527831474
#
# Epoch 1
# Training loss: 0.0013404702990197205
# Number Of Images Tested = 10000
# Model Accuracy = 0.9454
# Number Of Images Tested = 60000
# Model Accuracy = 0.9470833333333334
# Test loss: 0.33851197880657413
#
# Epoch 2
# Training loss: 0.000477506336379066
# Number Of Images Tested = 10000
# Model Accuracy = 0.9567
# Number Of Images Tested = 60000
# Model Accuracy = 0.9623333333333334
# Test loss: 0.23123866140465194
#
# Epoch 3
# Training loss: 0.00023877480316417306
# Number Of Images Tested = 10000
# Model Accuracy = 0.9566
# Number Of Images Tested = 60000
# Model Accuracy = 0.9648
# Test loss: 0.25583121172061096
#
# Epoch 4
# Training loss: 0.00014681176776854368
# Number Of Images Tested = 10000
# Model Accuracy = 0.9528
# Number Of Images Tested = 60000
# Model Accuracy = 0.9592333333333334
# Test loss: 0.3031743229897339
#
# Epoch 5
# Training loss: 0.00012073193840063908
# Number Of Images Tested = 10000
# Model Accuracy = 0.964
# Number Of Images Tested = 60000
# Model Accuracy = 0.97225
# Test loss: 0.2555380860569038
#
# Epoch 6
# Training loss: 9.27577596209838e-05
# Number Of Images Tested = 10000
# Model Accuracy = 0.9673
# Number Of Images Tested = 60000
# Model Accuracy = 0.9750833333333333
# Test loss: 0.25928569893069753
#
# Epoch 7
# Training loss: 9.719796793109153e-05
# Number Of Images Tested = 10000
# Model Accuracy = 0.9606
# Number Of Images Tested = 60000
# Model Accuracy = 0.9642166666666667
# Test loss: 0.26409750524562925
#
# Epoch 8
# Training loss: 8.120297537794586e-05
# Number Of Images Tested = 10000
# Model Accuracy = 0.9444
# Number Of Images Tested = 60000
# Model Accuracy = 0.9473833333333334
# Test loss: 0.4320395293680926
#
# Epoch 9
# Training loss: 7.60813386096643e-05
# Number Of Images Tested = 10000
# Model Accuracy = 0.9404
# Number Of Images Tested = 60000
# Model Accuracy = 0.9480666666666666
# Test loss: 0.47378449981348425
#
# Epoch 10
# Training loss: 7.827084067051666e-05
# Number Of Images Tested = 10000
# Model Accuracy = 0.9611
# Number Of Images Tested = 60000
# Model Accuracy = 0.9726666666666667
# Test loss: 0.3270880051688114
#
# Epoch 11
# Training loss: 0.00010171717158996148
# Number Of Images Tested = 10000
# Model Accuracy = 0.9456
# Number Of Images Tested = 60000
# Model Accuracy = 0.9558666666666666
# Test loss: 0.6079436421771592
#
# Epoch 12
# Training loss: 0.00011302898475526108
# Number Of Images Tested = 10000
# Model Accuracy = 0.964
# Number Of Images Tested = 60000
# Model Accuracy = 0.9741166666666666
# Test loss: 0.2834786840396214
#
# Epoch 13
# Training loss: 0.00011383049613791366
# Number Of Images Tested = 10000
# Model Accuracy = 0.9505
# Number Of Images Tested = 60000
# Model Accuracy = 0.96425
# Test loss: 0.4022367502197246
#
# Epoch 14
# Training loss: 0.00017349953693448784
# Number Of Images Tested = 10000
# Model Accuracy = 0.9611
# Number Of Images Tested = 60000
# Model Accuracy = 0.9680833333333333
# Test loss: 0.3678704607609919
#
#
# Training Time (in minutes) = 16.772625470161437

# %%
i=0
for bs_index,bs in enumerate(minibatch_size_grid):
    for hs_index,hs in enumerate(max_iter_grid):
        plt.figure(1, figsize = (12,10))
        plt.plot(results[3][i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(2, figsize = (12,10))
        plt.plot(results[1][i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(3, figsize = (12,10))
        plt.plot(results[4][i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(4, figsize = (12,10))
        plt.plot(results[2][i],label='bs = {}, hs = {}'.format(bs,hs))
        i=i+1

plt.figure(1)
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Minibatch LBFGS Test loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("mini_LBFGS_new_test_loss_fcnn_2.jpg")
plt.figure (2)
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
plt.title('Minibatch LBFGS Train loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("mini_LBFGS_new_train_loss_fcnn_2.jpg")
plt.figure (3)
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.title('Minibatch LBFGS Test accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("mini_LBFGS_new_test_acc_fcnn_2.jpg")
plt.figure (4)
plt.xlabel('Epochs')
plt.ylabel('Train Accuracy')
plt.title('Minibatch LBFGS Train accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("mini_LBFGS_new_train_acc_fcnn_2.jpg")

# %%
np.savetxt('LBFGS_new_minibatch_fcNN_trainloss_2.txt', results[1])
np.savetxt('LBFGS_new_minibatch_fcNN_testloss_2.txt', results[3])
np.savetxt('LBFGS_new_minibatch_fcNN_trainacc_2.txt', results[2])
np.savetxt('LBFGS_new_minibatch_fcNN_testacc_2.txt', results[4])
np.savetxt('LBFGS_new_minibatch_fcNN_times_2.txt',results[5])
