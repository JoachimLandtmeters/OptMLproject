# %%
# %matplotlib inline

import numpy as np
import torch
import matplotlib.pyplot as plt

#from helper2 import generate_dataset, visualize_one_dataset, visualize_datasets, predict_grid, visualize_predictions
from torch.utils import data

# %load_ext autoreload
# %autoreload 2

import torchvision

from time import time
from torchvision import datasets, transforms
from torch import nn, optim

from helpers_opt_parameters import *

# %%
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])

# %% [markdown]
# ### MNIST dataset
# The MNIST dataset is loaded.

# %%
trainset = datasets.MNIST('', download=True, train=True, transform=transform)
valset = datasets.MNIST('PATH_TO_STORE_TESTSET', download=True, train=False, transform=transform)

# %%
print("Training and test sets information is displayed.\n\n")
print("Trainset:\n",trainset)
print("Testset:\n",valset)
# Out:
# Training and test sets information is displayed.
#
#
# Trainset:
#  Dataset MNIST
#     Number of datapoints: 60000
#     Root location:
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5,), std=(0.5,))
#            )
# Testset:
#  Dataset MNIST
#     Number of datapoints: 10000
#     Root location: PATH_TO_STORE_TESTSET
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5,), std=(0.5,))
#            )

# %% [markdown]
# # LBFGS full-batch hyperparameters tuning

# %%
datapoints=[len(trainset)]
history_size_grid=[5,10,20]

# %%
epochs = 15

# %% [markdown]
# ### Fully connected network

# %%
training_loss_fcnn, test_loss_fcnn,training_accuracy_fcnn, test_accuracy_fcnn, time_fcnn =hyperparameters_tuning_LBFGS_minibatch(trainset,valset,datapoints, history_size_grid, epochs, "FCNN",fullbatch=True)
# Out:
# Minibatch size:  60000
# History size:  5
# Epoch 0
# Training loss: 0.6264114379882812
# Number Of Images Tested = 10000
# Model Accuracy = 0.8123
# Number Of Images Tested = 60000
# Model Accuracy = 0.8067333333333333
# Test loss: 0.6104886531829834
#
# Epoch 1
# Training loss: 0.45036032795906067
# Number Of Images Tested = 10000
# Model Accuracy = 0.8745
# Number Of Images Tested = 60000
# Model Accuracy = 0.8658666666666667
# Test loss: 0.43040958046913147
#
# Epoch 2
# Training loss: 0.38807210326194763
# Number Of Images Tested = 10000
# Model Accuracy = 0.8893
# Number Of Images Tested = 60000
# Model Accuracy = 0.8861166666666667
# Test loss: 0.371009886264801
#
# Epoch 3
# Training loss: 0.34127187728881836
# Number Of Images Tested = 10000
# Model Accuracy = 0.8996
# Number Of Images Tested = 60000
# Model Accuracy = 0.8985333333333333
# Test loss: 0.32805508375167847
#
# Epoch 4
# Training loss: 0.3041183352470398
# Number Of Images Tested = 10000
# Model Accuracy = 0.9117
# Number Of Images Tested = 60000
# Model Accuracy = 0.91095
# Test loss: 0.2947584092617035
#
# Epoch 5
# Training loss: 0.27802062034606934
# Number Of Images Tested = 10000
# Model Accuracy = 0.9225
# Number Of Images Tested = 60000
# Model Accuracy = 0.9200833333333334
# Test loss: 0.2724059224128723
#
# Epoch 6
# Training loss: 0.2563647925853729
# Number Of Images Tested = 10000
# Model Accuracy = 0.9272
# Number Of Images Tested = 60000
# Model Accuracy = 0.9273666666666667
# Test loss: 0.255016952753067
#
# Epoch 7
# Training loss: 0.23816943168640137
# Number Of Images Tested = 10000
# Model Accuracy = 0.9308
# Number Of Images Tested = 60000
# Model Accuracy = 0.9320166666666667
# Test loss: 0.23624438047409058
#
# Epoch 8
# Training loss: 0.22776804864406586
# Number Of Images Tested = 10000
# Model Accuracy = 0.9326
# Number Of Images Tested = 60000
# Model Accuracy = 0.9348333333333333
# Test loss: 0.22751794755458832
#
# Epoch 9
# Training loss: 0.2088261842727661
# Number Of Images Tested = 10000
# Model Accuracy = 0.938
# Number Of Images Tested = 60000
# Model Accuracy = 0.9404833333333333
# Test loss: 0.2084057629108429
#
# Epoch 10
# Training loss: 0.19326774775981903
# Number Of Images Tested = 10000
# Model Accuracy = 0.9409
# Number Of Images Tested = 60000
# Model Accuracy = 0.9433666666666667
# Test loss: 0.19487658143043518
#
# Epoch 11
# Training loss: 0.17399850487709045
# Number Of Images Tested = 10000
# Model Accuracy = 0.9474
# Number Of Images Tested = 60000
# Model Accuracy = 0.94875
# Test loss: 0.17740918695926666
#
# Epoch 12
# Training loss: 0.15994353592395782
# Number Of Images Tested = 10000
# Model Accuracy = 0.9504
# Number Of Images Tested = 60000
# Model Accuracy = 0.9532666666666667
# Test loss: 0.16683931648731232
#
# Epoch 13
# Training loss: 0.14612992107868195
# Number Of Images Tested = 10000
# Model Accuracy = 0.9528
# Number Of Images Tested = 60000
# Model Accuracy = 0.9567
# Test loss: 0.1565348207950592
#
# Epoch 14
# Training loss: 0.133967787027359
# Number Of Images Tested = 10000
# Model Accuracy = 0.9564
# Number Of Images Tested = 60000
# Model Accuracy = 0.9608
# Test loss: 0.14624962210655212
#
# Epoch 15
# Training loss: 0.1196400374174118
# Number Of Images Tested = 10000
# Model Accuracy = 0.958
# Number Of Images Tested = 60000
# Model Accuracy = 0.9657
# Test loss: 0.14146874845027924
#
# Epoch 16
# Training loss: 0.11055683344602585
# Number Of Images Tested = 10000
# Model Accuracy = 0.9612
# Number Of Images Tested = 60000
# Model Accuracy = 0.9682
# Test loss: 0.13797631859779358
#
# Epoch 17
# Training loss: 0.09967651218175888
# Number Of Images Tested = 10000
# Model Accuracy = 0.9632
# Number Of Images Tested = 60000
# Model Accuracy = 0.9709833333333333
# Test loss: 0.13442862033843994
#
# Epoch 18
# Training loss: 0.08886700868606567
# Number Of Images Tested = 10000
# Model Accuracy = 0.9649
# Number Of Images Tested = 60000
# Model Accuracy = 0.9742166666666666
# Test loss: 0.12957990169525146
#
# Epoch 19
# Training loss: 0.07959770411252975
# Number Of Images Tested = 10000
# Model Accuracy = 0.9662
# Number Of Images Tested = 60000
# Model Accuracy = 0.9763833333333334
# Test loss: 0.12618157267570496
#
# Epoch 20
# Training loss: 0.07057144492864609
# Number Of Images Tested = 10000
# Model Accuracy = 0.9665
# Number Of Images Tested = 60000
# Model Accuracy = 0.97825
# Test loss: 0.12568724155426025
#
# Epoch 21
# Training loss: 0.06302867084741592
# Number Of Images Tested = 10000
# Model Accuracy = 0.9671
# Number Of Images Tested = 60000
# Model Accuracy = 0.9809166666666667
# Test loss: 0.12187464535236359
#
# Epoch 22
# Training loss: 0.05766955390572548
# Number Of Images Tested = 10000
# Model Accuracy = 0.9681
# Number Of Images Tested = 60000
# Model Accuracy = 0.9823166666666666
# Test loss: 0.11909875273704529
#
# Epoch 23
# Training loss: 0.05128490552306175
# Number Of Images Tested = 10000
# Model Accuracy = 0.9696
# Number Of Images Tested = 60000
# Model Accuracy = 0.9842
# Test loss: 0.11350775510072708
#
# Epoch 24
# Training loss: 0.04557202011346817
# Number Of Images Tested = 10000
# Model Accuracy = 0.9688
# Number Of Images Tested = 60000
# Model Accuracy = 0.98605
# Test loss: 0.11098964512348175
#
# Epoch 25
# Training loss: 0.04041966050863266
# Number Of Images Tested = 10000
# Model Accuracy = 0.9702
# Number Of Images Tested = 60000
# Model Accuracy = 0.988
# Test loss: 0.10593509674072266
#
# Epoch 26
# Training loss: 0.03620956465601921
# Number Of Images Tested = 10000
# Model Accuracy = 0.9706
# Number Of Images Tested = 60000
# Model Accuracy = 0.9892333333333333
# Test loss: 0.1081138402223587
#
# Epoch 27
# Training loss: 0.03167416900396347
# Number Of Images Tested = 10000
# Model Accuracy = 0.9718
# Number Of Images Tested = 60000
# Model Accuracy = 0.9906
# Test loss: 0.11220921576023102
#
# Epoch 28
# Training loss: 0.027145514264702797
# Number Of Images Tested = 10000
# Model Accuracy = 0.9705
# Number Of Images Tested = 60000
# Model Accuracy = 0.99155
# Test loss: 0.11632443964481354
#
# Epoch 29
# Training loss: 0.022533100098371506
# Number Of Images Tested = 10000
# Model Accuracy = 0.9714
# Number Of Images Tested = 60000
# Model Accuracy = 0.9928833333333333
# Test loss: 0.12644104659557343
#
#
# Training Time (in minutes) = 17.17073421875636
#
#
# Minibatch size:  60000
# History size:  10
# Epoch 0
# Training loss: 0.6073217391967773
# Number Of Images Tested = 10000
# Model Accuracy = 0.8184
# Number Of Images Tested = 60000
# Model Accuracy = 0.8123166666666667
# Test loss: 0.5968936085700989
#
# Epoch 1
# Training loss: 0.41595712304115295
# Number Of Images Tested = 10000
# Model Accuracy = 0.8829
# Number Of Images Tested = 60000
# Model Accuracy = 0.8753
# Test loss: 0.3955884277820587
#
# Epoch 2
# Training loss: 0.3280389606952667
# Number Of Images Tested = 10000
# Model Accuracy = 0.9068
# Number Of Images Tested = 60000
# Model Accuracy = 0.9032666666666667
# Test loss: 0.31688743829727173
#
# Epoch 3
# Training loss: 0.2802796959877014
# Number Of Images Tested = 10000
# Model Accuracy = 0.9221
# Number Of Images Tested = 60000
# Model Accuracy = 0.9178333333333333
# Test loss: 0.26975110173225403
#
# Epoch 4
# Training loss: 0.24755536019802094
# Number Of Images Tested = 10000
# Model Accuracy = 0.9264
# Number Of Images Tested = 60000
# Model Accuracy = 0.9270333333333334
# Test loss: 0.2472800463438034
#
# Epoch 5
# Training loss: 0.21519219875335693
# Number Of Images Tested = 10000
# Model Accuracy = 0.9342
# Number Of Images Tested = 60000
# Model Accuracy = 0.9365333333333333
# Test loss: 0.21994145214557648
#
# Epoch 6
# Training loss: 0.1907491683959961
# Number Of Images Tested = 10000
# Model Accuracy = 0.9416
# Number Of Images Tested = 60000
# Model Accuracy = 0.9432166666666667
# Test loss: 0.19743512570858002
#
# Epoch 7
# Training loss: 0.15900233387947083
# Number Of Images Tested = 10000
# Model Accuracy = 0.9491
# Number Of Images Tested = 60000
# Model Accuracy = 0.9523
# Test loss: 0.17025426030158997
#
# Epoch 8
# Training loss: 0.13785657286643982
# Number Of Images Tested = 10000
# Model Accuracy = 0.9523
# Number Of Images Tested = 60000
# Model Accuracy = 0.9590833333333333
# Test loss: 0.15202848613262177
#
# Epoch 9
# Training loss: 0.11724142730236053
# Number Of Images Tested = 10000
# Model Accuracy = 0.9569
# Number Of Images Tested = 60000
# Model Accuracy = 0.9655166666666667
# Test loss: 0.14232514798641205
#
# Epoch 10
# Training loss: 0.09891610592603683
# Number Of Images Tested = 10000
# Model Accuracy = 0.9614
# Number Of Images Tested = 60000
# Model Accuracy = 0.97095
# Test loss: 0.13168057799339294
#
# Epoch 11
# Training loss: 0.08421669900417328
# Number Of Images Tested = 10000
# Model Accuracy = 0.964
# Number Of Images Tested = 60000
# Model Accuracy = 0.9754166666666667
# Test loss: 0.12238331139087677
#
# Epoch 12
# Training loss: 0.07106579840183258
# Number Of Images Tested = 10000
# Model Accuracy = 0.9676
# Number Of Images Tested = 60000
# Model Accuracy = 0.9785333333333334
# Test loss: 0.11352594196796417
#
# Epoch 13
# Training loss: 0.05934344232082367
# Number Of Images Tested = 10000
# Model Accuracy = 0.9681
# Number Of Images Tested = 60000
# Model Accuracy = 0.9815
# Test loss: 0.10717836767435074
#
# Epoch 14
# Training loss: 0.04828807711601257
# Number Of Images Tested = 10000
# Model Accuracy = 0.9714
# Number Of Images Tested = 60000
# Model Accuracy = 0.98525
# Test loss: 0.10240871459245682
#
# Epoch 15
# Training loss: 0.038800325244665146
# Number Of Images Tested = 10000
# Model Accuracy = 0.9713
# Number Of Images Tested = 60000
# Model Accuracy = 0.9887333333333334
# Test loss: 0.10333593934774399
#
# Epoch 16
# Training loss: 0.030153416097164154
# Number Of Images Tested = 10000
# Model Accuracy = 0.9723
# Number Of Images Tested = 60000
# Model Accuracy = 0.9913666666666666
# Test loss: 0.10590827465057373
#
# Epoch 17
# Training loss: 0.02258455567061901
# Number Of Images Tested = 10000
# Model Accuracy = 0.9718
# Number Of Images Tested = 60000
# Model Accuracy = 0.9937
# Test loss: 0.1165621429681778
#
# Epoch 18
# Training loss: 0.015581060200929642
# Number Of Images Tested = 10000
# Model Accuracy = 0.9718
# Number Of Images Tested = 60000
# Model Accuracy = 0.99625
# Test loss: 0.12514373660087585
#
# Epoch 19
# Training loss: 0.01023442018777132
# Number Of Images Tested = 10000
# Model Accuracy = 0.9702
# Number Of Images Tested = 60000
# Model Accuracy = 0.99785
# Test loss: 0.1361512839794159
#
# Epoch 20
# Training loss: 0.006238168105483055
# Number Of Images Tested = 10000
# Model Accuracy = 0.9726
# Number Of Images Tested = 60000
# Model Accuracy = 0.9989666666666667
# Test loss: 0.1541609913110733
#
# Epoch 21
# Training loss: 0.0032739939633756876
# Number Of Images Tested = 10000
# Model Accuracy = 0.9717
# Number Of Images Tested = 60000
# Model Accuracy = 0.9996333333333334
# Test loss: 0.17768947780132294
#
# Epoch 22
# Training loss: 0.0014589520869776607
# Number Of Images Tested = 10000
# Model Accuracy = 0.9722
# Number Of Images Tested = 60000
# Model Accuracy = 0.9999166666666667
# Test loss: 0.1897686868906021
#
# Epoch 23
# Training loss: 0.0005107736214995384
# Number Of Images Tested = 10000
# Model Accuracy = 0.9732
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.21462856233119965
#
# Epoch 24
# Training loss: 0.00017867781571112573
# Number Of Images Tested = 10000
# Model Accuracy = 0.9735
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.24136772751808167
#
# Epoch 25
# Training loss: 5.220604361966252e-05
# Number Of Images Tested = 10000
# Model Accuracy = 0.9742
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.276811420917511
#
# Epoch 26
# Training loss: 1.331335079157725e-05
# Number Of Images Tested = 10000
# Model Accuracy = 0.9741
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.3200543224811554
#
# Epoch 27
# Training loss: 2.0325567220425e-06
# Number Of Images Tested = 10000
# Model Accuracy = 0.9726
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.39405107498168945
#
# Epoch 28
# Training loss: 2.3629775114386575e-07
# Number Of Images Tested = 10000
# Model Accuracy = 0.9732
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.4811857044696808
#
# Epoch 29
# Training loss: 6.015662989966586e-08
# Number Of Images Tested = 10000
# Model Accuracy = 0.9728
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.5272189974784851
#
#
# Training Time (in minutes) = 20.77500125169754
#
#
# Minibatch size:  60000
# History size:  20
# Epoch 0
# Training loss: 0.6740382313728333
# Number Of Images Tested = 10000
# Model Accuracy = 0.7966
# Number Of Images Tested = 60000
# Model Accuracy = 0.7943
# Test loss: 0.6557245254516602
#
# Epoch 1
# Training loss: 0.4158266484737396
# Number Of Images Tested = 10000
# Model Accuracy = 0.8815
# Number Of Images Tested = 60000
# Model Accuracy = 0.87705
# Test loss: 0.40043479204177856
#
# Epoch 2
# Training loss: 0.3409462571144104
# Number Of Images Tested = 10000
# Model Accuracy = 0.9054
# Number Of Images Tested = 60000
# Model Accuracy = 0.8996833333333333
# Test loss: 0.3271978199481964
#
# Epoch 3
# Training loss: 0.2991950511932373
# Number Of Images Tested = 10000
# Model Accuracy = 0.9163
# Number Of Images Tested = 60000
# Model Accuracy = 0.9127166666666666
# Test loss: 0.2879006862640381
#
# Epoch 4
# Training loss: 0.2683561444282532
# Number Of Images Tested = 10000
# Model Accuracy = 0.9247
# Number Of Images Tested = 60000
# Model Accuracy = 0.9227166666666666
# Test loss: 0.2639605700969696
#
# Epoch 5
# Training loss: 0.23383906483650208
# Number Of Images Tested = 10000
# Model Accuracy = 0.9338
# Number Of Images Tested = 60000
# Model Accuracy = 0.9331166666666667
# Test loss: 0.23504699766635895
#
# Epoch 6
# Training loss: 0.20099319517612457
# Number Of Images Tested = 10000
# Model Accuracy = 0.9391
# Number Of Images Tested = 60000
# Model Accuracy = 0.942
# Test loss: 0.21177953481674194
#
# Epoch 7
# Training loss: 0.17369474470615387
# Number Of Images Tested = 10000
# Model Accuracy = 0.9446
# Number Of Images Tested = 60000
# Model Accuracy = 0.94945
# Test loss: 0.18884676694869995
#
# Epoch 8
# Training loss: 0.15055693686008453
# Number Of Images Tested = 10000
# Model Accuracy = 0.9522
# Number Of Images Tested = 60000
# Model Accuracy = 0.95515
# Test loss: 0.1700459122657776
#
# Epoch 9
# Training loss: 0.1295938342809677
# Number Of Images Tested = 10000
# Model Accuracy = 0.9558
# Number Of Images Tested = 60000
# Model Accuracy = 0.96155
# Test loss: 0.15649232268333435
#
# Epoch 10
# Training loss: 0.10938308387994766
# Number Of Images Tested = 10000
# Model Accuracy = 0.9596
# Number Of Images Tested = 60000
# Model Accuracy = 0.9671666666666666
# Test loss: 0.1393825113773346
#
# Epoch 11
# Training loss: 0.09346739202737808
# Number Of Images Tested = 10000
# Model Accuracy = 0.9643
# Number Of Images Tested = 60000
# Model Accuracy = 0.9715833333333334
# Test loss: 0.1291010081768036
#
# Epoch 12
# Training loss: 0.07844505459070206
# Number Of Images Tested = 10000
# Model Accuracy = 0.9654
# Number Of Images Tested = 60000
# Model Accuracy = 0.97625
# Test loss: 0.12074742466211319
#
# Epoch 13
# Training loss: 0.06390082091093063
# Number Of Images Tested = 10000
# Model Accuracy = 0.9688
# Number Of Images Tested = 60000
# Model Accuracy = 0.9809666666666667
# Test loss: 0.11231466382741928
#
# Epoch 14
# Training loss: 0.05206238850951195
# Number Of Images Tested = 10000
# Model Accuracy = 0.969
# Number Of Images Tested = 60000
# Model Accuracy = 0.9840666666666666
# Test loss: 0.10655638575553894
#
# Epoch 15
# Training loss: 0.042238276451826096
# Number Of Images Tested = 10000
# Model Accuracy = 0.9703
# Number Of Images Tested = 60000
# Model Accuracy = 0.9875166666666667
# Test loss: 0.10592757910490036
#
# Epoch 16
# Training loss: 0.032085590064525604
# Number Of Images Tested = 10000
# Model Accuracy = 0.9727
# Number Of Images Tested = 60000
# Model Accuracy = 0.9905333333333334
# Test loss: 0.10681112110614777
#
# Epoch 17
# Training loss: 0.022997697815299034
# Number Of Images Tested = 10000
# Model Accuracy = 0.9724
# Number Of Images Tested = 60000
# Model Accuracy = 0.99355
# Test loss: 0.11444518715143204
#
# Epoch 18
# Training loss: 0.016191311180591583
# Number Of Images Tested = 10000
# Model Accuracy = 0.9716
# Number Of Images Tested = 60000
# Model Accuracy = 0.9959
# Test loss: 0.11801451444625854
#
# Epoch 19
# Training loss: 0.009838812984526157
# Number Of Images Tested = 10000
# Model Accuracy = 0.9719
# Number Of Images Tested = 60000
# Model Accuracy = 0.9982
# Test loss: 0.13241393864154816
#
# Epoch 20
# Training loss: 0.005691662896424532
# Number Of Images Tested = 10000
# Model Accuracy = 0.9723
# Number Of Images Tested = 60000
# Model Accuracy = 0.9993333333333333
# Test loss: 0.15106797218322754
#
# Epoch 21
# Training loss: 0.002746764337643981
# Number Of Images Tested = 10000
# Model Accuracy = 0.9722
# Number Of Images Tested = 60000
# Model Accuracy = 0.9997833333333334
# Test loss: 0.17692773044109344
#
# Epoch 22
# Training loss: 0.0010182580444961786
# Number Of Images Tested = 10000
# Model Accuracy = 0.9719
# Number Of Images Tested = 60000
# Model Accuracy = 0.9999666666666667
# Test loss: 0.20457307994365692
#
# Epoch 23
# Training loss: 0.0003698428045026958
# Number Of Images Tested = 10000
# Model Accuracy = 0.9722
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.22842781245708466
#
# Epoch 24
# Training loss: 8.734236325835809e-05
# Number Of Images Tested = 10000
# Model Accuracy = 0.9716
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.2774272561073303
#
# Epoch 25
# Training loss: 1.970329503819812e-05
# Number Of Images Tested = 10000
# Model Accuracy = 0.9727
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.33167585730552673
#
# Epoch 26
# Training loss: 1.7908973859448452e-06
# Number Of Images Tested = 10000
# Model Accuracy = 0.9718
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.42623817920684814
#
# Epoch 27
# Training loss: 1.3028790135649615e-07
# Number Of Images Tested = 10000
# Model Accuracy = 0.9722
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.5393362045288086
#
# Epoch 28
# Training loss: 6.084602688360974e-08
# Number Of Images Tested = 10000
# Model Accuracy = 0.9723
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.5778489708900452
#
# Epoch 29
# Training loss: 6.084604109446445e-08
# Number Of Images Tested = 10000
# Model Accuracy = 0.9723
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.5778486132621765
#
#
# Training Time (in minutes) = 20.460638292630513

# %%
for bs_index,bs in enumerate(datapoints):
    for hs_index,hs in enumerate(history_size_grid):
        plt.figure(1, figsize = (12,10))
        plt.plot(test_loss_fcnn[hs_index*bs_index+hs_index],label='hs = {}'.format(hs))
        plt.figure(2, figsize = (12,10))
        plt.plot(training_loss_fcnn[hs_index*bs_index+hs_index],label='hs = {}'.format(hs))
        plt.figure(3, figsize = (12,10))
        plt.plot(test_accuracy_fcnn[hs_index*bs_index+hs_index],label='hs = {}'.format(hs))
        plt.figure(4, figsize = (12,10))
        plt.plot(training_accuracy_fcnn[hs_index*bs_index+hs_index],label='hs = {}'.format(hs))

plt.figure(1)
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Fullbatch LBFGS Test loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("LBFGS_test_loss_fcnn.jpg")
plt.figure (2)
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
plt.title('Fullbatch LBFGS Train loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("LBFGS_train_loss_fcnn.jpg")
plt.figure (3)
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.title('Fullbatch LBFGS Test accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("LBFGS_test_acc_fcnn.jpg")
plt.figure (4)
plt.xlabel('Epochs')
plt.ylabel('Train Accuracy')
plt.title('Fullbatch LBFGS Train accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("LBFGS_train_acc_fcnn.jpg")

# %%
np.savetxt('LBFGS_fullbatch_fcNN_trainloss.txt', training_loss_fcnn)
np.savetxt('LBFGS_fullbatch_fcNN_testloss.txt', test_loss_fcnn)
np.savetxt('LBFGS_fullbatch_fcNN_trainacc.txt', training_accuracy_fcnn)
np.savetxt('LBFGS_fullbatch_fcNN_testacc.txt', test_accuracy_fcnn)
np.savetxt('LBFGS_fullbatch_fcNN_times.txt',time_fcnn)

# %% [markdown]
# ### Convolutional neural network

# %%
training_loss_fcnn, test_loss_fcnn,training_accuracy_fcnn, test_accuracy_fcnn, time_fcnn =hyperparameters_tuning_LBFGS_minibatch(trainset,valset,datapoints, history_size_grid, epochs, "CNN")
# Out:
# Minibatch size:  60000
# History size:  5
# Epoch 0
# Training loss: 0.6999953985214233
# Number Of Images Tested = 10000
# Model Accuracy = 0.8506
# Number Of Images Tested = 60000
# Model Accuracy = 0.8411166666666666
# Test loss: 0.5037688612937927
#
# Epoch 1
# Training loss: 0.30367913842201233
# Number Of Images Tested = 10000
# Model Accuracy = 0.9162
# Number Of Images Tested = 60000
# Model Accuracy = 0.9089166666666667
# Test loss: 0.2865537106990814
#
# Epoch 2
# Training loss: 0.17512287199497223
# Number Of Images Tested = 10000
# Model Accuracy = 0.9529
# Number Of Images Tested = 60000
# Model Accuracy = 0.9486
# Test loss: 0.16201716661453247
#
# Epoch 3
# Training loss: 0.10486702620983124
# Number Of Images Tested = 10000
# Model Accuracy = 0.9707
# Number Of Images Tested = 60000
# Model Accuracy = 0.9682
# Test loss: 0.09172610938549042
#
# Epoch 4
# Training loss: 0.07217469811439514
# Number Of Images Tested = 10000
# Model Accuracy = 0.9808
# Number Of Images Tested = 60000
# Model Accuracy = 0.97815
# Test loss: 0.06173286586999893
#
# Epoch 5
# Training loss: 0.052567604929208755
# Number Of Images Tested = 10000
# Model Accuracy = 0.9851
# Number Of Images Tested = 60000
# Model Accuracy = 0.9838
# Test loss: 0.044098347425460815
#
# Epoch 6
# Training loss: 0.04045255854725838
# Number Of Images Tested = 10000
# Model Accuracy = 0.9872
# Number Of Images Tested = 60000
# Model Accuracy = 0.9875166666666667
# Test loss: 0.03787006065249443
#
# Epoch 7
# Training loss: 0.031901124864816666
# Number Of Images Tested = 10000
# Model Accuracy = 0.9886
# Number Of Images Tested = 60000
# Model Accuracy = 0.9903
# Test loss: 0.03572692722082138
#
# Epoch 8
# Training loss: 0.023900045081973076
# Number Of Images Tested = 10000
# Model Accuracy = 0.9898
# Number Of Images Tested = 60000
# Model Accuracy = 0.9927166666666667
# Test loss: 0.031903669238090515
#
# Epoch 9
# Training loss: 0.016352344304323196
# Number Of Images Tested = 10000
# Model Accuracy = 0.9905
# Number Of Images Tested = 60000
# Model Accuracy = 0.9948666666666667
# Test loss: 0.031092321500182152
#
# Epoch 10
# Training loss: 0.01127610169351101
# Number Of Images Tested = 10000
# Model Accuracy = 0.9907
# Number Of Images Tested = 60000
# Model Accuracy = 0.9965666666666667
# Test loss: 0.03016057424247265
#
# Epoch 11
# Training loss: 0.0075110746547579765
# Number Of Images Tested = 10000
# Model Accuracy = 0.9909
# Number Of Images Tested = 60000
# Model Accuracy = 0.9981166666666667
# Test loss: 0.03168254718184471
#
# Epoch 12
# Training loss: 0.004534789826720953
# Number Of Images Tested = 10000
# Model Accuracy = 0.9902
# Number Of Images Tested = 60000
# Model Accuracy = 0.9988166666666667
# Test loss: 0.03698495402932167
#
# Epoch 13
# Training loss: 0.0024831201881170273
# Number Of Images Tested = 10000
# Model Accuracy = 0.9907
# Number Of Images Tested = 60000
# Model Accuracy = 0.9995333333333334
# Test loss: 0.039244960993528366
#
# Epoch 14
# Training loss: 0.001311848289333284
# Number Of Images Tested = 10000
# Model Accuracy = 0.9911
# Number Of Images Tested = 60000
# Model Accuracy = 0.99985
# Test loss: 0.047184400260448456
#
#
# Training Time (in minutes) = 215.41551560163498
# Minibatch size:  60000
# History size:  10
# Epoch 0
# Training loss: 0.7064737677574158
# Number Of Images Tested = 10000
# Model Accuracy = 0.8344
# Number Of Images Tested = 60000
# Model Accuracy = 0.8233166666666667
# Test loss: 0.5328778028488159
#
# Epoch 1
# Training loss: 0.24405208230018616
# Number Of Images Tested = 10000
# Model Accuracy = 0.9332
# Number Of Images Tested = 60000
# Model Accuracy = 0.9283
# Test loss: 0.23208190500736237
#
# Epoch 2
# Training loss: 0.12949365377426147
# Number Of Images Tested = 10000
# Model Accuracy = 0.9658
# Number Of Images Tested = 60000
# Model Accuracy = 0.9608333333333333
# Test loss: 0.114823117852211
#
# Epoch 3
# Training loss: 0.078824982047081
# Number Of Images Tested = 10000
# Model Accuracy = 0.9801
# Number Of Images Tested = 60000
# Model Accuracy = 0.9767
# Test loss: 0.06727852672338486
#
# Epoch 4
# Training loss: 0.05816340446472168
# Number Of Images Tested = 10000
# Model Accuracy = 0.9834
# Number Of Images Tested = 60000
# Model Accuracy = 0.9825
# Test loss: 0.050408631563186646
#
# Epoch 5
# Training loss: 0.043478429317474365
# Number Of Images Tested = 10000
# Model Accuracy = 0.9855
# Number Of Images Tested = 60000
# Model Accuracy = 0.9870666666666666
# Test loss: 0.04076746478676796
#
# Epoch 6
# Training loss: 0.031665507704019547
# Number Of Images Tested = 10000
# Model Accuracy = 0.9891
# Number Of Images Tested = 60000
# Model Accuracy = 0.99065
# Test loss: 0.03257673606276512
#
# Epoch 7
# Training loss: 0.02365822158753872
# Number Of Images Tested = 10000
# Model Accuracy = 0.9892
# Number Of Images Tested = 60000
# Model Accuracy = 0.9929
# Test loss: 0.03155840188264847
#
# Epoch 8
# Training loss: 0.01786067895591259
# Number Of Images Tested = 10000
# Model Accuracy = 0.9899
# Number Of Images Tested = 60000
# Model Accuracy = 0.9944666666666667
# Test loss: 0.030266454443335533
#
# Epoch 9
# Training loss: 0.01256995927542448
# Number Of Images Tested = 10000
# Model Accuracy = 0.9908
# Number Of Images Tested = 60000
# Model Accuracy = 0.9963
# Test loss: 0.027776647359132767
#
# Epoch 10
# Training loss: 0.0077083054929971695
# Number Of Images Tested = 10000
# Model Accuracy = 0.9917
# Number Of Images Tested = 60000
# Model Accuracy = 0.99815
# Test loss: 0.02810434252023697
#
# Epoch 11
# Training loss: 0.005009026732295752
# Number Of Images Tested = 10000
# Model Accuracy = 0.9918
# Number Of Images Tested = 60000
# Model Accuracy = 0.9988666666666667
# Test loss: 0.03215067833662033
#
# Epoch 12
# Training loss: 0.003236585296690464
# Number Of Images Tested = 10000
# Model Accuracy = 0.9907
# Number Of Images Tested = 60000
# Model Accuracy = 0.9994666666666666
# Test loss: 0.03711148723959923
#
# Epoch 13
# Training loss: 0.001875508576631546
# Number Of Images Tested = 10000
# Model Accuracy = 0.9909
# Number Of Images Tested = 60000
# Model Accuracy = 0.9997666666666667
# Test loss: 0.04153279960155487
#
# Epoch 14
# Training loss: 0.0009876193944364786
# Number Of Images Tested = 10000
# Model Accuracy = 0.9903
# Number Of Images Tested = 60000
# Model Accuracy = 0.99985
# Test loss: 0.04711337015032768
#
#
# Training Time (in minutes) = 215.77097318172454
# Minibatch size:  60000
# History size:  20
# Epoch 0
# Training loss: 0.8300126194953918
# Number Of Images Tested = 10000
# Model Accuracy = 0.8192
# Number Of Images Tested = 60000
# Model Accuracy = 0.8147166666666666
# Test loss: 0.6095380783081055
#
# Epoch 1
# Training loss: 0.3591666519641876
# Number Of Images Tested = 10000
# Model Accuracy = 0.9002
# Number Of Images Tested = 60000
# Model Accuracy = 0.8952666666666667
# Test loss: 0.3448726236820221
#
# Epoch 2
# Training loss: 0.18712358176708221
# Number Of Images Tested = 10000
# Model Accuracy = 0.9467
# Number Of Images Tested = 60000
# Model Accuracy = 0.9434833333333333
# Test loss: 0.17292241752147675
#
# Epoch 3
# Training loss: 0.09306603670120239
# Number Of Images Tested = 10000
# Model Accuracy = 0.9755
# Number Of Images Tested = 60000
# Model Accuracy = 0.9717833333333333
# Test loss: 0.08021948486566544
#
# Epoch 4
# Training loss: 0.06430871039628983
# Number Of Images Tested = 10000
# Model Accuracy = 0.9812
# Number Of Images Tested = 60000
# Model Accuracy = 0.9802333333333333
# Test loss: 0.05621182918548584
#
# Epoch 5
# Training loss: 0.04236334189772606
# Number Of Images Tested = 10000
# Model Accuracy = 0.9862
# Number Of Images Tested = 60000
# Model Accuracy = 0.9868
# Test loss: 0.03746069222688675
#
# Epoch 6
# Training loss: 0.03262757137417793
# Number Of Images Tested = 10000
# Model Accuracy = 0.9887
# Number Of Images Tested = 60000
# Model Accuracy = 0.99025
# Test loss: 0.03349430486559868
#
# Epoch 7
# Training loss: 0.024201780557632446
# Number Of Images Tested = 10000
# Model Accuracy = 0.9894
# Number Of Images Tested = 60000
# Model Accuracy = 0.9926166666666667
# Test loss: 0.03096780925989151
#
# Epoch 8
# Training loss: 0.0172919649630785
# Number Of Images Tested = 10000
# Model Accuracy = 0.9902
# Number Of Images Tested = 60000
# Model Accuracy = 0.9946166666666667
# Test loss: 0.029359912499785423
#
# Epoch 9
# Training loss: 0.01068940106779337
# Number Of Images Tested = 10000
# Model Accuracy = 0.9912
# Number Of Images Tested = 60000
# Model Accuracy = 0.9965333333333334
# Test loss: 0.03015068918466568
#
# Epoch 10
# Training loss: 0.006534612737596035
# Number Of Images Tested = 10000
# Model Accuracy = 0.9902
# Number Of Images Tested = 60000
# Model Accuracy = 0.9983166666666666
# Test loss: 0.03530988469719887
#
# Epoch 11
# Training loss: 0.003132600337266922
# Number Of Images Tested = 10000
# Model Accuracy = 0.9907
# Number Of Images Tested = 60000
# Model Accuracy = 0.9994666666666666
# Test loss: 0.04815584793686867
#
# Epoch 12
# Training loss: 0.001611637882888317
# Number Of Images Tested = 10000
# Model Accuracy = 0.9908
# Number Of Images Tested = 60000
# Model Accuracy = 0.9997833333333334
# Test loss: 0.05999729782342911
#
# Epoch 13
# Training loss: 0.00042440343531779945
# Number Of Images Tested = 10000
# Model Accuracy = 0.9906
# Number Of Images Tested = 60000
# Model Accuracy = 0.9999833333333333
# Test loss: 0.06830162554979324
#
# Epoch 14
# Training loss: 7.963576354086399e-05
# Number Of Images Tested = 10000
# Model Accuracy = 0.9907
# Number Of Images Tested = 60000
# Model Accuracy = 1.0
# Test loss: 0.08329416811466217
#
#
# Training Time (in minutes) = 243.54828588167825

# %%
for bs_index,bs in enumerate(datapoints):
    for hs_index,hs in enumerate(history_size_grid):
        plt.figure(1, figsize = (12,10))
        plt.plot(test_loss_fcnn[hs_index*bs_index+hs_index],label='hs = {}'.format(hs))
        plt.figure(2, figsize = (12,10))
        plt.plot(training_loss_fcnn[hs_index*bs_index+hs_index],label='hs = {}'.format(hs))
        plt.figure(3, figsize = (12,10))
        plt.plot(test_accuracy_fcnn[hs_index*bs_index+hs_index],label='hs = {}'.format(hs))
        plt.figure(4, figsize = (12,10))
        plt.plot(training_accuracy_fcnn[hs_index*bs_index+hs_index],label='hs = {}'.format(hs))

plt.figure(1)
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Fullbatch LBFGS Test loss in CNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("LBFGS_test_loss_cnn.jpg")
plt.figure (2)
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
plt.title('Fullbatch LBFGS Train loss in CNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("LBFGS_train_loss_cnn.jpg")
plt.figure (3)
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.title('Fullbatch LBFGS Test Accuracy in CNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("LBFGS_test_acc_cnn.jpg")
plt.figure (4)
plt.xlabel('Epochs')
plt.ylabel('Train Accuracy')
plt.title('Fullbatch LBFGS Train Accuracy in CNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("LBFGS_train_acc_cnn.jpg")

# %%
np.savetxt('LBFGS_minibatch_CNN_trainloss.txt', training_loss_fcnn)
np.savetxt('LBFGS_minibatch_CNN_testloss.txt', test_loss_fcnn)
np.savetxt('LBFGS_minibatch_CNN_trainacc.txt', training_accuracy_fcnn)
np.savetxt('LBFGS_minibatch_CNN_testacc.txt', test_accuracy])
np.savetxt('LBFGS_minibatch_CNN_times.txt',time)
