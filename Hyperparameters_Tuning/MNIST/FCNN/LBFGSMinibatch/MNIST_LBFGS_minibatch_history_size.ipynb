# %%
# %matplotlib inline

import numpy as np
import torch
import matplotlib.pyplot as plt

#from helper2 import generate_dataset, visualize_one_dataset, visualize_datasets, predict_grid, visualize_predictions
from torch.utils import data

# %load_ext autoreload
# %autoreload 2

import torchvision

from time import time
from torchvision import datasets, transforms
from torch import nn, optim

from helpers_opt_parameters import *
from sdlbfgs import *

# %%
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])

# %% [markdown]
# ### MNIST dataset
# The MNIST dataset is loaded.

# %%
trainset = datasets.MNIST('', download=True, train=True, transform=transform)
valset = datasets.MNIST('PATH_TO_STORE_TESTSET', download=True, train=False, transform=transform)

# %%
print("Training and test sets information is displayed.\n\n")
print("Trainset:\n",trainset)
print("Testset:\n",valset)
# Out:
# Training and test sets information is displayed.
#
#
# Trainset:
#  Dataset MNIST
#     Number of datapoints: 60000
#     Root location:
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5,), std=(0.5,))
#            )
# Testset:
#  Dataset MNIST
#     Number of datapoints: 10000
#     Root location: PATH_TO_STORE_TESTSET
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5,), std=(0.5,))
#            )

# %% [markdown]
# # LBFGS mini-batch hyperparameters tuning

# %%
minibatch_size_grid=[32,64,128,512,1024]
history_size_grid=[10,20]

# %%
epochs = 30

# %% [markdown]
# ### Fully connected network

# %%
training_loss_fcnn, test_loss_fcnn,training_accuracy_fcnn, test_accuracy_fcnn, time_fcnn =hyperparameters_tuning_LBFGS_minibatch(trainset,valset,minibatch_size_grid, history_size_grid, epochs, "FCNN")
# Out:
# Minibatch size:  32
# History size:  10
# Epoch 0
# Training loss: 0.0836352018814888
# Number Of Images Tested = 10000
# Model Accuracy = 0.8433
# Number Of Images Tested = 60000
# Model Accuracy = 0.84045
# Test loss: 1.0030304225364004
#
# Epoch 1
# Training loss: 0.37237036967377884
# Number Of Images Tested = 10000
# Model Accuracy = 0.6916
# Number Of Images Tested = 60000
# Model Accuracy = 0.6828166666666666
# Test loss: 1.3217415851525987
#
# Epoch 2
# Training loss: 0.7905657754670673
# Number Of Images Tested = 10000
# Model Accuracy = 0.8079
# Number Of Images Tested = 60000
# Model Accuracy = 0.79685
# Test loss: 1.9166926893468101
#
# Epoch 3
# Training loss: 1.2605648162980874
# Number Of Images Tested = 10000
# Model Accuracy = 0.1028
# Number Of Images Tested = 60000
# Model Accuracy = 0.10441666666666667
# Test loss: 2.4521198973488123
#
# Epoch 4
# Training loss: 2.1633185377756754
# Number Of Images Tested = 10000
# Model Accuracy = 0.1032
# Number Of Images Tested = 60000
# Model Accuracy = 0.0993
# Test loss: 2.440556993880592
#
# Epoch 5
# Training loss: 2.1646912342707316
# Number Of Images Tested = 10000
# Model Accuracy = 0.1009
# Number Of Images Tested = 60000
# Model Accuracy = 0.09915
# Test loss: 2.4348059066187457
#
# Epoch 6
# Training loss: 2.160823246765137
# Number Of Images Tested = 10000
# Model Accuracy = 0.1009
# Number Of Images Tested = 60000
# Model Accuracy = 0.09915
# Test loss: 2.610276712777135
#
# Epoch 7
# Training loss: 2.1690566775639852
# Number Of Images Tested = 10000
# Model Accuracy = 0.0958
# Number Of Images Tested = 60000
# Model Accuracy = 0.09863333333333334
# Test loss: 2.4091699389984815
#
# Epoch 8
# Training loss: 2.189637612660726
# Number Of Images Tested = 10000
# Model Accuracy = 0.0892
# Number Of Images Tested = 60000
# Model Accuracy = 0.09035
# Test loss: 2.4265497385884247
#
# Epoch 9
# Training loss: 2.1652790590286255
# Number Of Images Tested = 10000
# Model Accuracy = 0.1135
# Number Of Images Tested = 60000
# Model Accuracy = 0.11236666666666667
# Test loss: 2.4044981178003377
#
# Epoch 10
# Training loss: 2.1603203824361166
# Number Of Images Tested = 10000
# Model Accuracy = 0.098
# Number Of Images Tested = 60000
# Model Accuracy = 0.09871666666666666
# Test loss: 2.4103217620057418
#
# Epoch 11
# Training loss: 2.16182424697876
# Number Of Images Tested = 10000
# Model Accuracy = 0.1032
# Number Of Images Tested = 60000
# Model Accuracy = 0.0993
# Test loss: 2.391082512304044
#
# Epoch 12
# Training loss: 2.1582090608596802
# Number Of Images Tested = 10000
# Model Accuracy = 0.101
# Number Of Images Tested = 60000
# Model Accuracy = 0.10218333333333333
# Test loss: 2.5320758453954144
#
# Epoch 13
# Training loss: 2.178718223317464
# Number Of Images Tested = 10000
# Model Accuracy = 0.098
# Number Of Images Tested = 60000
# Model Accuracy = 0.09871666666666666
# Test loss: 2.5101882040310213
#
# Epoch 14
# Training loss: 2.1635760938008626
# Number Of Images Tested = 10000
# Model Accuracy = 0.0974
# Number Of Images Tested = 60000
# Model Accuracy = 0.09751666666666667
# Test loss: 2.464446249861306
#
# Epoch 15
# Training loss: 2.1570952023188275
# Number Of Images Tested = 10000
# Model Accuracy = 0.0974
# Number Of Images Tested = 60000
# Model Accuracy = 0.09751666666666667
# Test loss: 3.0196178431708973
#
# Epoch 16
# Training loss: 2.1677503703435264
# Number Of Images Tested = 10000
# Model Accuracy = 0.1032
# Number Of Images Tested = 60000
# Model Accuracy = 0.0993
# Test loss: 2.4157801390455935
#
# Epoch 17
# Training loss: 2.1845879231770833
# Number Of Images Tested = 10000
# Model Accuracy = 0.0958
# Number Of Images Tested = 60000
# Model Accuracy = 0.09863333333333334
# Test loss: 2.4700008207997577
#
# Epoch 18
# Training loss: 2.1556930926005045
# Number Of Images Tested = 10000
# Model Accuracy = 0.0958
# Number Of Images Tested = 60000
# Model Accuracy = 0.09863333333333334
# Test loss: 2.52100670299591
#
# Epoch 19
# Training loss: 2.1591930433273316
# Number Of Images Tested = 10000
# Model Accuracy = 0.1135
# Number Of Images Tested = 60000
# Model Accuracy = 0.11236666666666667
# Test loss: 2.8624624337632056
#
# Epoch 20
# Training loss: 2.1647721610387167
# Number Of Images Tested = 10000
# Model Accuracy = 0.1135
# Number Of Images Tested = 60000
# Model Accuracy = 0.11236666666666667
# Test loss: 2.414768055985911
#
# Epoch 21
# Training loss: 2.158267398961385
# Number Of Images Tested = 10000
# Model Accuracy = 0.101
# Number Of Images Tested = 60000
# Model Accuracy = 0.10218333333333333
# Test loss: 2.9948760114919644
#
# Epoch 22
# Training loss: 2.1656943234761554
# Number Of Images Tested = 10000
# Model Accuracy = 0.1009
# Number Of Images Tested = 60000
# Model Accuracy = 0.09915
# Test loss: 2.326794897024624
#
# Epoch 23
# Training loss: 2.1598984859466555
# Number Of Images Tested = 10000
# Model Accuracy = 0.1032
# Number Of Images Tested = 60000
# Model Accuracy = 0.0993
# Test loss: 2.8260318615946907
#
# Epoch 24
# Training loss: 2.166589298947652
# Number Of Images Tested = 10000
# Model Accuracy = 0.0958
# Number Of Images Tested = 60000
# Model Accuracy = 0.09863333333333334
# Test loss: 2.40710164106692
#
# Epoch 25
# Training loss: 2.1682633569081626
# Number Of Images Tested = 10000
# Model Accuracy = 0.1028
# Number Of Images Tested = 60000
# Model Accuracy = 0.10441666666666667
# Test loss: 2.371592517858877
#
# Epoch 26
# Training loss: 2.1615667577107747
# Number Of Images Tested = 10000
# Model Accuracy = 0.1135
# Number Of Images Tested = 60000
# Model Accuracy = 0.11236666666666667
# Test loss: 2.8795942894566937
#
# Epoch 27
# Training loss: 2.161422984377543
# Number Of Images Tested = 10000
# Model Accuracy = 0.1135
# Number Of Images Tested = 60000
# Model Accuracy = 0.11236666666666667
# Test loss: 2.8104826398550893
#
# Epoch 28
# Training loss: 2.1624029490152994
# Number Of Images Tested = 10000
# Model Accuracy = 0.0958
# Number Of Images Tested = 60000
# Model Accuracy = 0.09863333333333334
# Test loss: 2.5286800320536944
#
# Epoch 29
# Training loss: 2.158271323267619
# Number Of Images Tested = 10000
# Model Accuracy = 0.1009
# Number Of Images Tested = 60000
# Model Accuracy = 0.09915
# Test loss: 2.9337622875603624
#
#
# Training Time (in minutes) = 55.04930823644002
#
#
# Minibatch size:  32
# History size:  20
# Epoch 0
# Training loss: 0.6826410835523838
# Number Of Images Tested = 10000
# Model Accuracy = 0.2071
# Number Of Images Tested = 60000
# Model Accuracy = 0.20895
# Test loss: 3.4796489210555346
#
# Epoch 1
# Training loss: 1.7152217518806459
# Number Of Images Tested = 10000
# Model Accuracy = 0.4145
# Number Of Images Tested = 60000
# Model Accuracy = 0.4120333333333333
# Test loss: 2.312573155084738
#
# Epoch 2
# Training loss: 1.6055480198224386
# Number Of Images Tested = 10000
# Model Accuracy = 0.0993
# Number Of Images Tested = 60000
# Model Accuracy = 0.10291666666666667
# Test loss: 10.302435627379737
#
# Epoch 3
# Training loss: 1.632995880126953
# Number Of Images Tested = 10000
# Model Accuracy = 0.3604
# Number Of Images Tested = 60000
# Model Accuracy = 0.36105
# Test loss: 2.060997167334389
#
# Epoch 4
# Training loss: 1.7867879821777344
# Number Of Images Tested = 10000
# Model Accuracy = 0.1843
# Number Of Images Tested = 60000
# Model Accuracy = 0.18353333333333333
# Test loss: 2.545780911613196
#
# Epoch 5
# Training loss: 2.203460873031616
# Number Of Images Tested = 10000
# Model Accuracy = 0.1749
# Number Of Images Tested = 60000
# Model Accuracy = 0.17241666666666666
# Test loss: 2.426782421410655
#
# Epoch 6
# Training loss: 2.3238874684651694
# Number Of Images Tested = 10000
# Model Accuracy = 0.1189
# Number Of Images Tested = 60000
# Model Accuracy = 0.11676666666666667
# Test loss: 2.9667189814412174
#
# Epoch 7
# Training loss: 7.223731345240275
# Number Of Images Tested = 10000
# Model Accuracy = 0.1485
# Number Of Images Tested = 60000
# Model Accuracy = 0.15535
# Test loss: 2.6127756434126783
#
# Epoch 8
# Training loss: 3.5983959484736125
# Number Of Images Tested = 10000
# Model Accuracy = 0.1304
# Number Of Images Tested = 60000
# Model Accuracy = 0.12933333333333333
# Test loss: 5.171831511080074
#
# Epoch 9
# Training loss: 2.2729571322758995
# Number Of Images Tested = 10000
# Model Accuracy = 0.1791
# Number Of Images Tested = 60000
# Model Accuracy = 0.17683333333333334
# Test loss: 2.7687362200155046
#
# Epoch 10
# Training loss: 2.37100637550354
# Number Of Images Tested = 10000
# Model Accuracy = 0.2262
# Number Of Images Tested = 60000
# Model Accuracy = 0.21988333333333332
# Test loss: 2.158274457477533
#
# Epoch 11
# Training loss: 1.9557262406667073
# Number Of Images Tested = 10000
# Model Accuracy = 0.1113
# Number Of Images Tested = 60000
# Model Accuracy = 0.10768333333333334
# Test loss: 2.4318119595987726
#
# Epoch 12
# Training loss: 2.033678531265259
# Number Of Images Tested = 10000
# Model Accuracy = 0.1755
# Number Of Images Tested = 60000
# Model Accuracy = 0.17156666666666667
# Test loss: 4.763197903435071
#
# Epoch 13
# Training loss: 2.7893284410794577
# Number Of Images Tested = 10000
# Model Accuracy = 0.2056
# Number Of Images Tested = 60000
# Model Accuracy = 0.19991666666666666
# Test loss: 10.305581581859162
#
# Epoch 14
# Training loss: 2.1071128092447915
# Number Of Images Tested = 10000
# Model Accuracy = 0.2547
# Number Of Images Tested = 60000
# Model Accuracy = 0.25226666666666664
# Test loss: 2.1798834400816847
#
# Epoch 15
# Training loss: 1.7744437185287476
# Number Of Images Tested = 10000
# Model Accuracy = 0.2593
# Number Of Images Tested = 60000
# Model Accuracy = 0.2553
# Test loss: 2.289781645464059
#
# Epoch 16
# Training loss: 1.7470885709762574
# Number Of Images Tested = 10000
# Model Accuracy = 0.2519
# Number Of Images Tested = 60000
# Model Accuracy = 0.24585
# Test loss: 2.334279596996003
#
# Epoch 17
# Training loss: 1.7483918006896972
# Number Of Images Tested = 10000
# Model Accuracy = 0.208
# Number Of Images Tested = 60000
# Model Accuracy = 0.20643333333333333
# Test loss: 2.1958827694384055
#
# Epoch 18
# Training loss: 1.74273796043396
# Number Of Images Tested = 10000
# Model Accuracy = 0.2729
# Number Of Images Tested = 60000
# Model Accuracy = 0.2682833333333333
# Test loss: 2.2300166245847466
#
# Epoch 19
# Training loss: 1.7916013912200928
# Number Of Images Tested = 10000
# Model Accuracy = 0.2524
# Number Of Images Tested = 60000
# Model Accuracy = 0.2516833333333333
# Test loss: 2.035095065927353
#
# Epoch 20
# Training loss: 1.7358457195281982
# Number Of Images Tested = 10000
# Model Accuracy = 0.2708
# Number Of Images Tested = 60000
# Model Accuracy = 0.2689166666666667
# Test loss: 2.4395169739525158
#
# Epoch 21
# Training loss: 1.7408150947570802
# Number Of Images Tested = 10000
# Model Accuracy = 0.2723
# Number Of Images Tested = 60000
# Model Accuracy = 0.26416666666666666
# Test loss: 2.0836526075491126
#
# Epoch 22
# Training loss: 1.7094472819010416
# Number Of Images Tested = 10000
# Model Accuracy = 0.2415
# Number Of Images Tested = 60000
# Model Accuracy = 0.24185
# Test loss: 2.079070510574804
#
# Epoch 23
# Training loss: 1.7136693509419758
# Number Of Images Tested = 10000
# Model Accuracy = 0.2272
# Number Of Images Tested = 60000
# Model Accuracy = 0.21995
# Test loss: 2.1611656167636664
#
# Epoch 24
# Training loss: 1.7047365730921427
# Number Of Images Tested = 10000
# Model Accuracy = 0.3009
# Number Of Images Tested = 60000
# Model Accuracy = 0.2950833333333333
# Test loss: 2.269163315288556
#
# Epoch 25
# Training loss: 1.6780650960286458
# Number Of Images Tested = 10000
# Model Accuracy = 0.2847
# Number Of Images Tested = 60000
# Model Accuracy = 0.2819
# Test loss: 2.162100826589444
#
# Epoch 26
# Training loss: 1.6782436816851298
# Number Of Images Tested = 10000
# Model Accuracy = 0.2499
# Number Of Images Tested = 60000
# Model Accuracy = 0.24426666666666666
# Test loss: 2.0172619872961564
#
# Epoch 27
# Training loss: 1.6724343221664428
# Number Of Images Tested = 10000
# Model Accuracy = 0.3007
# Number Of Images Tested = 60000
# Model Accuracy = 0.2961
# Test loss: 2.0954173494832586
#
# Epoch 28
# Training loss: 1.672820578289032
# Number Of Images Tested = 10000
# Model Accuracy = 0.2924
# Number Of Images Tested = 60000
# Model Accuracy = 0.2851666666666667
# Test loss: 2.055993361975819
#
# Epoch 29
# Training loss: 1.6681786256154378
# Number Of Images Tested = 10000
# Model Accuracy = 0.2876
# Number Of Images Tested = 60000
# Model Accuracy = 0.27465
# Test loss: 1.9308320420999496
#
#
# Training Time (in minutes) = 163.0076798915863
#
#
# Minibatch size:  64
# History size:  10
# Epoch 0
# Training loss: 0.06175124865904445
# Number Of Images Tested = 10000
# Model Accuracy = 0.8608
# Number Of Images Tested = 60000
# Model Accuracy = 0.8596833333333334
# Test loss: 0.6253786183727584
#
# Epoch 1
# Training loss: 0.0499883001579416
# Number Of Images Tested = 10000
# Model Accuracy = 0.9097
# Number Of Images Tested = 60000
# Model Accuracy = 0.9084666666666666
# Test loss: 0.6799243381187604
#
# Epoch 2
# Training loss: 0.059638183788097154
# Number Of Images Tested = 10000
# Model Accuracy = 0.9027
# Number Of Images Tested = 60000
# Model Accuracy = 0.9065333333333333
# Test loss: 0.6548331171203001
#
# Epoch 3
# Training loss: 0.06477493859773813
# Number Of Images Tested = 10000
# Model Accuracy = 0.9164
# Number Of Images Tested = 60000
# Model Accuracy = 0.91555
# Test loss: 0.6879039855234942
#
# Epoch 4
# Training loss: 0.07343205663883108
# Number Of Images Tested = 10000
# Model Accuracy = 0.9053
# Number Of Images Tested = 60000
# Model Accuracy = 0.9022666666666667
# Test loss: 0.9329940340389753
#
# Epoch 5
# Training loss: 0.08826703222054698
# Number Of Images Tested = 10000
# Model Accuracy = 0.9025
# Number Of Images Tested = 60000
# Model Accuracy = 0.9037666666666667
# Test loss: 0.9538823871570787
#
# Epoch 6
# Training loss: 0.11215568996585804
# Number Of Images Tested = 10000
# Model Accuracy = 0.8907
# Number Of Images Tested = 60000
# Model Accuracy = 0.8941166666666667
# Test loss: 0.6843378305625004
#
# Epoch 7
# Training loss: 0.12921005084746173
# Number Of Images Tested = 10000
# Model Accuracy = 0.8414
# Number Of Images Tested = 60000
# Model Accuracy = 0.8438333333333333
# Test loss: 1.408533746467838
#
# Epoch 8
# Training loss: 0.1415024139873526
# Number Of Images Tested = 10000
# Model Accuracy = 0.8713
# Number Of Images Tested = 60000
# Model Accuracy = 0.8728833333333333
# Test loss: 1.1208476692343214
#
# Epoch 9
# Training loss: 0.16950605951706826
# Number Of Images Tested = 10000
# Model Accuracy = 0.9176
# Number Of Images Tested = 60000
# Model Accuracy = 0.9208833333333334
# Test loss: 0.7174377837900523
#
# Epoch 10
# Training loss: 0.1983006776257203
# Number Of Images Tested = 10000
# Model Accuracy = 0.8847
# Number Of Images Tested = 60000
# Model Accuracy = 0.886
# Test loss: 0.7347963349834369
#
# Epoch 11
# Training loss: 0.19920029247485
# Number Of Images Tested = 10000
# Model Accuracy = 0.8506
# Number Of Images Tested = 60000
# Model Accuracy = 0.8535166666666667
# Test loss: 1.072377552177496
#
# Epoch 12
# Training loss: 0.22367711267690701
# Number Of Images Tested = 10000
# Model Accuracy = 0.903
# Number Of Images Tested = 60000
# Model Accuracy = 0.9032166666666667
# Test loss: 1.0193647249204338
#
# Epoch 13
# Training loss: 0.23033990693626824
# Number Of Images Tested = 10000
# Model Accuracy = 0.7944
# Number Of Images Tested = 60000
# Model Accuracy = 0.7972
# Test loss: 1.615169194093935
#
# Epoch 14
# Training loss: 0.2665903043114489
# Number Of Images Tested = 10000
# Model Accuracy = 0.8231
# Number Of Images Tested = 60000
# Model Accuracy = 0.8209166666666666
# Test loss: 2.145912987411402
#
# Epoch 15
# Training loss: 0.2781632255894931
# Number Of Images Tested = 10000
# Model Accuracy = 0.8719
# Number Of Images Tested = 60000
# Model Accuracy = 0.8722
# Test loss: 0.6832788382081469
#
# Epoch 16
# Training loss: 0.27727515501760486
# Number Of Images Tested = 10000
# Model Accuracy = 0.7897
# Number Of Images Tested = 60000
# Model Accuracy = 0.7907
# Test loss: 1.4339363721145946
#
# Epoch 17
# Training loss: 0.32066898655250864
# Number Of Images Tested = 10000
# Model Accuracy = 0.8919
# Number Of Images Tested = 60000
# Model Accuracy = 0.8977666666666667
# Test loss: 0.990618907437203
#
# Epoch 18
# Training loss: 0.3335591489731019
# Number Of Images Tested = 10000
# Model Accuracy = 0.7683
# Number Of Images Tested = 60000
# Model Accuracy = 0.77135
# Test loss: 1.021236515348884
#
# Epoch 19
# Training loss: 0.4248296646262283
# Number Of Images Tested = 10000
# Model Accuracy = 0.7914
# Number Of Images Tested = 60000
# Model Accuracy = 0.7955666666666666
# Test loss: 1.0661667680284779
#
# Epoch 20
# Training loss: 0.3700688560096138
# Number Of Images Tested = 10000
# Model Accuracy = 0.8984
# Number Of Images Tested = 60000
# Model Accuracy = 0.89855
# Test loss: 1.1316532696698123
#
# Epoch 21
# Training loss: 0.8155836837767347
# Number Of Images Tested = 10000
# Model Accuracy = 0.5279
# Number Of Images Tested = 60000
# Model Accuracy = 0.5312333333333333
# Test loss: 2.4089116340230223
#
# Epoch 22
# Training loss: 0.9052258466225444
# Number Of Images Tested = 10000
# Model Accuracy = 0.6014
# Number Of Images Tested = 60000
# Model Accuracy = 0.60545
# Test loss: 5.500400265690628
#
# Epoch 23
# Training loss: 0.8481988395486814
# Number Of Images Tested = 10000
# Model Accuracy = 0.6835
# Number Of Images Tested = 60000
# Model Accuracy = 0.6808
# Test loss: 1.1638358778255
#
# Epoch 24
# Training loss: 0.8615892545373709
# Number Of Images Tested = 10000
# Model Accuracy = 0.6315
# Number Of Images Tested = 60000
# Model Accuracy = 0.6313833333333333
# Test loss: 1.1162011904321658
#
# Epoch 25
# Training loss: 0.848401656727801
# Number Of Images Tested = 10000
# Model Accuracy = 0.5967
# Number Of Images Tested = 60000
# Model Accuracy = 0.60665
# Test loss: 1.6154610571587922
#
# Epoch 26
# Training loss: 0.9510386937589788
# Number Of Images Tested = 10000
# Model Accuracy = 0.6175
# Number Of Images Tested = 60000
# Model Accuracy = 0.62015
# Test loss: 2.118011476507612
#
# Epoch 27
# Training loss: 0.9646541243041756
# Number Of Images Tested = 10000
# Model Accuracy = 0.6108
# Number Of Images Tested = 60000
# Model Accuracy = 0.6149
# Test loss: 2.410075871428107
#
# Epoch 28
# Training loss: 0.9446537958851247
# Number Of Images Tested = 10000
# Model Accuracy = 0.5754
# Number Of Images Tested = 60000
# Model Accuracy = 0.5755
# Test loss: 1.65709557996434
#
# Epoch 29
# Training loss: 0.8271318209895702
# Number Of Images Tested = 10000
# Model Accuracy = 0.7111
# Number Of Images Tested = 60000
# Model Accuracy = 0.7146
# Test loss: 1.2487956422149755
#
#
# Training Time (in minutes) = 36.508118446667986
#
#
# Minibatch size:  64
# History size:  20
# Epoch 0
# Training loss: 0.053012050799314175
# Number Of Images Tested = 10000
# Model Accuracy = 0.8419
# Number Of Images Tested = 60000
# Model Accuracy = 0.8339333333333333
# Test loss: 1.599513294400683
#
# Epoch 1
# Training loss: 0.1695431566937197
# Number Of Images Tested = 10000
# Model Accuracy = 0.8092
# Number Of Images Tested = 60000
# Model Accuracy = 0.8040833333333334
# Test loss: 2.2976701751256443
#
# Epoch 2
# Training loss: 0.44663051519314445
# Number Of Images Tested = 10000
# Model Accuracy = 0.7934
# Number Of Images Tested = 60000
# Model Accuracy = 0.7850833333333334
# Test loss: 2.5609274927977546
#
# Epoch 3
# Training loss: 0.641443792111012
# Number Of Images Tested = 10000
# Model Accuracy = 0.7165
# Number Of Images Tested = 60000
# Model Accuracy = 0.7179333333333333
# Test loss: 3.7625374482695464
#
# Epoch 4
# Training loss: 0.8924801543768026
# Number Of Images Tested = 10000
# Model Accuracy = 0.5145
# Number Of Images Tested = 60000
# Model Accuracy = 0.5143166666666666
# Test loss: 3.3627232799104823
#
# Epoch 5
# Training loss: 1.036018402877647
# Number Of Images Tested = 10000
# Model Accuracy = 0.6121
# Number Of Images Tested = 60000
# Model Accuracy = 0.6042333333333333
# Test loss: 3.783847095100743
#
# Epoch 6
# Training loss: 1.088655102163998
# Number Of Images Tested = 10000
# Model Accuracy = 0.6581
# Number Of Images Tested = 60000
# Model Accuracy = 0.6493833333333333
# Test loss: 1.9754092063114141
#
# Epoch 7
# Training loss: 1.023787020366075
# Number Of Images Tested = 10000
# Model Accuracy = 0.6212
# Number Of Images Tested = 60000
# Model Accuracy = 0.61205
# Test loss: 2.026706578245588
#
# Epoch 8
# Training loss: 0.9241778961122672
# Number Of Images Tested = 10000
# Model Accuracy = 0.62
# Number Of Images Tested = 60000
# Model Accuracy = 0.61955
# Test loss: 1.647410759500637
#
# Epoch 9
# Training loss: 0.8998290935813237
# Number Of Images Tested = 10000
# Model Accuracy = 0.5834
# Number Of Images Tested = 60000
# Model Accuracy = 0.5687833333333333
# Test loss: 2.842379647835045
#
# Epoch 10
# Training loss: 0.7792011112419527
# Number Of Images Tested = 10000
# Model Accuracy = 0.6042
# Number Of Images Tested = 60000
# Model Accuracy = 0.6045666666666667
# Test loss: 1.9403516437597335
#
# Epoch 11
# Training loss: 0.9349906402292536
# Number Of Images Tested = 10000
# Model Accuracy = 0.6165
# Number Of Images Tested = 60000
# Model Accuracy = 0.6088166666666667
# Test loss: 1.3326392295254263
#
# Epoch 12
# Training loss: 0.8739333421722658
# Number Of Images Tested = 10000
# Model Accuracy = 0.5957
# Number Of Images Tested = 60000
# Model Accuracy = 0.6027166666666667
# Test loss: 1.8507445701368295
#
# Epoch 13
# Training loss: 0.8018963227965938
# Number Of Images Tested = 10000
# Model Accuracy = 0.7113
# Number Of Images Tested = 60000
# Model Accuracy = 0.70685
# Test loss: 1.2721494910823312
#
# Epoch 14
# Training loss: 0.7562408125730974
# Number Of Images Tested = 10000
# Model Accuracy = 0.7275
# Number Of Images Tested = 60000
# Model Accuracy = 0.7186833333333333
# Test loss: 1.3709484336862139
#
# Epoch 15
# Training loss: 0.7631972567803824
# Number Of Images Tested = 10000
# Model Accuracy = 0.6466
# Number Of Images Tested = 60000
# Model Accuracy = 0.6479666666666667
# Test loss: 1.536512820204352
#
# Epoch 16
# Training loss: 0.9196302194966436
# Number Of Images Tested = 10000
# Model Accuracy = 0.5289
# Number Of Images Tested = 60000
# Model Accuracy = 0.5211333333333333
# Test loss: 1.7881697928829559
#
# Epoch 17
# Training loss: 0.8850282896429237
# Number Of Images Tested = 10000
# Model Accuracy = 0.6267
# Number Of Images Tested = 60000
# Model Accuracy = 0.6224166666666666
# Test loss: 1.1863028160326041
#
# Epoch 18
# Training loss: 0.9019564636417036
# Number Of Images Tested = 10000
# Model Accuracy = 0.5386
# Number Of Images Tested = 60000
# Model Accuracy = 0.5311333333333333
# Test loss: 2.2163520250350808
#
# Epoch 19
# Training loss: 0.9290427231331115
# Number Of Images Tested = 10000
# Model Accuracy = 0.6806
# Number Of Images Tested = 60000
# Model Accuracy = 0.6741
# Test loss: 1.4413626945702134
#
# Epoch 20
# Training loss: 0.8731694095043231
# Number Of Images Tested = 10000
# Model Accuracy = 0.6992
# Number Of Images Tested = 60000
# Model Accuracy = 0.6953833333333334
# Test loss: 1.925109829872277
#
# Epoch 21
# Training loss: 0.8563864550102495
# Number Of Images Tested = 10000
# Model Accuracy = 0.6029
# Number Of Images Tested = 60000
# Model Accuracy = 0.5996833333333333
# Test loss: 1.8683757144174757
#
# Epoch 22
# Training loss: 1.0313547653302964
# Number Of Images Tested = 10000
# Model Accuracy = 0.404
# Number Of Images Tested = 60000
# Model Accuracy = 0.3948833333333333
# Test loss: 1.663240343142467
#
# Epoch 23
# Training loss: 1.4396168701430119
# Number Of Images Tested = 10000
# Model Accuracy = 0.4556
# Number Of Images Tested = 60000
# Model Accuracy = 0.44953333333333334
# Test loss: 2.026066941060838
#
# Epoch 24
# Training loss: 1.627035925256164
# Number Of Images Tested = 10000
# Model Accuracy = 0.3319
# Number Of Images Tested = 60000
# Model Accuracy = 0.3225
# Test loss: 1.778204336287869
#
# Epoch 25
# Training loss: 1.535180954282472
# Number Of Images Tested = 10000
# Model Accuracy = 0.35
# Number Of Images Tested = 60000
# Model Accuracy = 0.34615
# Test loss: 1.7066341873946462
#
# Epoch 26
# Training loss: 1.4910324801768322
# Number Of Images Tested = 10000
# Model Accuracy = 0.3804
# Number Of Images Tested = 60000
# Model Accuracy = 0.3832333333333333
# Test loss: 1.787053074806359
#
# Epoch 27
# Training loss: 1.338009253112492
# Number Of Images Tested = 10000
# Model Accuracy = 0.3794
# Number Of Images Tested = 60000
# Model Accuracy = 0.37495
# Test loss: 2.027127748082398
#
# Epoch 28
# Training loss: 1.3986067681043133
# Number Of Images Tested = 10000
# Model Accuracy = 0.4424
# Number Of Images Tested = 60000
# Model Accuracy = 0.4416
# Test loss: 1.6814258113788192
#
# Epoch 29
# Training loss: 1.3070759626466837
# Number Of Images Tested = 10000
# Model Accuracy = 0.4882
# Number Of Images Tested = 60000
# Model Accuracy = 0.48415
# Test loss: 1.7804890119346084
#
#
# Training Time (in minutes) = 93.6579061349233
#
#
# Minibatch size:  128
# History size:  10
# Epoch 0
# Training loss: 0.051232072159408164
# Number Of Images Tested = 10000
# Model Accuracy = 0.9308
# Number Of Images Tested = 60000
# Model Accuracy = 0.9281166666666667
# Test loss: 0.39957706979181196
#
# Epoch 1
# Training loss: 0.03778532864932918
# Number Of Images Tested = 10000
# Model Accuracy = 0.9145
# Number Of Images Tested = 60000
# Model Accuracy = 0.9213
# Test loss: 0.4424379832005199
#
# Epoch 2
# Training loss: 0.03429679885419916
# Number Of Images Tested = 10000
# Model Accuracy = 0.9386
# Number Of Images Tested = 60000
# Model Accuracy = 0.9415333333333333
# Test loss: 0.4385004871395193
#
# Epoch 3
# Training loss: 0.023905755468785015
# Number Of Images Tested = 10000
# Model Accuracy = 0.955
# Number Of Images Tested = 60000
# Model Accuracy = 0.9602666666666667
# Test loss: 0.29549084345609705
#
# Epoch 4
# Training loss: 0.023477391908795314
# Number Of Images Tested = 10000
# Model Accuracy = 0.9388
# Number Of Images Tested = 60000
# Model Accuracy = 0.9461
# Test loss: 0.38598872605664064
#
# Epoch 5
# Training loss: 0.02237556370191436
# Number Of Images Tested = 10000
# Model Accuracy = 0.9551
# Number Of Images Tested = 60000
# Model Accuracy = 0.9616833333333333
# Test loss: 0.32700343533784526
#
# Epoch 6
# Training loss: 0.02429358872711146
# Number Of Images Tested = 10000
# Model Accuracy = 0.9532
# Number Of Images Tested = 60000
# Model Accuracy = 0.9608
# Test loss: 0.41787532708626773
#
# Epoch 7
# Training loss: 0.01784029873195915
# Number Of Images Tested = 10000
# Model Accuracy = 0.9611
# Number Of Images Tested = 60000
# Model Accuracy = 0.9687166666666667
# Test loss: 0.33610892890108146
#
# Epoch 8
# Training loss: 0.020006297641393292
# Number Of Images Tested = 10000
# Model Accuracy = 0.9584
# Number Of Images Tested = 60000
# Model Accuracy = 0.96545
# Test loss: 0.3613415422762414
#
# Epoch 9
# Training loss: 0.022389115080489262
# Number Of Images Tested = 10000
# Model Accuracy = 0.9459
# Number Of Images Tested = 60000
# Model Accuracy = 0.95605
# Test loss: 0.5529444163924531
#
# Epoch 10
# Training loss: 0.015551711473646675
# Number Of Images Tested = 10000
# Model Accuracy = 0.9688
# Number Of Images Tested = 60000
# Model Accuracy = 0.9764333333333334
# Test loss: 0.3083641148202528
#
# Epoch 11
# Training loss: 0.019254289031611277
# Number Of Images Tested = 10000
# Model Accuracy = 0.9581
# Number Of Images Tested = 60000
# Model Accuracy = 0.96345
# Test loss: 0.4410045192211489
#
# Epoch 12
# Training loss: 0.01848406472584582
# Number Of Images Tested = 10000
# Model Accuracy = 0.9672
# Number Of Images Tested = 60000
# Model Accuracy = 0.9760333333333333
# Test loss: 0.30313324927694246
#
# Epoch 13
# Training loss: 0.019236181556345974
# Number Of Images Tested = 10000
# Model Accuracy = 0.9516
# Number Of Images Tested = 60000
# Model Accuracy = 0.95575
# Test loss: 0.559191154528121
#
# Epoch 14
# Training loss: 0.019467947017985338
# Number Of Images Tested = 10000
# Model Accuracy = 0.9602
# Number Of Images Tested = 60000
# Model Accuracy = 0.9683333333333334
# Test loss: 0.4301132042829649
#
# Epoch 15
# Training loss: 0.019485075997719092
# Number Of Images Tested = 10000
# Model Accuracy = 0.9655
# Number Of Images Tested = 60000
# Model Accuracy = 0.9744833333333334
# Test loss: 0.386582819249811
#
# Epoch 16
# Training loss: 0.015518015036089508
# Number Of Images Tested = 10000
# Model Accuracy = 0.9624
# Number Of Images Tested = 60000
# Model Accuracy = 0.9735833333333334
# Test loss: 0.4010852657822233
#
# Epoch 17
# Training loss: 0.015592219978549577
# Number Of Images Tested = 10000
# Model Accuracy = 0.9653
# Number Of Images Tested = 60000
# Model Accuracy = 0.9747333333333333
# Test loss: 0.40798254669467104
#
# Epoch 18
# Training loss: 0.021430019643772138
# Number Of Images Tested = 10000
# Model Accuracy = 0.9467
# Number Of Images Tested = 60000
# Model Accuracy = 0.9584666666666667
# Test loss: 0.6328579810789868
#
# Epoch 19
# Training loss: 0.016059746194669378
# Number Of Images Tested = 10000
# Model Accuracy = 0.963
# Number Of Images Tested = 60000
# Model Accuracy = 0.97335
# Test loss: 0.45327239655712737
#
# Epoch 20
# Training loss: 0.024825834509785892
# Number Of Images Tested = 10000
# Model Accuracy = 0.9444
# Number Of Images Tested = 60000
# Model Accuracy = 0.9550666666666666
# Test loss: 0.8116356899513851
#
# Epoch 21
# Training loss: 0.019466354622362673
# Number Of Images Tested = 10000
# Model Accuracy = 0.9595
# Number Of Images Tested = 60000
# Model Accuracy = 0.9696833333333333
# Test loss: 0.4888154357506693
#
# Epoch 22
# Training loss: 0.01872888062327415
# Number Of Images Tested = 10000
# Model Accuracy = 0.9655
# Number Of Images Tested = 60000
# Model Accuracy = 0.9785166666666667
# Test loss: 0.4377096837881622
#
# Epoch 23
# Training loss: 0.019999945888372735
# Number Of Images Tested = 10000
# Model Accuracy = 0.9657
# Number Of Images Tested = 60000
# Model Accuracy = 0.9785
# Test loss: 0.41569469500144446
#
# Epoch 24
# Training loss: 0.01785558682908743
# Number Of Images Tested = 10000
# Model Accuracy = 0.956
# Number Of Images Tested = 60000
# Model Accuracy = 0.9691333333333333
# Test loss: 0.5648022998548761
#
# Epoch 25
# Training loss: 0.01611979633644978
# Number Of Images Tested = 10000
# Model Accuracy = 0.9659
# Number Of Images Tested = 60000
# Model Accuracy = 0.9785166666666667
# Test loss: 0.43578852817759817
#
# Epoch 26
# Training loss: 0.023374645398663012
# Number Of Images Tested = 10000
# Model Accuracy = 0.951
# Number Of Images Tested = 60000
# Model Accuracy = 0.95925
# Test loss: 0.5781110589262806
#
# Epoch 27
# Training loss: 0.023282870952760285
# Number Of Images Tested = 10000
# Model Accuracy = 0.9531
# Number Of Images Tested = 60000
# Model Accuracy = 0.9629333333333333
# Test loss: 0.5713322826578647
#
# Epoch 28
# Training loss: 0.019424121083526386
# Number Of Images Tested = 10000
# Model Accuracy = 0.9657
# Number Of Images Tested = 60000
# Model Accuracy = 0.97735
# Test loss: 0.4868672701960303
#
# Epoch 29
# Training loss: 0.020588683289072887
# Number Of Images Tested = 10000
# Model Accuracy = 0.9553
# Number Of Images Tested = 60000
# Model Accuracy = 0.9668
# Test loss: 0.6208863469383007
#
#
# Training Time (in minutes) = 27.903945008913677
#
#
# Minibatch size:  128
# History size:  20
# Epoch 0
# Training loss: 0.037013113430235244
# Number Of Images Tested = 10000
# Model Accuracy = 0.9221
# Number Of Images Tested = 60000
# Model Accuracy = 0.9175
# Test loss: 0.5861678485157369
#
# Epoch 1
# Training loss: 0.050564236181697246
# Number Of Images Tested = 10000
# Model Accuracy = 0.9041
# Number Of Images Tested = 60000
# Model Accuracy = 0.9077333333333333
# Test loss: 0.4144320301240004
#
# Epoch 2
# Training loss: 0.03646669239089357
# Number Of Images Tested = 10000
# Model Accuracy = 0.871
# Number Of Images Tested = 60000
# Model Accuracy = 0.8728666666666667
# Test loss: 1.0584484991393512
#
# Epoch 3
# Training loss: 0.021791494046007755
# Number Of Images Tested = 10000
# Model Accuracy = 0.9009
# Number Of Images Tested = 60000
# Model Accuracy = 0.8974333333333333
# Test loss: 0.8905656122708623
#
# Epoch 4
# Training loss: 0.03131530065481584
# Number Of Images Tested = 10000
# Model Accuracy = 0.919
# Number Of Images Tested = 60000
# Model Accuracy = 0.9187166666666666
# Test loss: 0.7069236013708236
#
# Epoch 5
# Training loss: 0.04255273391737538
# Number Of Images Tested = 10000
# Model Accuracy = 0.9041
# Number Of Images Tested = 60000
# Model Accuracy = 0.9044333333333333
# Test loss: 1.1503601243978814
#
# Epoch 6
# Training loss: 0.07513421487656068
# Number Of Images Tested = 10000
# Model Accuracy = 0.8965
# Number Of Images Tested = 60000
# Model Accuracy = 0.89995
# Test loss: 0.9608981952637057
#
# Epoch 7
# Training loss: 0.07809835573142633
# Number Of Images Tested = 10000
# Model Accuracy = 0.8847
# Number Of Images Tested = 60000
# Model Accuracy = 0.8865833333333333
# Test loss: 0.8598903155402292
#
# Epoch 8
# Training loss: 0.09847894024227016
# Number Of Images Tested = 10000
# Model Accuracy = 0.9127
# Number Of Images Tested = 60000
# Model Accuracy = 0.9094833333333333
# Test loss: 1.039692770453948
#
# Epoch 9
# Training loss: 0.09915368471798125
# Number Of Images Tested = 10000
# Model Accuracy = 0.9228
# Number Of Images Tested = 60000
# Model Accuracy = 0.9253166666666667
# Test loss: 0.6580007773222802
#
# Epoch 10
# Training loss: 0.11341806719149612
# Number Of Images Tested = 10000
# Model Accuracy = 0.9108
# Number Of Images Tested = 60000
# Model Accuracy = 0.9145
# Test loss: 0.9526762534168702
#
# Epoch 11
# Training loss: 0.10212567801139907
# Number Of Images Tested = 10000
# Model Accuracy = 0.9175
# Number Of Images Tested = 60000
# Model Accuracy = 0.9214333333333333
# Test loss: 1.5481198471558244
#
# Epoch 12
# Training loss: 0.10666331033931988
# Number Of Images Tested = 10000
# Model Accuracy = 0.9068
# Number Of Images Tested = 60000
# Model Accuracy = 0.9057333333333333
# Test loss: 1.2422071751914447
#
# Epoch 13
# Training loss: 0.11110596383358726
# Number Of Images Tested = 10000
# Model Accuracy = 0.9151
# Number Of Images Tested = 60000
# Model Accuracy = 0.9148833333333334
# Test loss: 1.2304475601715377
#
# Epoch 14
# Training loss: 0.12022193494626886
# Number Of Images Tested = 10000
# Model Accuracy = 0.9172
# Number Of Images Tested = 60000
# Model Accuracy = 0.9172166666666667
# Test loss: 1.1741756979800477
#
# Epoch 15
# Training loss: 0.11323631202461448
# Number Of Images Tested = 10000
# Model Accuracy = 0.9151
# Number Of Images Tested = 60000
# Model Accuracy = 0.9173666666666667
# Test loss: 0.9380745254914162
#
# Epoch 16
# Training loss: 0.1231745633548936
# Number Of Images Tested = 10000
# Model Accuracy = 0.9276
# Number Of Images Tested = 60000
# Model Accuracy = 0.93215
# Test loss: 0.9814852679831748
#
# Epoch 17
# Training loss: 0.11504509855838958
# Number Of Images Tested = 10000
# Model Accuracy = 0.9342
# Number Of Images Tested = 60000
# Model Accuracy = 0.9394166666666667
# Test loss: 0.8599236635844919
#
# Epoch 18
# Training loss: 0.1341075233443333
# Number Of Images Tested = 10000
# Model Accuracy = 0.9161
# Number Of Images Tested = 60000
# Model Accuracy = 0.9159
# Test loss: 1.3621837384527242
#
# Epoch 19
# Training loss: 0.16498339432055878
# Number Of Images Tested = 10000
# Model Accuracy = 0.9218
# Number Of Images Tested = 60000
# Model Accuracy = 0.9244833333333333
# Test loss: 0.813502790995791
#
# Epoch 20
# Training loss: 0.14498005811821174
# Number Of Images Tested = 10000
# Model Accuracy = 0.9045
# Number Of Images Tested = 60000
# Model Accuracy = 0.90755
# Test loss: 1.152704690830617
#
# Epoch 21
# Training loss: 0.14347863917568768
# Number Of Images Tested = 10000
# Model Accuracy = 0.908
# Number Of Images Tested = 60000
# Model Accuracy = 0.9137166666666666
# Test loss: 1.842528714786602
#
# Epoch 22
# Training loss: 0.13954223706296537
# Number Of Images Tested = 10000
# Model Accuracy = 0.9153
# Number Of Images Tested = 60000
# Model Accuracy = 0.9185666666666666
# Test loss: 0.8548558697670321
#
# Epoch 23
# Training loss: 0.1454275871756893
# Number Of Images Tested = 10000
# Model Accuracy = 0.9198
# Number Of Images Tested = 60000
# Model Accuracy = 0.9230833333333334
# Test loss: 1.924049338773836
#
# Epoch 24
# Training loss: 0.15443285701119144
# Number Of Images Tested = 10000
# Model Accuracy = 0.8972
# Number Of Images Tested = 60000
# Model Accuracy = 0.9000166666666667
# Test loss: 1.0649903105406822
#
# Epoch 25
# Training loss: 0.14192074259472162
# Number Of Images Tested = 10000
# Model Accuracy = 0.9175
# Number Of Images Tested = 60000
# Model Accuracy = 0.922
# Test loss: 0.8498551811598525
#
# Epoch 26
# Training loss: 0.17971437273205032
# Number Of Images Tested = 10000
# Model Accuracy = 0.9077
# Number Of Images Tested = 60000
# Model Accuracy = 0.9117166666666666
# Test loss: 0.9418731226196771
#
# Epoch 27
# Training loss: 0.16403629071921702
# Number Of Images Tested = 10000
# Model Accuracy = 0.9223
# Number Of Images Tested = 60000
# Model Accuracy = 0.9263166666666667
# Test loss: 0.9334894324405284
#
# Epoch 28
# Training loss: 0.17039792567713938
# Number Of Images Tested = 10000
# Model Accuracy = 0.9046
# Number Of Images Tested = 60000
# Model Accuracy = 0.9068166666666667
# Test loss: 0.7197808806277528
#
# Epoch 29
# Training loss: 0.1515175851246492
# Number Of Images Tested = 10000
# Model Accuracy = 0.916
# Number Of Images Tested = 60000
# Model Accuracy = 0.9144666666666666
# Test loss: 1.0524344855471501
#
#
# Training Time (in minutes) = 49.76455795764923
#
#
# Minibatch size:  512
# History size:  10
# Epoch 0
# Training loss: 0.24357681617267052
# Number Of Images Tested = 10000
# Model Accuracy = 0.8471
# Number Of Images Tested = 60000
# Model Accuracy = 0.85005
# Test loss: 0.5155447810888291
#
# Epoch 1
# Training loss: 0.09831070532564516
# Number Of Images Tested = 10000
# Model Accuracy = 0.9294
# Number Of Images Tested = 60000
# Model Accuracy = 0.9301166666666667
# Test loss: 0.26544876024127007
#
# Epoch 2
# Training loss: 0.03020999057887327
# Number Of Images Tested = 10000
# Model Accuracy = 0.9537
# Number Of Images Tested = 60000
# Model Accuracy = 0.9542166666666667
# Test loss: 0.1840227909386158
#
# Epoch 3
# Training loss: 0.020525369181502925
# Number Of Images Tested = 10000
# Model Accuracy = 0.9131
# Number Of Images Tested = 60000
# Model Accuracy = 0.91815
# Test loss: 0.3935374587774277
#
# Epoch 4
# Training loss: 0.01302868679513113
# Number Of Images Tested = 10000
# Model Accuracy = 0.9481
# Number Of Images Tested = 60000
# Model Accuracy = 0.95455
# Test loss: 0.26130253449082375
#
# Epoch 5
# Training loss: 0.01285202470159166
# Number Of Images Tested = 10000
# Model Accuracy = 0.9657
# Number Of Images Tested = 60000
# Model Accuracy = 0.9742666666666666
# Test loss: 0.171755151450634
#
# Epoch 6
# Training loss: 0.007820336832576116
# Number Of Images Tested = 10000
# Model Accuracy = 0.9506
# Number Of Images Tested = 60000
# Model Accuracy = 0.9588
# Test loss: 0.3183853380382061
#
# Epoch 7
# Training loss: 0.008314926797507817
# Number Of Images Tested = 10000
# Model Accuracy = 0.9553
# Number Of Images Tested = 60000
# Model Accuracy = 0.9631166666666666
# Test loss: 0.28446049317717553
#
# Epoch 8
# Training loss: 0.009414473756343364
# Number Of Images Tested = 10000
# Model Accuracy = 0.9689
# Number Of Images Tested = 60000
# Model Accuracy = 0.9785666666666667
# Test loss: 0.18518757857382298
#
# Epoch 9
# Training loss: 0.007257124902488135
# Number Of Images Tested = 10000
# Model Accuracy = 0.9619
# Number Of Images Tested = 60000
# Model Accuracy = 0.9719166666666667
# Test loss: 0.21839060857892037
#
# Epoch 10
# Training loss: 0.006482580960961305
# Number Of Images Tested = 10000
# Model Accuracy = 0.9596
# Number Of Images Tested = 60000
# Model Accuracy = 0.96885
# Test loss: 0.28099251091480254
#
# Epoch 11
# Training loss: 0.006288739904957149
# Number Of Images Tested = 10000
# Model Accuracy = 0.9691
# Number Of Images Tested = 60000
# Model Accuracy = 0.9802166666666666
# Test loss: 0.21134581975638866
#
# Epoch 12
# Training loss: 0.004315595828949758
# Number Of Images Tested = 10000
# Model Accuracy = 0.9669
# Number Of Images Tested = 60000
# Model Accuracy = 0.9817666666666667
# Test loss: 0.2388860121369362
#
# Epoch 13
# Training loss: 0.005572779992689902
# Number Of Images Tested = 10000
# Model Accuracy = 0.9696
# Number Of Images Tested = 60000
# Model Accuracy = 0.9821833333333333
# Test loss: 0.2171698983758688
#
# Epoch 14
# Training loss: 0.004197488012015144
# Number Of Images Tested = 10000
# Model Accuracy = 0.9653
# Number Of Images Tested = 60000
# Model Accuracy = 0.9779833333333333
# Test loss: 0.24164729975163937
#
# Epoch 15
# Training loss: 0.0027977989155711625
# Number Of Images Tested = 10000
# Model Accuracy = 0.9727
# Number Of Images Tested = 60000
# Model Accuracy = 0.9873166666666666
# Test loss: 0.1910073272883892
#
# Epoch 16
# Training loss: 0.0026895034290677264
# Number Of Images Tested = 10000
# Model Accuracy = 0.9694
# Number Of Images Tested = 60000
# Model Accuracy = 0.98535
# Test loss: 0.20089753530919552
#
# Epoch 17
# Training loss: 0.004379264741107934
# Number Of Images Tested = 10000
# Model Accuracy = 0.9587
# Number Of Images Tested = 60000
# Model Accuracy = 0.9717166666666667
# Test loss: 0.31558426544070245
#
# Epoch 18
# Training loss: 0.0028623093894489336
# Number Of Images Tested = 10000
# Model Accuracy = 0.9649
# Number Of Images Tested = 60000
# Model Accuracy = 0.9832333333333333
# Test loss: 0.273244096711278
#
# Epoch 19
# Training loss: 0.001953311442236836
# Number Of Images Tested = 10000
# Model Accuracy = 0.9747
# Number Of Images Tested = 60000
# Model Accuracy = 0.9918333333333333
# Test loss: 0.20112701822072268
#
# Epoch 20
# Training loss: 0.002696927785529501
# Number Of Images Tested = 10000
# Model Accuracy = 0.9618
# Number Of Images Tested = 60000
# Model Accuracy = 0.9748666666666667
# Test loss: 0.30491547137498853
#
# Epoch 21
# Training loss: 0.002732227143554664
# Number Of Images Tested = 10000
# Model Accuracy = 0.9674
# Number Of Images Tested = 60000
# Model Accuracy = 0.9829666666666667
# Test loss: 0.2944221168756485
#
# Epoch 22
# Training loss: 0.0017752389900361407
# Number Of Images Tested = 10000
# Model Accuracy = 0.9721
# Number Of Images Tested = 60000
# Model Accuracy = 0.9906666666666667
# Test loss: 0.21902720481157303
#
# Epoch 23
# Training loss: 0.0015385571633310142
# Number Of Images Tested = 10000
# Model Accuracy = 0.9569
# Number Of Images Tested = 60000
# Model Accuracy = 0.9636166666666667
# Test loss: 0.40825174674391745
#
# Epoch 24
# Training loss: 0.00204233250287601
# Number Of Images Tested = 10000
# Model Accuracy = 0.9756
# Number Of Images Tested = 60000
# Model Accuracy = 0.9933833333333333
# Test loss: 0.20425423234701157
#
# Epoch 25
# Training loss: 0.0013306969416815157
# Number Of Images Tested = 10000
# Model Accuracy = 0.9742
# Number Of Images Tested = 60000
# Model Accuracy = 0.9915833333333334
# Test loss: 0.2367962770164013
#
# Epoch 26
# Training loss: 0.0016629920989632825
# Number Of Images Tested = 10000
# Model Accuracy = 0.9749
# Number Of Images Tested = 60000
# Model Accuracy = 0.99315
# Test loss: 0.22297867611050606
#
# Epoch 27
# Training loss: 0.0013273039473453104
# Number Of Images Tested = 10000
# Model Accuracy = 0.9731
# Number Of Images Tested = 60000
# Model Accuracy = 0.9915833333333334
# Test loss: 0.25929663218557836
#
# Epoch 28
# Training loss: 0.001124895951302972
# Number Of Images Tested = 10000
# Model Accuracy = 0.9694
# Number Of Images Tested = 60000
# Model Accuracy = 0.9856
# Test loss: 0.29500262439250946
#
# Epoch 29
# Training loss: 0.0015428238502617397
# Number Of Images Tested = 10000
# Model Accuracy = 0.9743
# Number Of Images Tested = 60000
# Model Accuracy = 0.9945
# Test loss: 0.237539641559124
#
#
# Training Time (in minutes) = 19.010867178440094
#
#
# Minibatch size:  512
# History size:  20
# Epoch 0
# Training loss: 0.1505313507533806
# Number Of Images Tested = 10000
# Model Accuracy = 0.8741
# Number Of Images Tested = 60000
# Model Accuracy = 0.8721833333333333
# Test loss: 0.5290333971381187
#
# Epoch 1
# Training loss: 0.04368612918237193
# Number Of Images Tested = 10000
# Model Accuracy = 0.9194
# Number Of Images Tested = 60000
# Model Accuracy = 0.9203333333333333
# Test loss: 0.35812959149479867
#
# Epoch 2
# Training loss: 0.012384109448649431
# Number Of Images Tested = 10000
# Model Accuracy = 0.9101
# Number Of Images Tested = 60000
# Model Accuracy = 0.9121833333333333
# Test loss: 0.42009335607290266
#
# Epoch 3
# Training loss: 0.006787374481495659
# Number Of Images Tested = 10000
# Model Accuracy = 0.931
# Number Of Images Tested = 60000
# Model Accuracy = 0.9381166666666667
# Test loss: 0.37388651072978973
#
# Epoch 4
# Training loss: 0.0032511246603215854
# Number Of Images Tested = 10000
# Model Accuracy = 0.953
# Number Of Images Tested = 60000
# Model Accuracy = 0.9583666666666667
# Test loss: 0.2900450512766838
#
# Epoch 5
# Training loss: 0.0022635515690667797
# Number Of Images Tested = 10000
# Model Accuracy = 0.9543
# Number Of Images Tested = 60000
# Model Accuracy = 0.9608166666666667
# Test loss: 0.2904900170862675
#
# Epoch 6
# Training loss: 0.003349474849917866
# Number Of Images Tested = 10000
# Model Accuracy = 0.9412
# Number Of Images Tested = 60000
# Model Accuracy = 0.9460166666666666
# Test loss: 0.4294924348592758
#
# Epoch 7
# Training loss: 0.0011270976643665285
# Number Of Images Tested = 10000
# Model Accuracy = 0.9514
# Number Of Images Tested = 60000
# Model Accuracy = 0.9589333333333333
# Test loss: 0.394483008235693
#
# Epoch 8
# Training loss: 0.006482199496585347
# Number Of Images Tested = 10000
# Model Accuracy = 0.9547
# Number Of Images Tested = 60000
# Model Accuracy = 0.9618666666666666
# Test loss: 0.3395068682730198
#
# Epoch 9
# Training loss: 0.004327591344739894
# Number Of Images Tested = 10000
# Model Accuracy = 0.954
# Number Of Images Tested = 60000
# Model Accuracy = 0.95985
# Test loss: 0.37632999420166013
#
# Epoch 10
# Training loss: 0.005117234338392627
# Number Of Images Tested = 10000
# Model Accuracy = 0.9137
# Number Of Images Tested = 60000
# Model Accuracy = 0.9182333333333333
# Test loss: 0.7214743494987488
#
# Epoch 11
# Training loss: 0.0034324947784931106
# Number Of Images Tested = 10000
# Model Accuracy = 0.9618
# Number Of Images Tested = 60000
# Model Accuracy = 0.9685166666666667
# Test loss: 0.3331689715385437
#
# Epoch 12
# Training loss: 0.0075727878004842285
# Number Of Images Tested = 10000
# Model Accuracy = 0.9641
# Number Of Images Tested = 60000
# Model Accuracy = 0.9725
# Test loss: 0.35400753021240233
#
# Epoch 13
# Training loss: 0.005540271856824478
# Number Of Images Tested = 10000
# Model Accuracy = 0.9438
# Number Of Images Tested = 60000
# Model Accuracy = 0.9518666666666666
# Test loss: 0.5886402033269406
#
# Epoch 14
# Training loss: 0.004544959135463329
# Number Of Images Tested = 10000
# Model Accuracy = 0.9553
# Number Of Images Tested = 60000
# Model Accuracy = 0.9642
# Test loss: 0.46094805002212524
#
# Epoch 15
# Training loss: 0.0030163496068878705
# Number Of Images Tested = 10000
# Model Accuracy = 0.9629
# Number Of Images Tested = 60000
# Model Accuracy = 0.9751833333333333
# Test loss: 0.365691140294075
#
# Epoch 16
# Training loss: 0.004011894217093681
# Number Of Images Tested = 10000
# Model Accuracy = 0.958
# Number Of Images Tested = 60000
# Model Accuracy = 0.9689333333333333
# Test loss: 0.46051818430423735
#
# Epoch 17
# Training loss: 0.0040029965566636206
# Number Of Images Tested = 10000
# Model Accuracy = 0.9587
# Number Of Images Tested = 60000
# Model Accuracy = 0.9723166666666667
# Test loss: 0.4300438955426216
#
# Epoch 18
# Training loss: 0.0018323936800053928
# Number Of Images Tested = 10000
# Model Accuracy = 0.9669
# Number Of Images Tested = 60000
# Model Accuracy = 0.9793833333333334
# Test loss: 0.37029229402542113
#
# Epoch 19
# Training loss: 0.002088702640051806
# Number Of Images Tested = 10000
# Model Accuracy = 0.9506
# Number Of Images Tested = 60000
# Model Accuracy = 0.9593166666666667
# Test loss: 0.5374992996454239
#
# Epoch 20
# Training loss: 0.00484654231827812
# Number Of Images Tested = 10000
# Model Accuracy = 0.9535
# Number Of Images Tested = 60000
# Model Accuracy = 0.9672333333333333
# Test loss: 0.533649069070816
#
# Epoch 21
# Training loss: 0.00853301614145067
# Number Of Images Tested = 10000
# Model Accuracy = 0.9661
# Number Of Images Tested = 60000
# Model Accuracy = 0.9729166666666667
# Test loss: 0.4293999679386616
#
# Epoch 22
# Training loss: 0.003715125552416907
# Number Of Images Tested = 10000
# Model Accuracy = 0.9621
# Number Of Images Tested = 60000
# Model Accuracy = 0.9759666666666666
# Test loss: 0.4382404968142509
#
# Epoch 23
# Training loss: 0.002654805927892556
# Number Of Images Tested = 10000
# Model Accuracy = 0.9706
# Number Of Images Tested = 60000
# Model Accuracy = 0.9875666666666667
# Test loss: 0.37928616628050804
#
# Epoch 24
# Training loss: 0.003632893440739866
# Number Of Images Tested = 10000
# Model Accuracy = 0.9752
# Number Of Images Tested = 60000
# Model Accuracy = 0.9904
# Test loss: 0.3099875219166279
#
# Epoch 25
# Training loss: 0.0014357773288856547
# Number Of Images Tested = 10000
# Model Accuracy = 0.9641
# Number Of Images Tested = 60000
# Model Accuracy = 0.97555
# Test loss: 0.47266619056463244
#
# Epoch 26
# Training loss: 0.0018404262838932577
# Number Of Images Tested = 10000
# Model Accuracy = 0.9649
# Number Of Images Tested = 60000
# Model Accuracy = 0.9766833333333333
# Test loss: 0.5221564933657646
#
# Epoch 27
# Training loss: 0.0034296065339938907
# Number Of Images Tested = 10000
# Model Accuracy = 0.9705
# Number Of Images Tested = 60000
# Model Accuracy = 0.9847833333333333
# Test loss: 0.3965288162231445
#
# Epoch 28
# Training loss: 0.0020765388808286836
# Number Of Images Tested = 10000
# Model Accuracy = 0.9627
# Number Of Images Tested = 60000
# Model Accuracy = 0.9744833333333334
# Test loss: 0.5291995145380497
#
# Epoch 29
# Training loss: 0.0013416810284344247
# Number Of Images Tested = 10000
# Model Accuracy = 0.9722
# Number Of Images Tested = 60000
# Model Accuracy = 0.9885166666666667
# Test loss: 0.38367264792323114
#
#
# Training Time (in minutes) = 26.22235136826833
#
#
# Minibatch size:  1024
# History size:  10
# Epoch 0
# Training loss: 0.29654921389232247
# Number Of Images Tested = 10000
# Model Accuracy = 0.9154
# Number Of Images Tested = 60000
# Model Accuracy = 0.9172
# Test loss: 0.2870340034365654
#
# Epoch 1
# Training loss: 0.17419341976864863
# Number Of Images Tested = 10000
# Model Accuracy = 0.9267
# Number Of Images Tested = 60000
# Model Accuracy = 0.9281166666666667
# Test loss: 0.24750272780656815
#
# Epoch 2
# Training loss: 0.13792455512083182
# Number Of Images Tested = 10000
# Model Accuracy = 0.94
# Number Of Images Tested = 60000
# Model Accuracy = 0.9422833333333334
# Test loss: 0.2083900034427643
#
# Epoch 3
# Training loss: 0.10561999716496064
# Number Of Images Tested = 10000
# Model Accuracy = 0.9505
# Number Of Images Tested = 60000
# Model Accuracy = 0.9530666666666666
# Test loss: 0.16285699754953384
#
# Epoch 4
# Training loss: 0.07779136375855591
# Number Of Images Tested = 10000
# Model Accuracy = 0.9472
# Number Of Images Tested = 60000
# Model Accuracy = 0.9513166666666667
# Test loss: 0.17269744277000426
#
# Epoch 5
# Training loss: 0.06211072604282428
# Number Of Images Tested = 10000
# Model Accuracy = 0.9499
# Number Of Images Tested = 60000
# Model Accuracy = 0.9533166666666667
# Test loss: 0.1663639396429062
#
# Epoch 6
# Training loss: 0.046082946077241733
# Number Of Images Tested = 10000
# Model Accuracy = 0.9569
# Number Of Images Tested = 60000
# Model Accuracy = 0.96165
# Test loss: 0.1465904638171196
#
# Epoch 7
# Training loss: 0.03350929309756069
# Number Of Images Tested = 10000
# Model Accuracy = 0.9575
# Number Of Images Tested = 60000
# Model Accuracy = 0.9648666666666667
# Test loss: 0.14575300067663194
#
# Epoch 8
# Training loss: 0.026226241915028984
# Number Of Images Tested = 10000
# Model Accuracy = 0.9599
# Number Of Images Tested = 60000
# Model Accuracy = 0.9703833333333334
# Test loss: 0.1438623361289501
#
# Epoch 9
# Training loss: 0.02053589749513036
# Number Of Images Tested = 10000
# Model Accuracy = 0.9579
# Number Of Images Tested = 60000
# Model Accuracy = 0.9677
# Test loss: 0.1619965463876724
#
# Epoch 10
# Training loss: 0.017351001485298247
# Number Of Images Tested = 10000
# Model Accuracy = 0.9625
# Number Of Images Tested = 60000
# Model Accuracy = 0.9694166666666667
# Test loss: 0.14622349441051483
#
# Epoch 11
# Training loss: 0.012767247689919452
# Number Of Images Tested = 10000
# Model Accuracy = 0.9543
# Number Of Images Tested = 60000
# Model Accuracy = 0.9653333333333334
# Test loss: 0.18262156546115876
#
# Epoch 12
# Training loss: 0.010880258411832027
# Number Of Images Tested = 10000
# Model Accuracy = 0.9601
# Number Of Images Tested = 60000
# Model Accuracy = 0.9732166666666666
# Test loss: 0.15758797898888588
#
# Epoch 13
# Training loss: 0.009059830128720378
# Number Of Images Tested = 10000
# Model Accuracy = 0.9615
# Number Of Images Tested = 60000
# Model Accuracy = 0.9720666666666666
# Test loss: 0.1676944948732853
#
# Epoch 14
# Training loss: 0.007595653598338871
# Number Of Images Tested = 10000
# Model Accuracy = 0.9647
# Number Of Images Tested = 60000
# Model Accuracy = 0.9774833333333334
# Test loss: 0.16086749732494354
#
# Epoch 15
# Training loss: 0.0075657183987135855
# Number Of Images Tested = 10000
# Model Accuracy = 0.9708
# Number Of Images Tested = 60000
# Model Accuracy = 0.9820166666666666
# Test loss: 0.13864725455641747
#
# Epoch 16
# Training loss: 0.005923554042780424
# Number Of Images Tested = 10000
# Model Accuracy = 0.9557
# Number Of Images Tested = 60000
# Model Accuracy = 0.9680166666666666
# Test loss: 0.21049524694681168
#
# Epoch 17
# Training loss: 0.007157585732599373
# Number Of Images Tested = 10000
# Model Accuracy = 0.9692
# Number Of Images Tested = 60000
# Model Accuracy = 0.98475
# Test loss: 0.14637068659067154
#
# Epoch 18
# Training loss: 0.0049880075670968175
# Number Of Images Tested = 10000
# Model Accuracy = 0.9703
# Number Of Images Tested = 60000
# Model Accuracy = 0.9862166666666666
# Test loss: 0.1567668281495571
#
# Epoch 19
# Training loss: 0.005292729450926437
# Number Of Images Tested = 10000
# Model Accuracy = 0.9694
# Number Of Images Tested = 60000
# Model Accuracy = 0.9854833333333334
# Test loss: 0.17134052962064744
#
# Epoch 20
# Training loss: 0.00493321010558787
# Number Of Images Tested = 10000
# Model Accuracy = 0.9711
# Number Of Images Tested = 60000
# Model Accuracy = 0.9868333333333333
# Test loss: 0.15514175072312356
#
# Epoch 21
# Training loss: 0.004267821783965485
# Number Of Images Tested = 10000
# Model Accuracy = 0.971
# Number Of Images Tested = 60000
# Model Accuracy = 0.9880166666666667
# Test loss: 0.17194017320871352
#
# Epoch 22
# Training loss: 0.0031396221380357203
# Number Of Images Tested = 10000
# Model Accuracy = 0.9712
# Number Of Images Tested = 60000
# Model Accuracy = 0.98635
# Test loss: 0.17301035821437835
#
# Epoch 23
# Training loss: 0.0048676840531821286
# Number Of Images Tested = 10000
# Model Accuracy = 0.9639
# Number Of Images Tested = 60000
# Model Accuracy = 0.9782833333333333
# Test loss: 0.20161715894937515
#
# Epoch 24
# Training loss: 0.00226138476321821
# Number Of Images Tested = 10000
# Model Accuracy = 0.9708
# Number Of Images Tested = 60000
# Model Accuracy = 0.99065
# Test loss: 0.17148536145687104
#
# Epoch 25
# Training loss: 0.002127837806286969
# Number Of Images Tested = 10000
# Model Accuracy = 0.9707
# Number Of Images Tested = 60000
# Model Accuracy = 0.98955
# Test loss: 0.1754564568400383
#
# Epoch 26
# Training loss: 0.0022554457434541863
# Number Of Images Tested = 10000
# Model Accuracy = 0.9716
# Number Of Images Tested = 60000
# Model Accuracy = 0.9925
# Test loss: 0.16806188523769378
#
# Epoch 27
# Training loss: 0.002496019634467518
# Number Of Images Tested = 10000
# Model Accuracy = 0.9687
# Number Of Images Tested = 60000
# Model Accuracy = 0.9877166666666667
# Test loss: 0.20023654401302338
#
# Epoch 28
# Training loss: 0.0008629608404343175
# Number Of Images Tested = 10000
# Model Accuracy = 0.9729
# Number Of Images Tested = 60000
# Model Accuracy = 0.9935
# Test loss: 0.1745418518781662
#
# Epoch 29
# Training loss: 0.0013715508518497839
# Number Of Images Tested = 10000
# Model Accuracy = 0.9723
# Number Of Images Tested = 60000
# Model Accuracy = 0.9936666666666667
# Test loss: 0.17911864072084427
#
#
# Training Time (in minutes) = 16.636776963869732
#
#
# Minibatch size:  1024
# History size:  20
# Epoch 0
# Training loss: 0.10175835532215187
# Number Of Images Tested = 10000
# Model Accuracy = 0.9369
# Number Of Images Tested = 60000
# Model Accuracy = 0.9396333333333333
# Test loss: 0.29004458487033846
#
# Epoch 1
# Training loss: 0.004830672459428246
# Number Of Images Tested = 10000
# Model Accuracy = 0.9543
# Number Of Images Tested = 60000
# Model Accuracy = 0.9578666666666666
# Test loss: 0.252685509622097
#
# Epoch 2
# Training loss: 0.0009199305210840667
# Number Of Images Tested = 10000
# Model Accuracy = 0.9593
# Number Of Images Tested = 60000
# Model Accuracy = 0.9665
# Test loss: 0.2469271808862686
#
# Epoch 3
# Training loss: 0.0010204552222834752
# Number Of Images Tested = 10000
# Model Accuracy = 0.9562
# Number Of Images Tested = 60000
# Model Accuracy = 0.9635333333333334
# Test loss: 0.2563012421131134
#
# Epoch 4
# Training loss: 0.0007360377451624442
# Number Of Images Tested = 10000
# Model Accuracy = 0.9678
# Number Of Images Tested = 60000
# Model Accuracy = 0.9759333333333333
# Test loss: 0.189019875228405
#
# Epoch 5
# Training loss: 0.0006282015017212084
# Number Of Images Tested = 10000
# Model Accuracy = 0.9658
# Number Of Images Tested = 60000
# Model Accuracy = 0.9740333333333333
# Test loss: 0.21237072646617888
#
# Epoch 6
# Training loss: 0.0006422588254373927
# Number Of Images Tested = 10000
# Model Accuracy = 0.9678
# Number Of Images Tested = 60000
# Model Accuracy = 0.9772166666666666
# Test loss: 0.2091618910431862
#
# Epoch 7
# Training loss: 0.0015752408277868676
# Number Of Images Tested = 10000
# Model Accuracy = 0.9689
# Number Of Images Tested = 60000
# Model Accuracy = 0.98105
# Test loss: 0.2009301207959652
#
# Epoch 8
# Training loss: 0.0013411254600904136
# Number Of Images Tested = 10000
# Model Accuracy = 0.9692
# Number Of Images Tested = 60000
# Model Accuracy = 0.9816333333333334
# Test loss: 0.21040662825107576
#
# Epoch 9
# Training loss: 0.0018041104940686513
# Number Of Images Tested = 10000
# Model Accuracy = 0.9695
# Number Of Images Tested = 60000
# Model Accuracy = 0.9825333333333334
# Test loss: 0.23470598161220552
#
# Epoch 10
# Training loss: 0.003990261706430867
# Number Of Images Tested = 10000
# Model Accuracy = 0.9726
# Number Of Images Tested = 60000
# Model Accuracy = 0.98445
# Test loss: 0.21993139386177063
#
# Epoch 11
# Training loss: 0.002754460810465543
# Number Of Images Tested = 10000
# Model Accuracy = 0.97
# Number Of Images Tested = 60000
# Model Accuracy = 0.9856
# Test loss: 0.21288858950138093
#
# Epoch 12
# Training loss: 0.002143805277747537
# Number Of Images Tested = 10000
# Model Accuracy = 0.9719
# Number Of Images Tested = 60000
# Model Accuracy = 0.9879333333333333
# Test loss: 0.20465445518493652
#
# Epoch 13
# Training loss: 0.001076862576997744
# Number Of Images Tested = 10000
# Model Accuracy = 0.9726
# Number Of Images Tested = 60000
# Model Accuracy = 0.9867833333333333
# Test loss: 0.2063992738723755
#
# Epoch 14
# Training loss: 0.001373696925396663
# Number Of Images Tested = 10000
# Model Accuracy = 0.971
# Number Of Images Tested = 60000
# Model Accuracy = 0.9879666666666667
# Test loss: 0.2434035435318947
#
# Epoch 15
# Training loss: 0.0029344608250490615
# Number Of Images Tested = 10000
# Model Accuracy = 0.9708
# Number Of Images Tested = 60000
# Model Accuracy = 0.9857333333333334
# Test loss: 0.25116234868764875
#
# Epoch 16
# Training loss: 0.001228959165539494
# Number Of Images Tested = 10000
# Model Accuracy = 0.9725
# Number Of Images Tested = 60000
# Model Accuracy = 0.9893666666666666
# Test loss: 0.23987634629011154
#
# Epoch 17
# Training loss: 0.001706570602653135
# Number Of Images Tested = 10000
# Model Accuracy = 0.9736
# Number Of Images Tested = 60000
# Model Accuracy = 0.9881333333333333
# Test loss: 0.23066411390900612
#
# Epoch 18
# Training loss: 0.0018184663121144434
# Number Of Images Tested = 10000
# Model Accuracy = 0.9741
# Number Of Images Tested = 60000
# Model Accuracy = 0.9905833333333334
# Test loss: 0.23817696720361708
#
# Epoch 19
# Training loss: 0.001343298131603668
# Number Of Images Tested = 10000
# Model Accuracy = 0.973
# Number Of Images Tested = 60000
# Model Accuracy = 0.989
# Test loss: 0.2657870352268219
#
# Epoch 20
# Training loss: 0.0013664730652094169
# Number Of Images Tested = 10000
# Model Accuracy = 0.9753
# Number Of Images Tested = 60000
# Model Accuracy = 0.9936333333333334
# Test loss: 0.2433810755610466
#
# Epoch 21
# Training loss: 0.0012991301180560277
# Number Of Images Tested = 10000
# Model Accuracy = 0.9736
# Number Of Images Tested = 60000
# Model Accuracy = 0.9921166666666666
# Test loss: 0.25375048369169234
#
# Epoch 22
# Training loss: 0.0008645338784092387
# Number Of Images Tested = 10000
# Model Accuracy = 0.9756
# Number Of Images Tested = 60000
# Model Accuracy = 0.99305
# Test loss: 0.2473842591047287
#
# Epoch 23
# Training loss: 0.0007808000794056116
# Number Of Images Tested = 10000
# Model Accuracy = 0.9714
# Number Of Images Tested = 60000
# Model Accuracy = 0.9888666666666667
# Test loss: 0.29046528935432436
#
# Epoch 24
# Training loss: 0.0011241488295688504
# Number Of Images Tested = 10000
# Model Accuracy = 0.9724
# Number Of Images Tested = 60000
# Model Accuracy = 0.9931166666666666
# Test loss: 0.2745827227830887
#
# Epoch 25
# Training loss: 0.0019364033637324133
# Number Of Images Tested = 10000
# Model Accuracy = 0.9737
# Number Of Images Tested = 60000
# Model Accuracy = 0.9927333333333334
# Test loss: 0.26720414608716964
#
# Epoch 26
# Training loss: 0.001665924363408187
# Number Of Images Tested = 10000
# Model Accuracy = 0.9768
# Number Of Images Tested = 60000
# Model Accuracy = 0.9945833333333334
# Test loss: 0.2548491179943085
#
# Epoch 27
# Training loss: 0.0015257525268728596
# Number Of Images Tested = 10000
# Model Accuracy = 0.9752
# Number Of Images Tested = 60000
# Model Accuracy = 0.9961833333333333
# Test loss: 0.2589853644371033
#
# Epoch 28
# Training loss: 0.0010080168395232142
# Number Of Images Tested = 10000
# Model Accuracy = 0.9752
# Number Of Images Tested = 60000
# Model Accuracy = 0.99455
# Test loss: 0.27106206566095353
#
# Epoch 29
# Training loss: 0.0012338340488445673
# Number Of Images Tested = 10000
# Model Accuracy = 0.9766
# Number Of Images Tested = 60000
# Model Accuracy = 0.9961333333333333
# Test loss: 0.26173464506864547
#
#
# Training Time (in minutes) = 20.674544564882915

# %%
i = 0
for bs_index,bs in enumerate(minibatch_size_grid):
    for hs_index,hs in enumerate(history_size_grid):
        plt.figure(1, figsize = (12,10))
        plt.plot(test_loss_fcnn[i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(2, figsize = (12,10))
        plt.plot(training_loss_fcnn[i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(3, figsize = (12,10))
        plt.plot(test_accuracy_fcnn[i],label='bs = {}, hs = {}'.format(bs,hs))
        plt.figure(4, figsize = (12,10))
        plt.plot(training_accuracy_fcnn[i],label='bs = {}, hs = {}'.format(bs,hs))
        i+=1

plt.figure(1)
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Minibatch LBFGS Test loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("mini_LBFGS_test_loss_fcnn.jpg")
plt.figure (2)
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
plt.title('Minibatch LBFGS Train loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("mini_LBFGS_train_loss_fcnn.jpg")
plt.figure (3)
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.title('Minibatch LBFGS Test accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("mini_LBFGS_test_acc_fcnn.jpg")
plt.figure (4)
plt.xlabel('Epochs')
plt.ylabel('Train Accuracy')
plt.title('Minibatch LBFGS Train accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig("mini_LBFGS_train_acc_fcnn.jpg")

# %%
np.savetxt('LBFGS_minibatch_fcNN_trainloss.txt', training_loss_fcnn)
np.savetxt('LBFGS_minibatch_fcNN_testloss.txt', test_loss_fcnn)
np.savetxt('LBFGS_minibatch_fcNN_trainacc.txt', training_accuracy_fcnn)
np.savetxt('LBFGS_minibatch_fcNN_testacc.txt', test_accuracy_fcnn)
np.savetxt('LBFGS_minibatch_fcNN_times.txt',time_fcnn)
