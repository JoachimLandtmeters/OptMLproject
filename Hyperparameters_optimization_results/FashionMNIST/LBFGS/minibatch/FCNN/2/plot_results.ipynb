# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
testacc = np.loadtxt("LBFGS_minibatch_fcNN_testacc.txt")
trainacc = np.loadtxt("LBFGS_minibatch_fcNN_trainacc.txt")
testloss = np.loadtxt("LBFGS_minibatch_fcNN_testloss.txt")
trainloss = np.loadtxt("LBFGS_minibatch_fcNN_trainloss.txt")

# %%
minibatch_size_grid = [0,128,512,512,1024,1024]
grid = [2,4,5]
history_size_grid=[0,0,10,20,10,20]

# %%
testacc[4]
# Out:
# array([0.83  , 0.8385, 0.8427, 0.8506, 0.8512, 0.8486, 0.8553, 0.8515,
#        0.8607, 0.8554, 0.8595, 0.8566, 0.8535, 0.8599, 0.8596, 0.8594,
#        0.8585, 0.8642, 0.8654, 0.8623, 0.8686, 0.8713, 0.8699, 0.8667,
#        0.8657, 0.8709, 0.8611, 0.8712, 0.8721, 0.8742])

# %%
for i in grid:
    
    bs = minibatch_size_grid[i]
    hs = history_size_grid[i]
    plt.figure(1, figsize = (12,10))
    plt.plot(testloss[i],label='bs = {}, hs = {}'.format(bs,hs))
    plt.figure(2, figsize = (12,10))
    plt.plot(trainloss[i],label='bs = {}, hs = {}'.format(bs,hs))
    plt.figure(3, figsize = (12,10))
    plt.plot(testacc[i],label='bs = {}, hs = {}'.format(bs,hs))
    plt.figure(4, figsize = (12,10))
    plt.plot(trainacc[i],label='bs = {}, hs = {}'.format(bs,hs))
    plt.figure(1)
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Minibatch LBFGS Test loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend()
plt.savefig("best_results/mini_LBFGS_test_loss_fcnn2.jpg")
plt.figure (2)
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
plt.title('Minibatch LBFGS Train loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend()
plt.savefig("best_results/mini_LBFGS_train_loss_fcnn2.jpg")
plt.figure (3)
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.title('Minibatch LBFGS Test accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend()
plt.savefig("best_results/mini_LBFGS_test_acc_fcnn2.jpg")
plt.figure (4)
plt.xlabel('Epochs')
plt.ylabel('Train Accuracy')
plt.title('Minibatch LBFGS Train accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend()
plt.savefig("best_results/mini_LBFGS_train_acc_fcnn2.jpg")

# %%
i=3
bs = 64
hs = 20
plt.figure(1, figsize = (12,10))
plt.plot(testloss[i],label='bs = {}, hs = {}'.format(bs,hs))
plt.figure(2, figsize = (12,10))
plt.plot(trainloss[i],label='bs = {}, hs = {}'.format(bs,hs))
plt.figure(3, figsize = (12,10))
plt.plot(testacc[i],label='bs = {}, hs = {}'.format(bs,hs))
plt.figure(4, figsize = (12,10))
plt.plot(trainacc[i],label='bs = {}, hs = {}'.format(bs,hs))
plt.figure(1)
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Minibatch LBFGS Test loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend()
plt.savefig("best_results/mini_LBFGS_test_loss_fcnn.jpg")
plt.figure (2)
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
plt.title('Minibatch LBFGS Train loss in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend()
plt.savefig("best_results/mini_LBFGS_train_loss_fcnn.jpg")
plt.figure (3)
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.title('Minibatch LBFGS Test accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend()
plt.savefig("best_results/mini_LBFGS_test_acc_fcnn.jpg")
plt.figure (4)
plt.xlabel('Epochs')
plt.ylabel('Train Accuracy')
plt.title('Minibatch LBFGS Train accuracy in FCNN for different batch sizes and history sizes',fontsize = 20)
plt.legend()
plt.savefig("best_results/mini_LBFGS_train_acc_fcnn.jpg")

# %%
testacc[9]
# Out:
# array([0.9369, 0.9543, 0.9593, 0.9562, 0.9678, 0.9658, 0.9678, 0.9689,
#        0.9692, 0.9695, 0.9726, 0.97  , 0.9719, 0.9726, 0.971 , 0.9708,
#        0.9725, 0.9736, 0.9741, 0.973 , 0.9753, 0.9736, 0.9756, 0.9714,
#        0.9724, 0.9737, 0.9768, 0.9752, 0.9752, 0.9766])

# %%
testacc[6]
# Out:
# array([0.8471, 0.9294, 0.9537, 0.9131, 0.9481, 0.9657, 0.9506, 0.9553,
#        0.9689, 0.9619, 0.9596, 0.9691, 0.9669, 0.9696, 0.9653, 0.9727,
#        0.9694, 0.9587, 0.9649, 0.9747, 0.9618, 0.9674, 0.9721, 0.9569,
#        0.9756, 0.9742, 0.9749, 0.9731, 0.9694, 0.9743])
