# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Test Accuracy

# %%
testacc = np.loadtxt("Test_accuracy.txt")

# %%
np.shape(testacc)
# Out:
# (5, 15)

# %%
methods = ["SGD","LBFGSfullbatch","LBFGSminibatch","LBFGSNewminibatch","SDLBFGS"]

bs_grid = [64,0,4096,1024,64]
hs_grid = [0,10,10,5,0]
epochs = [15, 15, 15, 10, 15]

# %%
testacc[0,0:15]
# Out:
# array([0.9816, 0.9878, 0.9914, 0.9908, 0.9892, 0.9911, 0.9927, 0.9921,
#        0.9914, 0.9927, 0.9926, 0.9909, 0.9929, 0.9926, 0.9935])

# %%
for i in range(5):
    bs = bs_grid[i]
    hs = hs_grid[i]
    meth = methods[i]    
    plt.figure(1, figsize = (12,12))
    if i ==0:
        lr = 0.001
        plt.plot(testacc[i,0:epochs[i]],label='{}, lr = {}, bs = {}'.format(meth,lr,bs))
        
    elif bs != 0 and hs !=0:
        plt.plot(testacc[i,0:epochs[i]],label='{}, bs = {}, hs = {}'.format(meth,bs,hs))
    elif bs != 0:
        plt.plot(testacc[i,0:epochs[i]],label='{}, bs = {}'.format(meth,bs))
    elif hs != 0:
        plt.plot(testacc[i,0:epochs[i]],label='{}, hs = {}'.format(meth,hs))
    else:
        plt.plot(testacc[i,0:epochs[i]],label='{}'.format(meth))
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.title('Test accuracy in CNN for different methods',fontsize = 20)
plt.legend(fontsize = 13)
plt.savefig("test_accuracy_semilogy_cnn.jpg")
plt.figure (2)

# %%
for i in range(5):
    bs = bs_grid[i]
    hs = hs_grid[i]
    meth = methods[i]    
    plt.figure(1, figsize = (12,12))
    if i ==0:
        lr = 0.01
        plt.semilogy(testacc[i,0:epochs[i]],label='{}, lr = {}, bs = {}'.format(meth,lr,bs))
        
    elif bs != 0 and hs !=0:
        plt.semilogy(testacc[i,0:epochs[i]],label='{}, bs = {}, hs = {}'.format(meth,bs,hs))
    elif bs != 0:
        plt.semilogy(testacc[i,0:epochs[i]],label='{}, bs = {}'.format(meth,bs))
    elif hs != 0:
        plt.semilogy(testacc[i,0:epochs[i]],label='{}, hs = {}'.format(meth,hs))
    else:
        plt.semilogy(testacc[i,0:epochs[i]],label='{}'.format(meth))
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
plt.title('Test accuracy in CNN for different methods',fontsize = 20)
plt.legend(fontsize = 13)
plt.savefig("test_accuracy_cnn.jpg")
plt.figure (2)

# %%
np.shape(testacc)[0]
# Out:
# 3

# %%
testacc[9]
# Out:
# array([0.9369, 0.9543, 0.9593, 0.9562, 0.9678, 0.9658, 0.9678, 0.9689,
#        0.9692, 0.9695, 0.9726, 0.97  , 0.9719, 0.9726, 0.971 , 0.9708,
#        0.9725, 0.9736, 0.9741, 0.973 , 0.9753, 0.9736, 0.9756, 0.9714,
#        0.9724, 0.9737, 0.9768, 0.9752, 0.9752, 0.9766])

# %%
testacc[6]
# Out:
# array([0.8471, 0.9294, 0.9537, 0.9131, 0.9481, 0.9657, 0.9506, 0.9553,
#        0.9689, 0.9619, 0.9596, 0.9691, 0.9669, 0.9696, 0.9653, 0.9727,
#        0.9694, 0.9587, 0.9649, 0.9747, 0.9618, 0.9674, 0.9721, 0.9569,
#        0.9756, 0.9742, 0.9749, 0.9731, 0.9694, 0.9743])

# %% [markdown]
# # Train Loss

# %%
trainloss = np.loadtxt("Train_loss.txt")

# %%
for i in range(5):
    bs = bs_grid[i]
    hs = hs_grid[i]
    meth = methods[i]    
    plt.figure(1, figsize = (12,12))
    if i ==0:
        lr = 0.01
        plt.plot(trainloss[i,0:epochs[i]],label='{}, lr = {}, bs = {}'.format(meth,lr,bs))
        
    elif bs != 0 and hs !=0:
        plt.semilogy(trainloss[i,0:epochs[i]],label='{}, bs = {}, hs = {}'.format(meth,bs,hs))
    elif bs != 0:
        plt.semilogy(trainloss[i,0:epochs[i]],label='{}, bs = {}'.format(meth,bs))
    elif hs != 0:
        plt.semilogy(trainloss[i,0:epochs[i]],label='{}, hs = {}'.format(meth,hs))
    else:
        plt.semilogy(trainloss[i,0:epochs[i]],label='{}'.format(meth))
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
plt.title('Train loss in CNN for different methods',fontsize = 20)
plt.legend(fontsize = 13)
plt.savefig("train_loss_semilogy_cnn.jpg")
plt.figure (2)

# %%
for i in range(5):
    bs = bs_grid[i]
    hs = hs_grid[i]
    meth = methods[i]    
    plt.figure(1, figsize = (12,12))
    if i ==0:
        lr = 0.01
        plt.plot(trainloss[i,0:epochs[i]],label='{}, lr = {}, bs = {}'.format(meth,lr,bs))
        
    elif bs != 0 and hs !=0:
        plt.plot(trainloss[i,0:epochs[i]],label='{}, bs = {}, hs = {}'.format(meth,bs,hs))
    elif bs != 0:
        plt.plot(trainloss[i,0:epochs[i]],label='{}, bs = {}'.format(meth,bs))
    elif hs != 0:
        plt.plot(trainloss[i,0:epochs[i]],label='{}, hs = {}'.format(meth,hs))
    else:
        plt.plot(trainloss[i,0:epochs[i]],label='{}'.format(meth))
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
plt.title('Train loss in CNN for different methods',fontsize = 20)
plt.legend(fontsize = 13)
plt.savefig("train_loss_cnn.jpg")
plt.figure (2)

# %% [markdown]
# # Test Loss

# %%
testloss = np.loadtxt("Test_loss.txt")

# %%
for i in range(5):
    bs = bs_grid[i]
    hs = hs_grid[i]
    meth = methods[i]    
    plt.figure(1, figsize = (12,12))
    if i ==0:
        lr = 0.01
        plt.semilogy(testloss[i,0:epochs[i]],label='{}, lr = {}, bs = {}'.format(meth,lr,bs))
        
    elif bs != 0 and hs !=0:
        plt.semilogy(testloss[i,0:epochs[i]],label='{}, bs = {}, hs = {}'.format(meth,bs,hs))
    elif bs != 0:
        plt.semilogy(testloss[i,0:epochs[i]],label='{}, bs = {}'.format(meth,bs))
    elif hs != 0:
        plt.semilogy(testloss[i,0:epochs[i]],label='{}, hs = {}'.format(meth,hs))
    else:
        plt.semilogy(testloss[i,0:epochs[i]],label='{}'.format(meth))
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Test loss in CNN for different methods',fontsize = 20)
plt.legend(fontsize = 13)
plt.savefig("test_loss_semilogy_cnn.jpg")
plt.figure (2)

# %%
for i in range(5):
    bs = bs_grid[i]
    hs = hs_grid[i]
    meth = methods[i]    
    plt.figure(1, figsize = (12,12))
    if i ==0:
        lr = 0.01
        plt.semilogy(trainloss[i,0:epochs[i]],label='{}, lr = {}, bs = {}'.format(meth,lr,bs))
        
    elif bs != 0 and hs !=0:
        plt.plot(testloss[i,0:epochs[i]],label='{}, bs = {}, hs = {}'.format(meth,bs,hs))
    elif bs != 0:
        plt.plot(testloss[i,0:epochs[i]],label='{}, bs = {}'.format(meth,bs))
    elif hs != 0:
        plt.plot(testloss[i,0:epochs[i]],label='{}, hs = {}'.format(meth,hs))
    else:
        plt.plot(testloss[i,0:epochs[i]],label='{}'.format(meth))
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Test loss in CNN for different methods',fontsize = 20)
plt.legend(fontsize = 13)
plt.savefig("test_loss_cnn.jpg")
plt.figure (2)
