# %%
# torch and math  
import torch
from torch import Tensor
import math
from torch import nn
from torch.nn import functional as F
import numpy as np

# data and vizualisation
from helpers import *
import matplotlib
import matplotlib.pyplot as plt

# %%
#Parameters
nb_samples = 1000

# %%
# generate the data
train_input, train_target, test_input, test_target = generate_disc_data(nb_samples, one_hot_labels = False, normalize = True)

# %%
plot_disc_data(train_input, train_target, one_hot_labels = False)

# %%
def model_creation():
    model_1 = nn.Sequential(
    nn.Linear(2, 25),nn.ReLU(),
    nn.Linear(25, 25),nn.ReLU(),
    nn.Linear(25, 25),nn.ReLU(),
    nn.Linear(25, 25),nn.ReLU(),
    nn.Tanh(),nn.Linear(25,2)
    );
    return model_1

# %%
def SGD_optimizer(parameter):
    eta = 0.1
    return torch.optim.SGD(parameter, lr = eta)

# %%
nb_samples,epochs = 1000, 250
eta, batch_size = 0.1 , 100
validation_ratio , validation_rounds = 0.1 , 10
one_hot_labels,show_training= False, False
result ,loss_feedback = evaluate_model(model_creation,train_SGD,SGD_optimizer,nb_samples, epochs, batch_size, validation_ratio, validation_rounds,one_hot_labels,show_training)
# Out:
# Train error = 0.7777777777777778 Validation error = 1.0 Test error = 1.3
# Train error = 0.6666666666666666 Validation error = 2.0 Test error = 0.5
# Train error = 0.0 Validation error = 1.0 Test error = 1.1
# Train error = 1.1111111111111112 Validation error = 2.0 Test error = 1.6
# Train error = 0.7777777777777778 Validation error = 0.0 Test error = 0.7
# Train error = 0.2222222222222222 Validation error = 0.0 Test error = 0.9
# Train error = 0.4444444444444444 Validation error = 1.0 Test error = 0.7
# Train error = 0.0 Validation error = 1.0 Test error = 0.9
# Train error = 0.1111111111111111 Validation error = 2.0 Test error = 1.0
# Train error = 0.0 Validation error = 2.0 Test error = 0.5

# %%
convergence_vizualisation(loss_feedback)

# %%
def LBFGS_optimizer(parameter):
    lr=0.8
    max_iter=20
    max_eval=None
    tolerance_grad=1e-07
    tolerance_change=1e-09
    history_size=100
    line_search_fn='strong_wolfe'
    return torch.optim.LBFGS(parameter, lr, max_iter, max_eval, tolerance_grad, tolerance_change, history_size, line_search_fn)

# %%
nb_samples,epochs = 1000, 25
eta, batch_size = 0.1 , 100
validation_ratio , validation_rounds = 0.1 , 10
one_hot_labels,show_training= False, False
result ,loss_feedback = evaluate_model(model_creation,train_LBFGS,LBFGS_optimizer,nb_samples, epochs, batch_size, validation_ratio, validation_rounds,one_hot_labels,show_training)
# Out:
# Train error = 0.0 Validation error = 0.0 Test error = 0.3
# Train error = 0.0 Validation error = 1.0 Test error = 0.4
# Train error = 0.0 Validation error = 0.0 Test error = 0.6
# Train error = 0.0 Validation error = 0.0 Test error = 0.7
# Train error = 0.0 Validation error = 1.0 Test error = 0.5
# Train error = 0.0 Validation error = 2.0 Test error = 0.8
# Train error = 0.0 Validation error = 0.0 Test error = 0.9
# Train error = 0.0 Validation error = 1.0 Test error = 0.5
# Train error = 0.0 Validation error = 1.0 Test error = 1.0
# Train error = 0.0 Validation error = 2.0 Test error = 0.4

# %%
loss_feedback[:,0]
# Out:
# array([0.00749044, 0.00732851, 0.01570801, 0.02523712, 0.03936102,
#        0.00281208, 0.0116416 , 0.00921138, 0.04394196, 0.01326703])

# %%
convergence_vizualisation(loss_feedback)

# %%
convergence_vizualisation(loss_feedback[4:8])
