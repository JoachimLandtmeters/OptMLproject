# %%
# torch and math  
import torch
from torch import Tensor
import math
from torch import nn
from torch.nn import functional as F
import numpy as np

# data and vizualisation
from helpers import *
import matplotlib
import matplotlib.pyplot as plt

# %%
#Parameters
nb_samples = 1000

# %%
# generate the data
train_input, train_target, test_input, test_target = generate_disc_data(nb_samples, one_hot_labels = False, normalize = True)

# %%
plot_disc_data(train_input, train_target, one_hot_labels = False)

# %%
def model_creation():
    model_1 = nn.Sequential(
    nn.Linear(2, 25),nn.ReLU(),
    nn.Linear(25, 25),nn.ReLU(),
    nn.Linear(25, 25),nn.ReLU(),
    nn.Linear(25, 25),nn.ReLU(),
    nn.Tanh(),nn.Linear(25,2)
    );
    return model_1

# %%
nb_samples,epochs = 1000, 250
eta, batch_size = 0.1 , 100
validation_ratio , validation_rounds = 0.1 , 10
one_hot_labels,show_training= False, False
result ,loss_feedback = evaluate_model(model_creation, nb_samples,eta, epochs, batch_size, validation_ratio, validation_rounds,one_hot_labels,show_training)
# Out:
# Train error = 0.0 Validation error = 1.0 Test error = 0.9
# Train error = 0.1111111111111111 Validation error = 0.0 Test error = 0.3
# Train error = 0.2222222222222222 Validation error = 1.0 Test error = 1.5
# Train error = 0.1111111111111111 Validation error = 3.0 Test error = 1.2
# Train error = 0.3333333333333333 Validation error = 1.0 Test error = 1.1
# Train error = 0.2222222222222222 Validation error = 3.0 Test error = 1.4
# Train error = 0.1111111111111111 Validation error = 3.0 Test error = 0.7
# Train error = 0.1111111111111111 Validation error = 0.0 Test error = 0.7
# Train error = 1.5555555555555556 Validation error = 3.0 Test error = 2.0
# Train error = 1.1111111111111112 Validation error = 0.0 Test error = 0.8

# %%
convergence_vizualisation(loss_feedback)
